# %%
# imports required for the algorithm
import os

from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from datetime import datetime
from math import sqrt
import numpy as np

from matplotlib import pyplot

from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# path to load and save data
data_input_path = '../../data_in/CE_Crateus.csv'
data_output_path = '../../data_out/weather.csv'
data_output_path_npsave = '../../data_out/weather.npy'

# %%
# transform date into appropriate format
def parse(x):
	return datetime.strptime(x, '%d/%m/%Y')

# %%
# load the input dataset and save like a output dataset
def format_dataset(data_input_path, output_path):
    try:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1')
    except:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1', skiprows=2)
    
    dataset.index.name = 'date'

    dataset.drop('Unnamed: 11', axis=1, inplace=True)
    dataset.drop('Estacao', axis=1, inplace=True)
    
    dataset['TempMinima'] = dataset['TempMinima'].shift(-1)
    dataset['Precipitacao'] = dataset['Precipitacao'].shift(-1)
    
    dataset.drop('Hora', axis=1, inplace=True)
    
    dataset = dataset.loc[~dataset.index.duplicated(keep='first')]
    
    # replaces first line NA values with next line value
    dataset.iloc[0,:].fillna(dataset.iloc[1,:], inplace=True)
    
    # replace all NA values with prev line value
    dataset.ffill(axis=0, inplace=True)

    # show the first 5 lines on the dataset
    print(dataset)
        
    # save file
    dataset.to_csv(output_path)

format_dataset(data_input_path, data_output_path)
# Out:
#             Precipitacao  TempMaxima  TempMinima  Insolacao  Evaporacao Piche  \
# date
# 2015-01-01           0.0        35.0        23.7        5.9              10.2
# 2015-01-02           0.0        35.8        23.0       10.6              10.2
# 2015-01-03          37.4        31.9        22.3        4.3               6.2
# 2015-01-04          12.4        27.3        20.7        1.9               3.5
# 2015-01-05          23.0        32.4        20.7        8.3               1.5
# ...                  ...         ...         ...        ...               ...
# 2018-04-26           0.0        31.0        20.8        8.9               0.5
# 2018-04-27           0.0        31.7        22.9       10.5               0.5
# 2018-04-28           0.0        31.3        21.5        9.5               0.5
# 2018-04-29           3.5        28.9        22.7        2.5               0.5
# 2018-04-30           0.4        28.9        21.9        2.5               0.5
#
#             Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media
# date
# 2015-01-01            28.76                   47.00                   2.633333
# 2015-01-02            26.72                   72.50                   1.866667
# 2015-01-03            26.32                   71.50                   1.600000
# 2015-01-04            23.50                   88.25                   2.266667
# 2015-01-05            26.64                   66.75                   3.166667
# ...                     ...                     ...                        ...
# 2018-04-26            25.66                   78.00                   1.286100
# 2018-04-27            26.26                   77.00                   1.800540
# 2018-04-28            26.38                   81.00                   1.028880
# 2018-04-29            24.64                   93.00                   1.543320
# 2018-04-30            24.64                   93.00                   2.057760
#
# [1091 rows x 8 columns]

# %%
# load dataset
def load_dataset(input_path):
    return read_csv(input_path, header=0, index_col=0)

dataset = load_dataset(data_output_path)
values = dataset.values

# %%
# plot each column in a graph
def plot_columns(values):
    groups = list(range(0,len(values[0])))
    i = 1
    
    pyplot.figure(dpi=120)
    for group in groups:
        pyplot.subplot(len(groups), 1, i)
        pyplot.plot(values[:, group])
        pyplot.title(dataset.columns[group], y=0.1, loc='right')
        i += 1
    pyplot.show()

plot_columns(values)

# %%
# convert series to supervised learning
def series_to_supervised(dataset, day):
    y_test = np.array([dataset.loc[day]['TempMaxima'], dataset.loc[day]['TempMinima']])
    y_test = y_test.reshape(1,2)
    
    dataset = dataset[:-1]
    
    x_test = np.array(dataset[-60:])
    x_test = x_test.reshape(1,60,8)
    
    lista = []
    
    for i in list(dataset.index):
        lista.append([dataset.loc[i]['TempMaxima'], dataset.loc[i]['TempMinima']])
    y_train = np.array(lista[60:])
    
    dataset = dataset[:-1]
    
    x_train = np.array(dataset[-60:])
    x_train = x_train.reshape(1,60,8)
    dataset = dataset[:-1]
    
    while len(dataset) >= 60:
        array_aux = np.array(dataset[-60:])
        array_aux = array_aux.reshape(1,60,8)
        x_train = np.concatenate((x_train, array_aux), axis=0)
        dataset = dataset[:-1]
    
    return [x_train, y_train, x_test, y_test]

# %%
# inner loop
def myLSTM(x_train, y_train, x_test, y_test):
    x_val = x_train[-1]
    y_val = y_train[-1]
    x_val = x_val.reshape(1,60,8)
    y_val = y_val.reshape(1,2)
    x_train = x_train[:-1]
    y_train = y_train[:-1]
    
    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dense(16, activation='relu'))   # worth it?
    model.add(Dense(2))
    model.compile(loss='mae', optimizer='adam', metrics=['mse'])
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')
    ]
    
    # fit network
    history = model.fit(x_train, y_train,
                        epochs=1000, 
                        batch_size=72, 
                        validation_data=(x_val, y_val), 
                        verbose=2, 
                        shuffle=True, 
                        callbacks=callbacks)
    
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()
    
    y = inverseScale(model, x_test, y_test)
    inv_y_hat = y[0]
    inv_y_test = y[1]
    
    print('\npredict: {}'.format(inv_y_hat))
    print('real:      {}\n'.format(inv_y_test))
    
    return [inv_y_hat, inv_y_test]

# %%
def inverseScale(model, x_test, y_test):
    # make a prediction
    y_hat = model.predict(x_test)
    
    new_x_test = x_test[:,-1,:]
    new_x_test = new_x_test.reshape((x_test.shape[0], x_test.shape[2]))
    new_x_test = np.concatenate((new_x_test[:, 0:1], new_x_test[:, 3:]), axis=1)
    
    # invert scaling for forecast
    inv_y_hat = np.concatenate((y_hat, new_x_test), axis=1)
    inv_y_hat = np.expm1(inv_y_hat)
    inv_y_hat = inv_y_hat[:,:2]
    
    # invert scaling for actual value
    new_test_y = y_test.reshape((len(y_test), 2))
    inv_y_test = np.concatenate((new_test_y, new_x_test), axis=1)
    inv_y_test = np.expm1(inv_y_test)
    inv_y_test = inv_y_test[:,:2]
    
    return [inv_y_hat, inv_y_test]

# %%
# Nested Cross Validation
def NCV(dataset, days_to_predict):
    i = len(days_to_predict) - 1
    y_hats = []
    y_tests = []
    
    # outer loop
    while(i >= 0):
        data = series_to_supervised(dataset, days_to_predict[i])
        x_train = data[0]
        y_train = data[1]
        x_test = data[2]
        y_test = data[3]
        
        result = myLSTM(x_train, y_train, x_test, y_test)
        
        y_hats += result[0].tolist()
        y_tests += result[1].tolist()
        
        i -= 1
        dataset = dataset[:-1]
        
    return [y_hats, y_tests]

# %%
def metrics(y_hats, y_tests):
    y_hats_max = []
    y_hats_min = []
    y_tests_max = []
    y_tests_min = []
    percentual = 100
    n = len(y_hats)
    j = 1
    
    for y in y_hats:
        y_hats_max += [y[0]]
        y_hats_min += [y[1]]
        
    for y in y_tests:
        y_tests_max += [y[0]]
        y_tests_min += [y[1]]
    
    rmse_max = sqrt(mean_squared_error(y_tests_max, y_hats_max))
    variance_max = explained_variance_score(y_tests_max, y_hats_max)
    maxError_max = max_error(y_tests_max, y_hats_max)
    meanAbsolutError_max = mean_absolute_error(y_tests_max, y_hats_max)
    medianAbsoluteError_max = median_absolute_error(y_tests_max, y_hats_max)
    
    rmse_min = sqrt(mean_squared_error(y_tests_min, y_hats_min))
    variance_min = explained_variance_score(y_tests_min, y_hats_min)
    maxError_min = max_error(y_tests_min, y_hats_min)
    meanAbsolutError_min = mean_absolute_error(y_tests_min, y_hats_min)
    medianAbsoluteError_min = median_absolute_error(y_tests_min, y_hats_min)
    
    print('Maximum metrics')
    print('Test RMSE -------------------------- {:.4}'.format(rmse_max))
    print('Test VARIANCE ---------------------- {:.4}'.format(variance_max))
    print('Test MAX-ERROR --------------------- {:.4}'.format(maxError_max))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError_max))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError_max))
    
    print('\nAccuracy')
    while percentual > 0:
        count = 0
        n = len(y_hats_max)
        
        for i in range(0,len(y_hats_max)):
            error = abs(y_hats_max[i] - y_tests_max[i])
            if  error > j-1 and error <= j:
                count += 1
        
        percentual = round((count/n)*100,2)
        if percentual > 0:
            print('{}% of predictions missed {} point(s) or less'.format(percentual, j))
        j += 1
    
    print('\nMinimum metrics')
    print('Test RMSE -------------------------- {:.4}'.format(rmse_min))
    print('Test VARIANCE ---------------------- {:.4}'.format(variance_min))
    print('Test MAX-ERROR --------------------- {:.4}'.format(maxError_min))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError_min))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError_min))
    
    j = 1
    percentual = 100
    print('\nAccuracy')
    while percentual > 0:
        count = 0
        n = len(y_hats_max)
        
        for i in range(0,len(y_hats_max)):
            error = abs(y_hats_min[i] - y_tests_min[i])
            if  error > j-1 and error <= j:
                count += 1
        
        percentual = round((count/n)*100,2)
        if percentual > 0:
            print('{}% of predictions missed {} point(s) or less'.format(percentual, j))
        j += 1

# %%
# to get index the last 30 days
days_to_predict = list(dataset.index[-30:])

values_scaled = np.log1p(values)
dataset_scaled = DataFrame(values_scaled)
dataset_scaled.index = dataset.index
dataset_scaled.columns = dataset.columns

plot_columns(values_scaled)

result = NCV(dataset_scaled, days_to_predict)
# Out:
# Train on 1029 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2
1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0706 - val_mean_squared_error: 0.0099
# Epoch 24/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0703 - val_mean_squared_error: 0.0098
# Epoch 25/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0714 - val_mean_squared_error: 0.0099
# Epoch 26/1000
#  - 1s - loss: 0.0456 - mean_squared_error: 0.0035 - val_loss: 0.0696 - val_mean_squared_error: 0.0094
# Epoch 27/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0762 - val_mean_squared_error: 0.0107
# Epoch 28/1000
#  - 1s - loss: 0.0454 - mean_squared_error: 0.0035 - val_loss: 0.0700 - val_mean_squared_error: 0.0092
# Epoch 29/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0720 - val_mean_squared_error: 0.0101
# Epoch 30/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.0703 - val_mean_squared_error: 0.0098
# Epoch 31/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0706 - val_mean_squared_error: 0.0098
# Epoch 32/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.0737 - val_mean_squared_error: 0.0101
# Epoch 33/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0694 - val_mean_squared_error: 0.0093
# Epoch 34/1000
#  - 1s - loss: 0.0454 - mean_squared_error: 0.0034 - val_loss: 0.0685 - val_mean_squared_error: 0.0093
# Epoch 35/1000
#  - 1s - loss: 0.0454 - mean_squared_error: 0.0034 - val_loss: 0.0712 - val_mean_squared_error: 0.0094
# Epoch 36/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0719 - val_mean_squared_error: 0.0094
# Epoch 37/1000
#  - 1s - loss: 0.0452 - mean_squared_error: 0.0034 - val_loss: 0.0704 - val_mean_squared_error: 0.0088
# Epoch 38/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0689 - val_mean_squared_error: 0.0090
# Epoch 39/1000
#  - 1s - loss: 0.0451 - mean_squared_error: 0.0034 - val_loss: 0.0683 - val_mean_squared_error: 0.0092
# Epoch 40/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0727 - val_mean_squared_error: 0.0094
# Epoch 41/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.0671 - val_mean_squared_error: 0.0089
# Epoch 42/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0692 - val_mean_squared_error: 0.0092
# Epoch 43/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0700 - val_mean_squared_error: 0.0095
# Epoch 44/1000
#  - 1s - loss: 0.0449 - mean_squared_error: 0.0034 - val_loss: 0.0701 - val_mean_squared_error: 0.0094
# Epoch 45/1000
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0488 - val_mean_squared_error: 0.0024
# Epoch 12/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0478 - val_mean_squared_error: 0.0023
# Epoch 13/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0036 - val_loss: 0.0497 - val_mean_squared_error: 0.0025
# predict: [[26.76816468 21.91581662]]
# real:      [[28.9 22.7]]
#
# Train on 1027 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.9100 - mean_squared_error: 8.6697 - val_loss: 2.1076 - val_mean_squared_error: 4.5249
# Epoch 2/1000
#  - 1s - loss: 1.5022 - mean_squared_error: 2.7221 - val_loss: 0.7897 - val_mean_squared_error: 1.0287
# Epoch 3/1000
#  - 1s - loss: 0.5677 - mean_squared_error: 0.5249 - val_loss: 0.2188 - val_mean_squared_error: 0.0634
# Epoch 4/1000
#  - 1s - loss: 0.1199 - mean_squared_error: 0.0246 - val_loss: 0.0989 - val_mean_squared_error: 0.0119
# Epoch 5/1000
#  - 1s - loss: 0.0645 - mean_squared_error: 0.0063 - val_loss: 0.0455 - val_mean_squared_error: 0.0025
# Epoch 6/1000
#  - 1s - loss: 0.0513 - mean_squared_error: 0.0043 - val_loss: 0.0197 - val_mean_squared_error: 3.8713e-04
# Epoch 7/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0387 - val_mean_squared_error: 0.0017
# Epoch 8/1000
#  - 1s - loss: 0.0467 - mean_squared_error: 0.0036 - val_loss: 0.0391 - val_mean_squared_error: 0.0029
# Epoch 9/1000
#  - 1s - loss: 0.0467 - mean_squared_error: 0.0037 - val_loss: 0.0352 - val_mean_squared_error: 0.0015
# Epoch 10/1000
#  - 1s - loss: 0.0456 - mean_squared_error: 0.0035 - val_loss: 0.0290 - val_mean_squared_error: 0.0010
# Epoch 11/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0282 - val_mean_squared_error: 0.0010
# Epoch 12/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0270 - val_mean_squared_error: 7.9782e-04
# Epoch 13/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0320 - val_mean_squared_error: 0.0020
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.0291 - val_mean_squared_error: 0.0010
# Epoch 15/1000
#  - 1s - loss: 0.0445 - mean_squared_error: 0.0033 - val_loss: 0.0271 - val_mean_squared_error: 0.0011
# Epoch 16/1000
#  - 1s - loss: 0.0445 - mean_squared_error: 0.0034 - val_loss: 0.0279 - val_mean_squared_error: 0.0011
# predict: [[31.76968534 22.07985417]]
# real:      [[31.3 21.5]]
#
# Train on 1026 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2
#  - 1s - loss: 0.0451 - mean_squared_error: 0.0034 - val_loss: 0.0888 - val_mean_squared_error: 0.0094
# Epoch 26/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0035 - val_loss: 0.0711 - val_mean_squared_error: 0.0056
# Epoch 27/1000
#  - 1s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0708 - val_mean_squared_error: 0.0053
# Epoch 28/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0033 - val_loss: 0.0907 - val_mean_squared_error: 0.0090
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 29/1000
#  - 1s - loss: 0.0449 - mean_squared_error: 0.0034 - val_loss: 0.0670 - val_mean_squared_error: 0.0047
# Epoch 30/1000
#  - 1s - loss: 0.0446 - mean_squared_error: 0.0033 - val_loss: 0.0757 - val_mean_squared_error: 0.0062
# Epoch 31/1000
#  - 1s - loss: 0.0442 - mean_squared_error: 0.0032 - val_loss: 0.0777 - val_mean_squared_error: 0.0065
# predict: [[31.07438931 22.34723036]]
# real:      [[31.7 22.9]]
#
# Train on 1025 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.8718 - mean_squared_error: 8.5237 - val_loss: 2.1499 - val_mean_squared_error: 4.9178
# Epoch 2/1000
#  - 1s - loss: 1.5879 - mean_squared_error: 3.0546 - val_loss: 0.6657 - val_mean_squared_error: 0.8717
# Epoch 3/1000
#  - 1s - loss: 0.4109 - mean_squared_error: 0.3249 - val_loss: 0.1913 - val_mean_squared_error: 0.0416
# Epoch 4/1000
#  - 1s - loss: 0.1300 - mean_squared_error: 0.0252 - val_loss: 0.0515 - val_mean_squared_error: 0.0042
# Epoch 5/1000
#  - 1s - loss: 0.0733 - mean_squared_error: 0.0086 - val_loss: 0.0572 - val_mean_squared_error: 0.0033
# Epoch 6/1000
#  - 1s - loss: 0.0572 - mean_squared_error: 0.0054 - val_loss: 0.0592 - val_mean_squared_error: 0.0038
# Epoch 7/1000
#  - 1s - loss: 0.0501 - mean_squared_error: 0.0042 - val_loss: 0.0362 - val_mean_squared_error: 0.0016
# Epoch 8/1000
#  - 1s - loss: 0.0498 - mean_squared_error: 0.0041 - val_loss: 0.0581 - val_mean_squared_error: 0.0035
# Epoch 9/1000
#  - 1s - loss: 0.0493 - mean_squared_error: 0.0041 - val_loss: 0.0410 - val_mean_squared_error: 0.0022
# Epoch 10/1000
#  - 1s - loss: 0.0479 - mean_squared_error: 0.0039 - val_loss: 0.0556 - val_mean_squared_error: 0.0032
# Epoch 11/1000
#  - 1s - loss: 0.0475 - mean_squared_error: 0.0037 - val_loss: 0.0532 - val_mean_squared_error: 0.0031
# Epoch 12/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0037 - val_loss: 0.0610 - val_mean_squared_error: 0.0038
# Epoch 13/1000
#  - 1s - loss: 0.0468 - mean_squared_error: 0.0037 - val_loss: 0.0825 - val_mean_squared_error: 0.0068
# Epoch 14/1000
#  - 1s - loss: 0.0475 - mean_squared_error: 0.0038 - val_loss: 0.0510 - val_mean_squared_error: 0.0026
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 1s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0650 - val_mean_squared_error: 0.0042
# Epoch 16/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0036 - val_loss: 0.0566 - val_mean_squared_error: 0.0032
# Epoch 17/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0035 - val_loss: 0.0611 - val_mean_squared_error: 0.0037
# predict: [[31.73709051 21.13911752]]
# real:      [[31.  20.8]]
#
# Train on 1024 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.3743 - mean_squared_error: 5.9044 - val_loss: 1.5678 - val_mean_squared_error: 2.5655
# Epoch 2/1000
#  - 1s - loss: 0.9961 - mean_squared_error: 1.2795 - val_loss: 0.3085 - val_mean_squared_error: 0.1153
# Epoch 3/1000
#  - 1s - loss: 0.2130 - mean_squared_error: 0.0616 - val_loss: 0.1015 - val_mean_squared_error: 0.0121
# Epoch 4/1000
#  - 1s - loss: 0.0953 - mean_squared_error: 0.0135 - val_loss: 0.0760 - val_mean_squared_error: 0.0058
# Epoch 5/1000
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0054 - val_loss: 0.0621 - val_mean_squared_error: 0.0048
# Epoch 6/1000
#  - 1s - loss: 0.0513 - mean_squared_error: 0.0044 - val_loss: 0.0415 - val_mean_squared_error: 0.0030
# Epoch 7/1000
#  - 1s - loss: 0.0492 - mean_squared_error: 0.0040 - val_loss: 0.0263 - val_mean_squared_error: 0.0013
# Epoch 8/1000
#  - 1s - loss: 0.0493 - mean_squared_error: 0.0040 - val_loss: 0.0186 - val_mean_squared_error: 6.8676e-04
# Epoch 9/1000
#  - 1s - loss: 0.0490 - mean_squared_error: 0.0040 - val_loss: 0.0332 - val_mean_squared_error: 0.0022
# Epoch 10/1000
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0038 - val_loss: 0.0544 - val_mean_squared_error: 0.0037
# Epoch 11/1000
#  - 1s - loss: 0.0481 - mean_squared_error: 0.0039 - val_loss: 0.0255 - val_mean_squared_error: 0.0012
# Epoch 12/1000
#  - 1s - loss: 0.0484 - mean_squared_error: 0.0038 - val_loss: 0.0434 - val_mean_squared_error: 0.0022
# Epoch 13/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0039 - val_loss: 0.0621 - val_mean_squared_error: 0.0043
# Epoch 14/1000
#  - 1s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0375 - val_mean_squared_error: 0.0017
# Epoch 15/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0037 - val_loss: 0.0635 - val_mean_squared_error: 0.0045
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 1s - loss: 0.0472 - mean_squared_error: 0.0038 - val_loss: 0.0430 - val_mean_squared_error: 0.0021
# Epoch 17/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0496 - val_mean_squared_error: 0.0029
# Epoch 18/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0036 - val_loss: 0.0462 - val_mean_squared_error: 0.0024
# predict: [[30.40078508 20.84193069]]
# real:      [[30.7 21. ]]
#
# Train on 1023 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.6582 - mean_squared_error: 7.2444 - val_loss: 1.7389 - val_mean_squared_error: 3.0495
# Epoch 2/1000
#  - 1s - loss: 1.1068 - mean_squared_error: 1.4925 - val_loss: 0.3869 - val_mean_squared_error: 0.1524
# Epoch 3/1000
#  - 1s - loss: 0.2104 - mean_squared_error: 0.0583 - val_loss: 0.0580 - val_mean_squared_error: 0.0036
# Epoch 4/1000
#  - 1s - loss: 0.0892 - mean_squared_error: 0.0121 - val_loss: 0.0865 - val_mean_squared_error: 0.0076
# Epoch 5/1000
#  - 1s - loss: 0.0611 - mean_squared_error: 0.0059 - val_loss: 0.0748 - val_mean_squared_error: 0.0085
# Epoch 6/1000
#  - 1s - loss: 0.0519 - mean_squared_error: 0.0043 - val_loss: 0.0787 - val_mean_squared_error: 0.0090
# Epoch 7/1000
#  - 1s - loss: 0.0495 - mean_squared_error: 0.0040 - val_loss: 0.0797 - val_mean_squared_error: 0.0088
# Epoch 8/1000
#  - 1s - loss: 0.0484 - mean_squared_error: 0.0039 - val_loss: 0.0712 - val_mean_squared_error: 0.0077
# Epoch 9/1000
#  - 1s - loss: 0.0481 - mean_squared_error: 0.0038 - val_loss: 0.0878 - val_mean_squared_error: 0.0092
# Epoch 10/1000
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0038 - val_loss: 0.0809 - val_mean_squared_error: 0.0085
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 1s - loss: 0.0473 - mean_squared_error: 0.0038 - val_loss: 0.0626 - val_mean_squared_error: 0.0057
# Epoch 12/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0036 - val_loss: 0.0687 - val_mean_squared_error: 0.0063
# Epoch 13/1000
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0037 - val_loss: 0.0667 - val_mean_squared_error: 0.0062
# predict: [[30.09684512 23.52614508]]
# real:      [[30.6 21.7]]
#
# Train on 1022 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 3.0750 - mean_squared_error: 9.7453 - val_loss: 2.6594 - val_mean_squared_error: 8.3284
# Epoch 2/1000
#  - 1s - loss: 2.3897 - mean_squared_error: 8.2790 - val_loss: 2.2167 - val_mean_squared_error: 8.5392
# Epoch 3/1000
#  - 1s - loss: 2.0500 - mean_squared_error: 7.8698 - val_loss: 1.9613 - val_mean_squared_error: 7.3808
# Epoch 4/1000
#  - 1s - loss: 1.9011 - mean_squared_error: 6.9857 - val_loss: 1.8524 - val_mean_squared_error: 6.5408
# Epoch 5/1000
#  - 1s - loss: 1.7518 - mean_squared_error: 5.9747 - val_loss: 1.5929 - val_mean_squared_error: 4.6309
# Epoch 6/1000
#  - 1s - loss: 1.2421 - mean_squared_error: 3.0375 - val_loss: 0.8894 - val_mean_squared_error: 1.3945
# Epoch 7/1000
#  - 1s - loss: 0.4427 - mean_squared_error: 0.4993 - val_loss: 0.2085 - val_mean_squared_error: 0.0497
# Epoch 8/1000
#  - 1s - loss: 0.1247 - mean_squared_error: 0.0288 - val_loss: 0.1399 - val_mean_squared_error: 0.0197
# Epoch 9/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0060 - val_loss: 0.0881 - val_mean_squared_error: 0.0089
# Epoch 10/1000
# Epoch 9/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0399 - val_mean_squared_error: 0.0031
# Epoch 10/1000
#  - 1s - loss: 0.0467 - mean_squared_error: 0.0036 - val_loss: 0.0311 - val_mean_squared_error: 0.0018
# Epoch 11/1000
#  - 1s - loss: 0.0467 - mean_squared_error: 0.0036 - val_loss: 0.0390 - val_mean_squared_error: 0.0023
# Epoch 12/1000
#  - 1s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0430 - val_mean_squared_error: 0.0024
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 1s - loss: 0.0459 - mean_squared_error: 0.0036 - val_loss: 0.0398 - val_mean_squared_error: 0.0024
# Epoch 14/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0033 - val_loss: 0.0360 - val_mean_squared_error: 0.0023
# Epoch 15/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0363 - val_mean_squared_error: 0.0023
# predict: [[31.48964772 21.93388079]]
# real:      [[30.  23.1]]
#
# Train on 1020 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.6900 - mean_squared_error: 9.7893 - val_loss: 2.0218 - val_mean_squared_error: 7.3754
# Epoch 2/1000
#  - 1s - loss: 1.7969 - mean_squared_error: 6.0584 - val_loss: 1.4849 - val_mean_squared_error: 4.1869
# Epoch 3/1000
#  - 1s - loss: 1.3639 - mean_squared_error: 3.5797 - val_loss: 1.1427 - val_mean_squared_error: 2.5939
# Epoch 4/1000
#  - 1s - loss: 1.1326 - mean_squared_error: 2.4378 - val_loss: 0.9982 - val_mean_squared_error: 1.8951
# Epoch 5/1000
#  - 1s - loss: 0.9726 - mean_squared_error: 1.7773 - val_loss: 0.8732 - val_mean_squared_error: 1.4659
# Epoch 6/1000
#  - 1s - loss: 0.8557 - mean_squared_error: 1.3759 - val_loss: 0.7459 - val_mean_squared_error: 1.0603
# Epoch 7/1000
#  - 1s - loss: 0.7350 - mean_squared_error: 1.0073 - val_loss: 0.6187 - val_mean_squared_error: 0.7180
# Epoch 8/1000
#  - 1s - loss: 0.5985 - mean_squared_error: 0.6575 - val_loss: 0.4728 - val_mean_squared_error: 0.4098
# Epoch 9/1000
#  - 1s - loss: 0.4407 - mean_squared_error: 0.3467 - val_loss: 0.2996 - val_mean_squared_error: 0.1530
# Epoch 10/1000
#  - 1s - loss: 0.2504 - mean_squared_error: 0.1074 - val_loss: 0.0932 - val_mean_squared_error: 0.0089
# Epoch 11/1000
#  - 1s - loss: 0.0734 - mean_squared_error: 0.0089 - val_loss: 0.0861 - val_mean_squared_error: 0.0141
# Epoch 12/1000
#  - 1s - loss: 0.0587 - mean_squared_error: 0.0055 - val_loss: 0.0616 - val_mean_squared_error: 0.0042
# Epoch 13/1000
#  - 1s - loss: 0.0485 - mean_squared_error: 0.0039 - val_loss: 0.0629 - val_mean_squared_error: 0.0047
# Epoch 14/1000
#  - 1s - loss: 0.0465 - mean_squared_error: 0.0037 - val_loss: 0.0424 - val_mean_squared_error: 0.0030
# Epoch 15/1000
#  - 1s - loss: 0.0472 - mean_squared_error: 0.0038 - val_loss: 0.0357 - val_mean_squared_error: 0.0021
# Epoch 16/1000
#  - 1s - loss: 0.0483 - mean_squared_error: 0.0038 - val_loss: 0.0769 - val_mean_squared_error: 0.0068
# Epoch 17/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0036 - val_loss: 0.0365 - val_mean_squared_error: 0.0024
# Epoch 18/1000
#  - 1s - loss: 0.0467 - mean_squared_error: 0.0037 - val_loss: 0.0540 - val_mean_squared_error: 0.0037
# Epoch 19/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0524 - val_mean_squared_error: 0.0036
# Epoch 20/1000
#  - 1s - loss: 0.0457 - mean_squared_error: 0.0035 - val_loss: 0.0648 - val_mean_squared_error: 0.0049
# Epoch 21/1000
#  - 1s - loss: 0.0456 - mean_squared_error: 0.0036 - val_loss: 0.0308 - val_mean_squared_error: 0.0018
# Epoch 22/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0037 - val_loss: 0.0365 - val_mean_squared_error: 0.0023
# Epoch 23/1000
#  - 1s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.0480 - val_mean_squared_error: 0.0031
# Epoch 24/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0654 - val_mean_squared_error: 0.0051
# Epoch 25/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0036 - val_loss: 0.0671 - val_mean_squared_error: 0.0052
# Epoch 26/1000
#  - 1s - loss: 0.0473 - mean_squared_error: 0.0038 - val_loss: 0.0399 - val_mean_squared_error: 0.0025
# Epoch 27/1000
#  - 1s - loss: 0.0456 - mean_squared_error: 0.0035 - val_loss: 0.0370 - val_mean_squared_error: 0.0022
# Epoch 28/1000
#  - 1s - loss: 0.0449 - mean_squared_error: 0.0034 - val_loss: 0.0502 - val_mean_squared_error: 0.0034
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 29/1000
#  - 1s - loss: 0.0448 - mean_squared_error: 0.0034 - val_loss: 0.0587 - val_mean_squared_error: 0.0042
# Epoch 30/1000
#  - 1s - loss: 0.0447 - mean_squared_error: 0.0034 - val_loss: 0.0523 - val_mean_squared_error: 0.0035
# Epoch 31/1000
#  - 1s - loss: 0.0446 - mean_squared_error: 0.0034 - val_loss: 0.0540 - val_mean_squared_error: 0.0036
# predict: [[31.74112601 21.3389614 ]]
# real:      [[31.1 22.8]]
#
# Train on 1019 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.3391 - mean_squared_error: 5.7480 - val_loss: 1.3191 - val_mean_squared_error: 2.0326
# Epoch 2/1000
#  - 1s - loss: 0.8903 - mean_squared_error: 1.0870 - val_loss: 0.6843 - val_mean_squared_error: 0.5052
# Epoch 3/1000
#  - 1s - loss: 0.3839 - mean_squared_error: 0.2233 - val_loss: 0.1699 - val_mean_squared_error: 0.0289
# Epoch 4/1000
#  - 1s - loss: 0.0891 - mean_squared_error: 0.0118 - val_loss: 0.0193 - val_mean_squared_error: 4.0648e-04
# Epoch 5/1000
#  - 1s - loss: 0.0555 - mean_squared_error: 0.0049 - val_loss: 0.0538 - val_mean_squared_error: 0.0042
# Epoch 6/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0443 - val_mean_squared_error: 0.0031
# Epoch 7/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0335 - val_mean_squared_error: 0.0019
# Epoch 8/1000
#  - 1s - loss: 0.0468 - mean_squared_error: 0.0036 - val_loss: 0.0393 - val_mean_squared_error: 0.0017
# Epoch 9/1000
#  - 1s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0403 - val_mean_squared_error: 0.0018
# Epoch 10/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0362 - val_mean_squared_error: 0.0021
# Epoch 11/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0373 - val_mean_squared_error: 0.0025
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0036 - val_loss: 0.0355 - val_mean_squared_error: 0.0016
# Epoch 13/1000
#  - 1s - loss: 0.0457 - mean_squared_error: 0.0035 - val_loss: 0.0355 - val_mean_squared_error: 0.0020
# Epoch 14/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0035 - val_loss: 0.0371 - val_mean_squared_error: 0.0019
# predict: [[31.20328765 23.26694863]]
# real:      [[31.1 22.3]]
#
# Train on 1018 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.5222 - mean_squared_error: 7.2460 - val_loss: 1.6815 - val_mean_squared_error: 3.7351
# Epoch 2/1000
#  - 1s - loss: 1.1634 - mean_squared_error: 2.2570 - val_loss: 0.4028 - val_mean_squared_error: 0.3037
# Epoch 3/1000
#  - 1s - loss: 0.2245 - mean_squared_error: 0.0975 - val_loss: 0.1401 - val_mean_squared_error: 0.0388
# Epoch 4/1000
#  - 1s - loss: 0.0876 - mean_squared_error: 0.0123 - val_loss: 0.0898 - val_mean_squared_error: 0.0154
# Epoch 5/1000
#  - 1s - loss: 0.0612 - mean_squared_error: 0.0060 - val_loss: 0.0797 - val_mean_squared_error: 0.0090
# Epoch 6/1000
#  - 1s - loss: 0.0521 - mean_squared_error: 0.0045 - val_loss: 0.0664 - val_mean_squared_error: 0.0060
# Epoch 7/1000
#  - 1s - loss: 0.0497 - mean_squared_error: 0.0041 - val_loss: 0.0370 - val_mean_squared_error: 0.0027
# Epoch 8/1000
#  - 1s - loss: 0.0501 - mean_squared_error: 0.0041 - val_loss: 0.0328 - val_mean_squared_error: 0.0019
# Epoch 9/1000
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0038 - val_loss: 0.0581 - val_mean_squared_error: 0.0043
# Epoch 10/1000
#  - 1s - loss: 0.0483 - mean_squared_error: 0.0039 - val_loss: 0.0563 - val_mean_squared_error: 0.0037
# Epoch 11/1000
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0036 - val_loss: 0.0381 - val_mean_squared_error: 0.0017
# Epoch 12/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0436 - val_mean_squared_error: 0.0025
# Epoch 13/1000
#  - 1s - loss: 0.0468 - mean_squared_error: 0.0037 - val_loss: 0.0342 - val_mean_squared_error: 0.0022
# Epoch 14/1000
#  - 1s - loss: 0.0493 - mean_squared_error: 0.0040 - val_loss: 0.0634 - val_mean_squared_error: 0.0040
# Epoch 15/1000
#  - 1s - loss: 0.0479 - mean_squared_error: 0.0038 - val_loss: 0.0404 - val_mean_squared_error: 0.0017
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 1s - loss: 0.0466 - mean_squared_error: 0.0035 - val_loss: 0.0589 - val_mean_squared_error: 0.0038
# Epoch 17/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0036 - val_loss: 0.0509 - val_mean_squared_error: 0.0027
# Epoch 18/1000
#  - 1s - loss: 0.0457 - mean_squared_error: 0.0034 - val_loss: 0.0529 - val_mean_squared_error: 0.0030
# predict: [[31.5596862  22.16133256]]
# real:      [[31.  22.8]]
#
# Train on 1017 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.7113 - mean_squared_error: 7.5222 - val_loss: 1.9012 - val_mean_squared_error: 3.6148
# Epoch 2/1000
#  - 1s - loss: 1.3681 - mean_squared_error: 2.0404 - val_loss: 0.4605 - val_mean_squared_error: 0.2121
# Epoch 3/1000
#  - 1s - loss: 0.2605 - mean_squared_error: 0.0882 - val_loss: 0.1691 - val_mean_squared_error: 0.0396
# Epoch 4/1000
#  - 1s - loss: 0.0925 - mean_squared_error: 0.0122 - val_loss: 0.1260 - val_mean_squared_error: 0.0299
# Epoch 5/1000
#  - 1s - loss: 0.0614 - mean_squared_error: 0.0060 - val_loss: 0.1039 - val_mean_squared_error: 0.0174
# Epoch 6/1000
#  - 1s - loss: 0.0512 - mean_squared_error: 0.0044 - val_loss: 0.1027 - val_mean_squared_error: 0.0158
# Epoch 7/1000
#  - 1s - loss: 0.0490 - mean_squared_error: 0.0040 - val_loss: 0.0961 - val_mean_squared_error: 0.0148
# Epoch 8/1000
#  - 1s - loss: 0.0484 - mean_squared_error: 0.0039 - val_loss: 0.1045 - val_mean_squared_error: 0.0142
# Epoch 9/1000
#  - 1s - loss: 0.0481 - mean_squared_error: 0.0038 - val_loss: 0.0990 - val_mean_squared_error: 0.0126
# Epoch 10/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0037 - val_loss: 0.1001 - val_mean_squared_error: 0.0136
# Epoch 11/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.1040 - val_mean_squared_error: 0.0140
# Epoch 12/1000
#  - 1s - loss: 0.0466 - mean_squared_error: 0.0037 - val_loss: 0.0974 - val_mean_squared_error: 0.0143
# Epoch 13/1000
#  - 1s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0919 - val_mean_squared_error: 0.0135
# Epoch 14/1000
#  - 1s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0942 - val_mean_squared_error: 0.0137
# Epoch 15/1000
#  - 1s - loss: 0.0468 - mean_squared_error: 0.0037 - val_loss: 0.0985 - val_mean_squared_error: 0.0140
# Epoch 16/1000
#  - 1s - loss: 0.0463 - mean_squared_error: 0.0036 - val_loss: 0.0918 - val_mean_squared_error: 0.0106
# Epoch 17/1000
#  - 1s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0811 - val_mean_squared_error: 0.0111
# Epoch 18/1000
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0533 - val_mean_squared_error: 0.0033
# Epoch 16/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0036 - val_loss: 0.0494 - val_mean_squared_error: 0.0029
# Epoch 17/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0036 - val_loss: 0.0507 - val_mean_squared_error: 0.0031
# predict: [[30.31236661 21.80857288]]
# real:      [[29.5 23. ]]
#
# Train on 1014 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.2863 - mean_squared_error: 5.6774 - val_loss: 0.9651 - val_mean_squared_error: 1.1420
# Epoch 2/1000
#  - 1s - loss: 0.5642 - mean_squared_error: 0.4876 - val_loss: 0.2217 - val_mean_squared_error: 0.0723
# Epoch 3/1000
#  - 1s - loss: 0.1275 - mean_squared_error: 0.0260 - val_loss: 0.0745 - val_mean_squared_error: 0.0088
# Epoch 4/1000
#  - 1s - loss: 0.0676 - mean_squared_error: 0.0071 - val_loss: 0.0805 - val_mean_squared_error: 0.0066
# Epoch 5/1000
#  - 1s - loss: 0.0540 - mean_squared_error: 0.0048 - val_loss: 0.0861 - val_mean_squared_error: 0.0074
# Epoch 6/1000
#  - 1s - loss: 0.0505 - mean_squared_error: 0.0042 - val_loss: 0.0401 - val_mean_squared_error: 0.0017
# Epoch 7/1000
#  - 1s - loss: 0.0494 - mean_squared_error: 0.0040 - val_loss: 0.0451 - val_mean_squared_error: 0.0023
# Epoch 8/1000
#  - 1s - loss: 0.0479 - mean_squared_error: 0.0038 - val_loss: 0.0690 - val_mean_squared_error: 0.0049
# Epoch 9/1000
#  - 1s - loss: 0.0475 - mean_squared_error: 0.0037 - val_loss: 0.0917 - val_mean_squared_error: 0.0085
# Epoch 10/1000
#  - 1s - loss: 0.0504 - mean_squared_error: 0.0043 - val_loss: 0.0543 - val_mean_squared_error: 0.0030
# Epoch 11/1000
#  - 1s - loss: 0.0488 - mean_squared_error: 0.0039 - val_loss: 0.0724 - val_mean_squared_error: 0.0056
# Epoch 12/1000
#  - 1s - loss: 0.0494 - mean_squared_error: 0.0041 - val_loss: 0.0544 - val_mean_squared_error: 0.0034
# Epoch 13/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0037 - val_loss: 0.0651 - val_mean_squared_error: 0.0048
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0632 - val_mean_squared_error: 0.0042
# Epoch 15/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0676 - val_mean_squared_error: 0.0047
# Epoch 16/1000
#  - 1s - loss: 0.0465 - mean_squared_error: 0.0037 - val_loss: 0.0593 - val_mean_squared_error: 0.0037
# predict: [[30.8880293  21.04130947]]
# real:      [[30.7 21.8]]
#
# Train on 1013 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.7744 - mean_squared_error: 7.8340 - val_loss: 1.9018 - val_mean_squared_error: 3.7742
# Epoch 2/1000
#  - 1s - loss: 1.4769 - mean_squared_error: 2.8151 - val_loss: 1.0288 - val_mean_squared_error: 1.4169
# Epoch 3/1000
#  - 1s - loss: 0.5549 - mean_squared_error: 0.5843 - val_loss: 0.1954 - val_mean_squared_error: 0.0533
# Epoch 4/1000
#  - 1s - loss: 0.1327 - mean_squared_error: 0.0294 - val_loss: 0.1541 - val_mean_squared_error: 0.0337
# Epoch 5/1000
#  - 1s - loss: 0.0576 - mean_squared_error: 0.0051 - val_loss: 0.1804 - val_mean_squared_error: 0.0410
# Epoch 6/1000
#  - 1s - loss: 0.0491 - mean_squared_error: 0.0039 - val_loss: 0.1605 - val_mean_squared_error: 0.0326
# Epoch 7/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0036 - val_loss: 0.1587 - val_mean_squared_error: 0.0318
# Epoch 8/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.1476 - val_mean_squared_error: 0.0267
# Epoch 9/1000
#  - 1s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.1549 - val_mean_squared_error: 0.0293
# Epoch 10/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.1530 - val_mean_squared_error: 0.0319
# Epoch 11/1000
#  - 1s - loss: 0.0478 - mean_squared_error: 0.0037 - val_loss: 0.1734 - val_mean_squared_error: 0.0403
# Epoch 12/1000
#  - 1s - loss: 0.0512 - mean_squared_error: 0.0042 - val_loss: 0.1500 - val_mean_squared_error: 0.0273
# Epoch 13/1000
#  - 1s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.1377 - val_mean_squared_error: 0.0233
# Epoch 14/1000
#  - 1s - loss: 0.0491 - mean_squared_error: 0.0039 - val_loss: 0.1484 - val_mean_squared_error: 0.0276
# Epoch 15/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.1465 - val_mean_squared_error: 0.0277
# Epoch 16/1000
#  - 1s - loss: 0.0477 - mean_squared_error: 0.0037 - val_loss: 0.1605 - val_mean_squared_error: 0.0331
# Epoch 17/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.1579 - val_mean_squared_error: 0.0363
# Epoch 18/1000
#  - 1s - loss: 0.0490 - mean_squared_error: 0.0039 - val_loss: 0.1593 - val_mean_squared_error: 0.0374
# Epoch 19/1000
#  - 1s - loss: 0.0481 - mean_squared_error: 0.0038 - val_loss: 0.1525 - val_mean_squared_error: 0.0326
# Epoch 20/1000
#  - 1s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.1308 - val_mean_squared_error: 0.0250
# Epoch 21/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0035 - val_loss: 0.1305 - val_mean_squared_error: 0.0231
# Epoch 22/1000
# ...
# Epoch 5/1000
#  - 1s - loss: 0.2966 - mean_squared_error: 0.2023 - val_loss: 0.2144 - val_mean_squared_error: 0.0603
# Epoch 6/1000
#  - 1s - loss: 0.1126 - mean_squared_error: 0.0222 - val_loss: 0.0476 - val_mean_squared_error: 0.0027
# Epoch 7/1000
#  - 1s - loss: 0.0661 - mean_squared_error: 0.0071 - val_loss: 0.0403 - val_mean_squared_error: 0.0031
# Epoch 8/1000
#  - 1s - loss: 0.0524 - mean_squared_error: 0.0044 - val_loss: 0.0567 - val_mean_squared_error: 0.0039
# Epoch 9/1000
#  - 1s - loss: 0.0489 - mean_squared_error: 0.0039 - val_loss: 0.0411 - val_mean_squared_error: 0.0025
# Epoch 10/1000
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0038 - val_loss: 0.0279 - val_mean_squared_error: 0.0013
# Epoch 11/1000
#  - 1s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0384 - val_mean_squared_error: 0.0018
# Epoch 12/1000
#  - 1s - loss: 0.0466 - mean_squared_error: 0.0036 - val_loss: 0.0299 - val_mean_squared_error: 0.0017
# Epoch 13/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0035 - val_loss: 0.0359 - val_mean_squared_error: 0.0023
# Epoch 14/1000
#  - 1s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0373 - val_mean_squared_error: 0.0016
# Epoch 15/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0356 - val_mean_squared_error: 0.0015
# Epoch 16/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0035 - val_loss: 0.0294 - val_mean_squared_error: 9.4373e-04
# Epoch 17/1000
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0036 - val_loss: 0.0321 - val_mean_squared_error: 0.0013
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0033 - val_loss: 0.0343 - val_mean_squared_error: 0.0023
# Epoch 19/1000
#  - 1s - loss: 0.0452 - mean_squared_error: 0.0034 - val_loss: 0.0377 - val_mean_squared_error: 0.0023
# Epoch 20/1000
#  - 1s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0347 - val_mean_squared_error: 0.0019
# predict: [[31.71784091 22.29387612]]
# real:      [[31.1 22.3]]
#
# Train on 1006 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.7717 - mean_squared_error: 8.2691 - val_loss: 1.7501 - val_mean_squared_error: 3.5287
# Epoch 2/1000
#  - 1s - loss: 1.1143 - mean_squared_error: 1.8599 - val_loss: 0.5265 - val_mean_squared_error: 0.3217
# Epoch 3/1000
#  - 1s - loss: 0.2585 - mean_squared_error: 0.1038 - val_loss: 0.2435 - val_mean_squared_error: 0.0607
# Epoch 4/1000
#  - 1s - loss: 0.1038 - mean_squared_error: 0.0162 - val_loss: 0.0026 - val_mean_squared_error: 7.3179e-06
# Epoch 5/1000
#  - 1s - loss: 0.0605 - mean_squared_error: 0.0061 - val_loss: 0.0261 - val_mean_squared_error: 9.4786e-04
# Epoch 6/1000
#  - 1s - loss: 0.0528 - mean_squared_error: 0.0045 - val_loss: 0.0533 - val_mean_squared_error: 0.0033
# Epoch 7/1000
#  - 1s - loss: 0.0501 - mean_squared_error: 0.0041 - val_loss: 0.0481 - val_mean_squared_error: 0.0023
# Epoch 8/1000
#  - 1s - loss: 0.0488 - mean_squared_error: 0.0039 - val_loss: 0.0431 - val_mean_squared_error: 0.0034
# Epoch 9/1000
#  - 1s - loss: 0.0483 - mean_squared_error: 0.0039 - val_loss: 0.0353 - val_mean_squared_error: 0.0015
# Epoch 10/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0377 - val_mean_squared_error: 0.0018
# Epoch 11/1000
#  - 1s - loss: 0.0468 - mean_squared_error: 0.0036 - val_loss: 0.0306 - val_mean_squared_error: 9.9940e-04
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0463 - mean_squared_error: 0.0034 - val_loss: 0.0333 - val_mean_squared_error: 0.0015
# Epoch 13/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0035 - val_loss: 0.0334 - val_mean_squared_error: 0.0013
# Epoch 14/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0034 - val_loss: 0.0323 - val_mean_squared_error: 0.0013
# predict: [[31.27234718 22.99578384]]
# real:      [[31.  22.8]]
#
# Train on 1005 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 3.1458 - mean_squared_error: 9.9869 - val_loss: 2.6432 - val_mean_squared_error: 6.9985
# Epoch 2/1000
#  - 1s - loss: 2.2280 - mean_squared_error: 5.0518 - val_loss: 1.6515 - val_mean_squared_error: 2.7286
# Epoch 3/1000
#  - 1s - loss: 1.0750 - mean_squared_error: 1.4031 - val_loss: 0.4537 - val_mean_squared_error: 0.3169
# Epoch 4/1000
#  - 1s - loss: 0.2326 - mean_squared_error: 0.0994 - val_loss: 0.1871 - val_mean_squared_error: 0.0527
# Epoch 5/1000
#  - 1s - loss: 0.0935 - mean_squared_error: 0.0137 - val_loss: 0.0330 - val_mean_squared_error: 0.0016
# Epoch 6/1000
#  - 1s - loss: 0.0560 - mean_squared_error: 0.0049 - val_loss: 0.0238 - val_mean_squared_error: 6.0435e-04
# Epoch 7/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0036 - val_loss: 0.0220 - val_mean_squared_error: 7.8035e-04
# Epoch 8/1000
#  - 1s - loss: 0.0473 - mean_squared_error: 0.0036 - val_loss: 0.0336 - val_mean_squared_error: 0.0014
# Epoch 9/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0034 - val_loss: 0.0369 - val_mean_squared_error: 0.0024
# Epoch 10/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0034 - val_loss: 0.0356 - val_mean_squared_error: 0.0022
# Epoch 11/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0286 - val_mean_squared_error: 0.0013
# Epoch 12/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0034 - val_loss: 0.0314 - val_mean_squared_error: 0.0018
# Epoch 13/1000
#  - 1s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0376 - val_mean_squared_error: 0.0020
# Epoch 14/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0034 - val_loss: 0.0388 - val_mean_squared_error: 0.0022
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 1s - loss: 0.0452 - mean_squared_error: 0.0034 - val_loss: 0.0313 - val_mean_squared_error: 0.0019
# Epoch 16/1000
#  - 1s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0285 - val_mean_squared_error: 0.0016
# Epoch 17/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0033 - val_loss: 0.0321 - val_mean_squared_error: 0.0020
# predict: [[31.42960101 22.92868991]]
# real:      [[31.5 23. ]]
#
# Train on 1004 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.4013 - mean_squared_error: 6.0573 - val_loss: 1.5920 - val_mean_squared_error: 2.5494
# Epoch 2/1000
#  - 1s - loss: 0.9403 - mean_squared_error: 1.1126 - val_loss: 0.3330 - val_mean_squared_error: 0.1358
# Epoch 3/1000
#  - 1s - loss: 0.2095 - mean_squared_error: 0.0582 - val_loss: 0.1838 - val_mean_squared_error: 0.0344
# Epoch 4/1000
#  - 1s - loss: 0.0897 - mean_squared_error: 0.0119 - val_loss: 0.0358 - val_mean_squared_error: 0.0016
# Epoch 5/1000
#  - 1s - loss: 0.0593 - mean_squared_error: 0.0055 - val_loss: 0.0201 - val_mean_squared_error: 5.5887e-04
# Epoch 6/1000
#  - 1s - loss: 0.0506 - mean_squared_error: 0.0041 - val_loss: 0.0338 - val_mean_squared_error: 0.0011
# Epoch 7/1000
#  - 1s - loss: 0.0479 - mean_squared_error: 0.0037 - val_loss: 0.0439 - val_mean_squared_error: 0.0020
# Epoch 8/1000
#  - 1s - loss: 0.0473 - mean_squared_error: 0.0037 - val_loss: 0.0394 - val_mean_squared_error: 0.0016
# Epoch 9/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0461 - val_mean_squared_error: 0.0021
# Epoch 10/1000
#  - 1s - loss: 0.0466 - mean_squared_error: 0.0035 - val_loss: 0.0358 - val_mean_squared_error: 0.0016
# Epoch 11/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0351 - val_mean_squared_error: 0.0024
# Epoch 12/1000
#  - 1s - loss: 0.0479 - mean_squared_error: 0.0038 - val_loss: 0.0422 - val_mean_squared_error: 0.0019
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 1s - loss: 0.0461 - mean_squared_error: 0.0034 - val_loss: 0.0365 - val_mean_squared_error: 0.0014
# Epoch 14/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0302 - val_mean_squared_error: 0.0010
# Epoch 15/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0034 - val_loss: 0.0367 - val_mean_squared_error: 0.0014
# predict: [[31.4926766 23.0821837]]
# real:      [[30.9 22.9]]
#
# Train on 1003 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.2340 - mean_squared_error: 5.6394 - val_loss: 1.4055 - val_mean_squared_error: 2.8578
# Epoch 2/1000
#  - 1s - loss: 1.0823 - mean_squared_error: 1.9947 - val_loss: 0.6557 - val_mean_squared_error: 0.8527
# Epoch 3/1000
#  - 1s - loss: 0.4780 - mean_squared_error: 0.4461 - val_loss: 0.0895 - val_mean_squared_error: 0.0112
# Epoch 4/1000
#  - 1s - loss: 0.1120 - mean_squared_error: 0.0202 - val_loss: 0.1192 - val_mean_squared_error: 0.0214
# Epoch 5/1000
#  - 1s - loss: 0.0649 - mean_squared_error: 0.0068 - val_loss: 0.0841 - val_mean_squared_error: 0.0074
# Epoch 6/1000
#  - 1s - loss: 0.0540 - mean_squared_error: 0.0049 - val_loss: 0.0632 - val_mean_squared_error: 0.0040
# Epoch 7/1000
#  - 1s - loss: 0.0523 - mean_squared_error: 0.0044 - val_loss: 0.0819 - val_mean_squared_error: 0.0068
# Epoch 8/1000
#  - 1s - loss: 0.0500 - mean_squared_error: 0.0041 - val_loss: 0.0884 - val_mean_squared_error: 0.0085
# Epoch 9/1000
#  - 1s - loss: 0.0485 - mean_squared_error: 0.0038 - val_loss: 0.0796 - val_mean_squared_error: 0.0067
# Epoch 10/1000
#  - 1s - loss: 0.0478 - mean_squared_error: 0.0038 - val_loss: 0.0802 - val_mean_squared_error: 0.0065
# Epoch 11/1000
#  - 1s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0845 - val_mean_squared_error: 0.0078
# Epoch 12/1000
#  - 1s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0796 - val_mean_squared_error: 0.0067
# Epoch 13/1000
#  - 1s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0783 - val_mean_squared_error: 0.0064
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 1s - loss: 0.0468 - mean_squared_error: 0.0036 - val_loss: 0.0859 - val_mean_squared_error: 0.0075
# Epoch 15/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0035 - val_loss: 0.0808 - val_mean_squared_error: 0.0067
# Epoch 16/1000
#  - 1s - loss: 0.0464 - mean_squared_error: 0.0035 - val_loss: 0.0859 - val_mean_squared_error: 0.0075
# predict: [[33.27338928 22.55860301]]
# real:      [[31.2 23.2]]
#
# Train on 1002 samples, validate on 1 samples
# Epoch 1/1000
#  - 3s - loss: 2.8747 - mean_squared_error: 8.3928 - val_loss: 2.2467 - val_mean_squared_error: 5.1165
# Epoch 2/1000
#  - 1s - loss: 1.7745 - mean_squared_error: 3.4491 - val_loss: 1.0335 - val_mean_squared_error: 1.5605
# Epoch 3/1000
#  - 0s - loss: 0.7117 - mean_squared_error: 0.8176 - val_loss: 0.3212 - val_mean_squared_error: 0.1409
# Epoch 4/1000
#  - 1s - loss: 0.1650 - mean_squared_error: 0.0447 - val_loss: 0.1769 - val_mean_squared_error: 0.0338
# Epoch 5/1000
#  - 1s - loss: 0.0864 - mean_squared_error: 0.0119 - val_loss: 0.1065 - val_mean_squared_error: 0.0123
# Epoch 6/1000
#  - 1s - loss: 0.0587 - mean_squared_error: 0.0056 - val_loss: 0.0805 - val_mean_squared_error: 0.0080
# Epoch 7/1000
#  - 1s - loss: 0.0533 - mean_squared_error: 0.0045 - val_loss: 0.0552 - val_mean_squared_error: 0.0051
# Epoch 8/1000
#  - 1s - loss: 0.0486 - mean_squared_error: 0.0038 - val_loss: 0.0654 - val_mean_squared_error: 0.0067
# Epoch 9/1000
#  - 1s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0490 - val_mean_squared_error: 0.0043
# Epoch 10/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0036 - val_loss: 0.0705 - val_mean_squared_error: 0.0088
# Epoch 11/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0690 - val_mean_squared_error: 0.0085
# Epoch 12/1000
#  - 1s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0553 - val_mean_squared_error: 0.0055
# Epoch 13/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0035 - val_loss: 0.0798 - val_mean_squared_error: 0.0106
# Epoch 14/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0689 - val_mean_squared_error: 0.0080
# Epoch 15/1000
#  - 1s - loss: 0.0456 - mean_squared_error: 0.0034 - val_loss: 0.0591 - val_mean_squared_error: 0.0061
# Epoch 16/1000
#  - 1s - loss: 0.0457 - mean_squared_error: 0.0034 - val_loss: 0.0724 - val_mean_squared_error: 0.0090
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0674 - val_mean_squared_error: 0.0081
# Epoch 18/1000
#  - 1s - loss: 0.0449 - mean_squared_error: 0.0033 - val_loss: 0.0689 - val_mean_squared_error: 0.0085
# Epoch 19/1000
#  - 1s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0657 - val_mean_squared_error: 0.0081
# predict: [[29.63356344 22.772031  ]]
# real:      [[31.  21.1]]
#
# Train on 1001 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.7839 - mean_squared_error: 7.9516 - val_loss: 2.0029 - val_mean_squared_error: 4.0696
# Epoch 2/1000
#  - 1s - loss: 1.3250 - mean_squared_error: 2.1273 - val_loss: 0.4660 - val_mean_squared_error: 0.3819
# Epoch 3/1000
#  - 1s - loss: 0.3890 - mean_squared_error: 0.2072 - val_loss: 0.1808 - val_mean_squared_error: 0.0329
# Epoch 4/1000
#  - 1s - loss: 0.1092 - mean_squared_error: 0.0186 - val_loss: 0.0970 - val_mean_squared_error: 0.0144
# Epoch 5/1000
#  - 1s - loss: 0.0643 - mean_squared_error: 0.0067 - val_loss: 0.0490 - val_mean_squared_error: 0.0034
# Epoch 6/1000
#  - 1s - loss: 0.0512 - mean_squared_error: 0.0043 - val_loss: 0.0339 - val_mean_squared_error: 0.0016
# Epoch 7/1000
#  - 1s - loss: 0.0493 - mean_squared_error: 0.0040 - val_loss: 0.0380 - val_mean_squared_error: 0.0023
# Epoch 8/1000
#  - 1s - loss: 0.0487 - mean_squared_error: 0.0039 - val_loss: 0.0490 - val_mean_squared_error: 0.0025
# Epoch 9/1000
#  - 1s - loss: 0.0487 - mean_squared_error: 0.0039 - val_loss: 0.0419 - val_mean_squared_error: 0.0034
# Epoch 10/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0435 - val_mean_squared_error: 0.0027
# Epoch 11/1000
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0037 - val_loss: 0.0503 - val_mean_squared_error: 0.0031
# Epoch 12/1000
#  - 1s - loss: 0.0475 - mean_squared_error: 0.0037 - val_loss: 0.0421 - val_mean_squared_error: 0.0032
# Epoch 13/1000
#  - 1s - loss: 0.0465 - mean_squared_error: 0.0035 - val_loss: 0.0439 - val_mean_squared_error: 0.0032
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0034 - val_loss: 0.0412 - val_mean_squared_error: 0.0032
# Epoch 15/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0404 - val_mean_squared_error: 0.0031
# Epoch 16/1000
#  - 1s - loss: 0.0459 - mean_squared_error: 0.0034 - val_loss: 0.0415 - val_mean_squared_error: 0.0032
# predict: [[31.35698015 22.23118169]]
# real:      [[28.7 22.8]]
#
# Train on 1000 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.8486 - mean_squared_error: 9.1328 - val_loss: 1.7788 - val_mean_squared_error: 3.2637
# Epoch 2/1000
#  - 0s - loss: 0.9873 - mean_squared_error: 1.2641 - val_loss: 0.0097 - val_mean_squared_error: 1.0193e-04
# Epoch 3/1000
#  - 0s - loss: 0.1759 - mean_squared_error: 0.0425 - val_loss: 0.0488 - val_mean_squared_error: 0.0024
# Epoch 4/1000
#  - 0s - loss: 0.0964 - mean_squared_error: 0.0131 - val_loss: 0.0951 - val_mean_squared_error: 0.0090
# Epoch 5/1000
#  - 0s - loss: 0.0591 - mean_squared_error: 0.0055 - val_loss: 0.0518 - val_mean_squared_error: 0.0028
# Epoch 6/1000
#  - 0s - loss: 0.0491 - mean_squared_error: 0.0040 - val_loss: 0.0312 - val_mean_squared_error: 0.0010
# Epoch 7/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0206 - val_mean_squared_error: 4.2723e-04
# Epoch 8/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0036 - val_loss: 0.0271 - val_mean_squared_error: 7.3584e-04
# Epoch 9/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0482 - val_mean_squared_error: 0.0024
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/1000
#  - 0s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0364 - val_mean_squared_error: 0.0014
# Epoch 11/1000
#  - 1s - loss: 0.0458 - mean_squared_error: 0.0034 - val_loss: 0.0366 - val_mean_squared_error: 0.0014
# Epoch 12/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0393 - val_mean_squared_error: 0.0016
# predict: [[31.95079482 21.76798184]]
# real:      [[30.1 22.9]]

# %%
y_hats = result[0]
y_tests = result[1]

metrics(y_hats, y_tests)
# Out:
# Maximum metrics
# Test RMSE -------------------------- 1.756
# Test VARIANCE ---------------------- -0.5759
# Test MAX-ERROR --------------------- 5.208
# Test MEAN-ABSOLUTE-ERROR ----------- 1.182
# Test MEDIAN-ABSOLUTE-ERROR --------- 0.6211
#
# Accuracy
# 66.67% of predictions missed 1 point(s) or less
# 10.0% of predictions missed 2 point(s) or less
# 13.33% of predictions missed 3 point(s) or less
# 3.33% of predictions missed 4 point(s) or less
# 3.33% of predictions missed 5 point(s) or less
# 3.33% of predictions missed 6 point(s) or less
#
# Minimum metrics
# Test RMSE -------------------------- 0.8502
# Test VARIANCE ---------------------- -0.209
# Test MAX-ERROR --------------------- 1.826
# Test MEAN-ABSOLUTE-ERROR ----------- 0.6822
# Test MEDIAN-ABSOLUTE-ERROR --------- 0.5743
#
# Accuracy
# 76.67% of predictions missed 1 point(s) or less
# 23.33% of predictions missed 2 point(s) or less
