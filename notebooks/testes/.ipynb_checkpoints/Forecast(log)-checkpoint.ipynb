# %%
# imports required for the algorithm
import os

from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from datetime import datetime
from math import sqrt
import numpy as np

from matplotlib import pyplot

from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# path to load and save data
data_input_path = '../../data_in/CE_Crateus.csv'
data_output_path = '../../data_out/weather.csv'
data_output_path_npsave = '../../data_out/weather.npy'

# %%
# transform date into appropriate format
def parse(x):
	return datetime.strptime(x, '%d/%m/%Y')

# %%
# load the input dataset and save like a output dataset
def format_dataset(data_input_path, output_path):
    try:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1')
    except:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1', skiprows=2)
    
    dataset.index.name = 'date'

    dataset.drop('Unnamed: 11', axis=1, inplace=True)
    dataset.drop('Estacao', axis=1, inplace=True)
    
    dataset['TempMinima'] = dataset['TempMinima'].shift(-1)
    dataset['Precipitacao'] = dataset['Precipitacao'].shift(-1)
    
    dataset.drop('Hora', axis=1, inplace=True)
    
    dataset = dataset.loc[~dataset.index.duplicated(keep='first')]
    
    # replaces first line NA values with next line value
    dataset.iloc[0,:].fillna(dataset.iloc[1,:], inplace=True)
    
    # replace all NA values with prev line value
    dataset.ffill(axis=0, inplace=True)

    # show the first 5 lines on the dataset
    print(dataset)
        
    # save file
    dataset.to_csv(output_path)

format_dataset(data_input_path, data_output_path)
# Out:
#             Precipitacao  TempMaxima  TempMinima  Insolacao  Evaporacao Piche  \
# date
# 2015-01-01           0.0        35.0        23.7        5.9              10.2
# 2015-01-02           0.0        35.8        23.0       10.6              10.2
# 2015-01-03          37.4        31.9        22.3        4.3               6.2
# 2015-01-04          12.4        27.3        20.7        1.9               3.5
# 2015-01-05          23.0        32.4        20.7        8.3               1.5
# ...                  ...         ...         ...        ...               ...
# 2018-04-26           0.0        31.0        20.8        8.9               0.5
# 2018-04-27           0.0        31.7        22.9       10.5               0.5
# 2018-04-28           0.0        31.3        21.5        9.5               0.5
# 2018-04-29           3.5        28.9        22.7        2.5               0.5
# 2018-04-30           0.4        28.9        21.9        2.5               0.5
#
#             Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media
# date
# 2015-01-01            28.76                   47.00                   2.633333
# 2015-01-02            26.72                   72.50                   1.866667
# 2015-01-03            26.32                   71.50                   1.600000
# 2015-01-04            23.50                   88.25                   2.266667
# 2015-01-05            26.64                   66.75                   3.166667
# ...                     ...                     ...                        ...
# 2018-04-26            25.66                   78.00                   1.286100
# 2018-04-27            26.26                   77.00                   1.800540
# 2018-04-28            26.38                   81.00                   1.028880
# 2018-04-29            24.64                   93.00                   1.543320
# 2018-04-30            24.64                   93.00                   2.057760
#
# [1091 rows x 8 columns]

# %%
# load dataset
def load_dataset(input_path):
    return read_csv(input_path, header=0, index_col=0)

dataset = load_dataset(data_output_path)
values = dataset.values

# %%
# plot each column in a graph
def plot_columns(values):
    groups = list(range(0,len(values[0])))
    i = 1
    
    pyplot.figure(dpi=120)
    for group in groups:
        pyplot.subplot(len(groups), 1, i)
        pyplot.plot(values[:, group])
        pyplot.title(dataset.columns[group], y=0.1, loc='right')
        i += 1
    pyplot.show()

plot_columns(values)

# %%
# convert series to supervised learning
def series_to_supervised(dataset, day):
    y_test = np.array([dataset.loc[day]['TempMaxima'], dataset.loc[day]['TempMinima']])
    y_test = y_test.reshape(1,2)
    
    dataset = dataset[:-1]
    
    x_test = np.array(dataset[-60:])
    x_test = x_test.reshape(1,60,8)
    
    lista = []
    
    for i in list(dataset.index):
        lista.append([dataset.loc[i]['TempMaxima'], dataset.loc[i]['TempMinima']])
    y_train = np.array(lista[60:])
    
    dataset = dataset[:-1]
    
    x_train = np.array(dataset[-60:])
    x_train = x_train.reshape(1,60,8)
    dataset = dataset[:-1]
    
    while len(dataset) >= 60:
        array_aux = np.array(dataset[-60:])
        array_aux = array_aux.reshape(1,60,8)
        x_train = np.concatenate((x_train, array_aux), axis=0)
        dataset = dataset[:-1]
    
    return (x_train, y_train, x_test, y_test)

# %%
# inner loop
def myLSTM(x_train, y_train, x_test, y_test, scaler):
    x_val = x_train[-1]
    y_val = y_train[-1]
    x_val = x_val.reshape(1,60,8)
    y_val = y_val.reshape(1,2)
    x_train = x_train[:-1]
    y_train = y_train[:-1]
    
    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dense(16, activation='relu'))   # worth it?
    model.add(Dense(2))
    model.compile(loss='mae', optimizer='adam', metrics=['mse'])
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')
    ]
    
    # fit network
    history = model.fit(x_train, y_train,
                        epochs=1000, 
                        batch_size=72, 
                        validation_data=(x_val, y_val), 
                        verbose=2, 
                        shuffle=True, 
                        callbacks=callbacks)
    
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()
    
    y = inverseScale(model, x_test, y_test, scaler)
    inv_y_hat = y[0]
    inv_y_test = y[1]
    
    print('\npredict: {}'.format(inv_y_hat))
    print('real:      {}\n'.format(inv_y_test))
    
    return model

# %%
def inverseScale(model, x_test, y_test, scaler):
    # make a prediction
    y_hat = model.predict(x_test)
    
    new_x_test = x_test[:,-1,:]
    new_x_test = new_x_test.reshape((x_test.shape[0], x_test.shape[2]))
    new_x_test = np.concatenate((new_x_test[:, 0:1], new_x_test[:, 3:]), axis=1)
    
    # invert scaling for forecast
    inv_y_hat = np.concatenate((y_hat, new_x_test), axis=1)
    inv_y_hat = np.expm1(inv_y_hat)
    inv_y_hat = inv_y_hat[:,:2]
    
    # invert scaling for actual value
    new_test_y = y_test.reshape((len(y_test), 2))
    inv_y_test = np.concatenate((new_test_y, new_x_test), axis=1)
    inv_y_test = np.expm1(inv_y_test)
    inv_y_test = inv_y_test[:,:2]
    
    return [inv_y_hat, inv_y_test]

# %%
# calculate metrics
def metrics(model, x_test, y_test, scaler):
    y = inverseScale(model, x_test, y_test, scaler)
    inv_y_hat = y[0]
    inv_y_test = y[1]
    
    rmse = sqrt(mean_squared_error(inv_y_test, inv_y_hat))
    variance = explained_variance_score(inv_y_test, inv_y_hat)
    maxError = np.abs(inv_y_test - inv_y_hat)
    meanAbsolutError = mean_absolute_error(inv_y_test, inv_y_hat)
    medianAbsoluteError = np.abs(inv_y_test - inv_y_hat)
    
    return [rmse, variance, maxError, meanAbsolutError, medianAbsoluteError]

# %%
# Nested Cross Validation
def NCV(dataset, days_to_predict, scaler=None):
    metrics_list = []
    rmse = []
    variance = []
    maxError = []
    meanAbsolutError = []
    medianAbsoluteError = []
    i = len(days_to_predict) - 1
    
    # outer loop
    while(i >= 0):
        data = series_to_supervised(dataset, days_to_predict[i])
        x_train = data[0]
        y_train = data[1]
        x_test = data[2]
        y_test = data[3]
        
        model = myLSTM(x_train, y_train, x_test, y_test, scaler)    
        metrics_list += metrics(model, x_test, y_test, scaler)
        
        rmse += [metrics_list[0]]
        variance += [metrics_list[1]]
        maxError += [metrics_list[2]]
        meanAbsolutError += [metrics_list[3]]
        medianAbsoluteError += [metrics_list[4]]
        
        i -= 1
        dataset = dataset[:-1]
        
    print('Test RMSE -------------------------- {:.4}'.format(np.mean(rmse)))
    print('Test VARIANCE ---------------------- {:.4}'.format(np.mean(variance)))
    print('Test MAX-ERROR --------------------- {:.4}'.format(np.max(maxError)))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(np.mean(meanAbsolutError)))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(np.median((medianAbsoluteError))))

# %%
# to get index the last 30 days
days_to_predict = list(dataset.index[-30:])

values_scaled = np.log1p(values)
dataset_scaled = DataFrame(values_scaled)
dataset_scaled.index = dataset.index
dataset_scaled.columns = dataset.columns

plot_columns(values_scaled)

NCV(dataset_scaled, days_to_predict)
# Out:
# Train on 1029 samples, validate on 1 samples
# Epoch 1/1000
#  - 0s - loss: 3.4481 - mean_squared_error: 11.9874 - val_loss: 3.0049 - val_mean_squared_error: 9.0332
# Epoch 2/1000
#  - 0s - loss: 2.8731 - mean_squared_error: 8.2951 - val_loss: 2.4873 - val_mean_squared_error: 6.2769
# Epoch 3/1000
#  - 0s - loss: 2.1558 - mean_squared_error: 4.7751 - val_loss: 1.4207 - val_mean_squared_error: 2.0932
# Epoch 4/1000
#  - 0s - loss: 0.7330 - mean_squared_error: 0.7833 - val_loss: 0.2942 - val_mean_squared_error: 0.0943
# Epoch 5/1000
#  - 0s - loss: 0.1383 - mean_squared_error: 0.0269 - val_loss: 0.1119 - val_mean_squared_error: 0.0209
# Epoch 6/1000
#  - 0s - loss: 0.0621 - mean_squared_error: 0.0061 - val_loss: 0.0966 - val_mean_squared_error: 0.0144
# Epoch 7/1000
#  - 0s - loss: 0.0491 - mean_squared_error: 0.0040 - val_loss: 0.0817 - val_mean_squared_error: 0.0103
samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.3459 - mean_squared_error: 5.8627 - val_loss: 1.3424 - val_mean_squared_error: 1.9699
# Epoch 2/1000
#  - 0s - loss: 0.7711 - mean_squared_error: 0.8326 - val_loss: 0.4127 - val_mean_squared_error: 0.1813
# Epoch 3/1000
#  - 0s - loss: 0.2118 - mean_squared_error: 0.0747 - val_loss: 0.1019 - val_mean_squared_error: 0.0165
# Epoch 4/1000
#  - 0s - loss: 0.0855 - mean_squared_error: 0.0125 - val_loss: 0.0364 - val_mean_squared_error: 0.0013
# Epoch 5/1000
#  - 0s - loss: 0.0571 - mean_squared_error: 0.0053 - val_loss: 0.0254 - val_mean_squared_error: 9.9870e-04
# Epoch 6/1000
#  - 0s - loss: 0.0486 - mean_squared_error: 0.0039 - val_loss: 0.0477 - val_mean_squared_error: 0.0023
# Epoch 7/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0039 - val_loss: 0.0590 - val_mean_squared_error: 0.0035
# Epoch 8/1000
#  - 0s - loss: 0.0470 - mean_squared_error: 0.0037 - val_loss: 0.0250 - val_mean_squared_error: 6.5670e-04
# Epoch 9/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0036 - val_loss: 0.0620 - val_mean_squared_error: 0.0038
# Epoch 10/1000
#  - 0s - loss: 0.0483 - mean_squared_error: 0.0039 - val_loss: 0.0541 - val_mean_squared_error: 0.0029
# Epoch 11/1000
#  - 0s - loss: 0.0457 - mean_squared_error: 0.0035 - val_loss: 0.0499 - val_mean_squared_error: 0.0025
# Epoch 12/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0565 - val_mean_squared_error: 0.0032
# Epoch 13/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0036 - val_loss: 0.0517 - val_mean_squared_error: 0.0027
# Epoch 14/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0518 - val_mean_squared_error: 0.0027
# Epoch 15/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0039 - val_loss: 0.0400 - val_mean_squared_error: 0.0016
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 0s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0533 - val_mean_squared_error: 0.0028
# Epoch 17/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0035 - val_loss: 0.0472 - val_mean_squared_error: 0.0022
# Epoch 18/1000
#  - 0s - loss: 0.0452 - mean_squared_error: 0.0034 - val_loss: 0.0517 - val_mean_squared_error: 0.0027
# predict: [[31.7310733  21.46107347]]
# real:      [[28.9 22.7]]
#
# Train on 1027 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.7574 - mean_squared_error: 7.7542 - val_loss: 2.1007 - val_mean_squared_error: 4.4140
# Epoch 2/1000
#  - 0s - loss: 1.5432 - mean_squared_error: 2.5473 - val_loss: 0.7187 - val_mean_squared_error: 0.5442
# Epoch 3/1000
#  - 0s - loss: 0.3017 - mean_squared_error: 0.1561 - val_loss: 0.2740 - val_mean_squared_error: 0.1010
# Epoch 4/1000
#  - 0s - loss: 0.1232 - mean_squared_error: 0.0263 - val_loss: 0.0607 - val_mean_squared_error: 0.0068
# Epoch 5/1000
#  - 0s - loss: 0.0648 - mean_squared_error: 0.0068 - val_loss: 0.0381 - val_mean_squared_error: 0.0021
# Epoch 6/1000
#  - 0s - loss: 0.0520 - mean_squared_error: 0.0045 - val_loss: 0.0271 - val_mean_squared_error: 7.5392e-04
# Epoch 7/1000
#  - 0s - loss: 0.0492 - mean_squared_error: 0.0040 - val_loss: 0.0453 - val_mean_squared_error: 0.0021
# Epoch 8/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0037 - val_loss: 0.0286 - val_mean_squared_error: 8.3776e-04
# Epoch 9/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0036 - val_loss: 0.0315 - val_mean_squared_error: 9.9649e-04
# Epoch 10/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0224 - val_mean_squared_error: 5.4164e-04
# Epoch 11/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0525 - val_mean_squared_error: 0.0029
# Epoch 12/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0066 - val_mean_squared_error: 5.8851e-05
# Epoch 13/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0152 - val_mean_squared_error: 2.3273e-04
# Epoch 14/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0036 - val_loss: 0.0321 - val_mean_squared_error: 0.0011
# Epoch 15/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0130 - val_mean_squared_error: 2.9420e-04
# Epoch 16/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0036 - val_loss: 0.0222 - val_mean_squared_error: 6.6771e-04
# Epoch 17/1000
#  - 0s - loss: 0.0485 - mean_squared_error: 0.0039 - val_loss: 0.0301 - val_mean_squared_error: 9.3992e-04
# Epoch 18/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0036 - val_loss: 0.0401 - val_mean_squared_error: 0.0016
# Epoch 19/1000
#  - 0s - loss: 0.0458 - mean_squared_error: 0.0035 - val_loss: 0.0259 - val_mean_squared_error: 7.2504e-04
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 20/1000
#  - 0s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0170 - val_mean_squared_error: 3.3786e-04
# Epoch 21/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0219 - val_mean_squared_error: 4.9587e-04
# Epoch 22/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0213 - val_mean_squared_error: 5.1132e-04
# predict: [[30.36623131 23.14762955]]
# real:      [[31.3 21.5]]
#
# Train on 1026 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 3.5422 - mean_squared_error: 12.6356 - val_loss: 3.1374 - val_mean_squared_error: 9.8437
# Epoch 2/1000
#  - 0s - loss: 2.9953 - mean_squared_error: 9.0401 - val_loss: 2.6106 - val_mean_squared_error: 6.9645
# Epoch 3/1000
#  - 0s - loss: 2.4055 - mean_squared_error: 6.1606 - val_loss: 1.9326 - val_mean_squared_error: 4.3609
# Epoch 4/1000
#  - 0s - loss: 1.6051 - mean_squared_error: 3.6314 - val_loss: 1.1813 - val_mean_squared_error: 2.3775
# Epoch 5/1000
#  - 0s - loss: 0.9603 - mean_squared_error: 1.7073 - val_loss: 0.6386 - val_mean_squared_error: 0.7495
# Epoch 6/1000
#  - 0s - loss: 0.4887 - mean_squared_error: 0.4606 - val_loss: 0.2037 - val_mean_squared_error: 0.0636
# Epoch 7/1000
#  - 0s - loss: 0.1162 - mean_squared_error: 0.0274 - val_loss: 0.1539 - val_mean_squared_error: 0.0292
# Epoch 8/1000
#  - 0s - loss: 0.0671 - mean_squared_error: 0.0075 - val_loss: 0.0477 - val_mean_squared_error: 0.0027
# Epoch 9/1000
#  - 0s - loss: 0.0504 - mean_squared_error: 0.0041 - val_loss: 0.0835 - val_mean_squared_error: 0.0071
# Epoch 10/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0035 - val_loss: 0.0832 - val_mean_squared_error: 0.0070
# Epoch 11/1000
#  - 0s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0776 - val_mean_squared_error: 0.0061
# Epoch 12/1000
#  - 0s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0763 - val_mean_squared_error: 0.0060
# Epoch 13/1000
#  - 0s - loss: 0.0452 - mean_squared_error: 0.0034 - val_loss: 0.0760 - val_mean_squared_error: 0.0058
# Epoch 14/1000
#  - 0s - loss: 0.0448 - mean_squared_error: 0.0033 - val_loss: 0.0752 - val_mean_squared_error: 0.0057
# Epoch 15/1000
#  - 0s - loss: 0.0445 - mean_squared_error: 0.0033 - val_loss: 0.0713 - val_mean_squared_error: 0.0053
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 0s - loss: 0.0436 - mean_squared_error: 0.0032 - val_loss: 0.0682 - val_mean_squared_error: 0.0050
# Epoch 17/1000
#  - 0s - loss: 0.0434 - mean_squared_error: 0.0032 - val_loss: 0.0691 - val_mean_squared_error: 0.0051
# Epoch 18/1000
#  - 0s - loss: 0.0432 - mean_squared_error: 0.0031 - val_loss: 0.0693 - val_mean_squared_error: 0.0050
# predict: [[33.29312075 21.36629529]]
# real:      [[31.7 22.9]]
#
# Train on 1025 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.8147 - mean_squared_error: 8.1034 - val_loss: 2.0925 - val_mean_squared_error: 4.5077
# Epoch 2/1000
#  - 0s - loss: 1.6039 - mean_squared_error: 2.8894 - val_loss: 0.7285 - val_mean_squared_error: 0.7685
# Epoch 3/1000
#  - 0s - loss: 0.3479 - mean_squared_error: 0.2664 - val_loss: 0.2934 - val_mean_squared_error: 0.1015
# Epoch 4/1000
#  - 0s - loss: 0.1205 - mean_squared_error: 0.0216 - val_loss: 0.0414 - val_mean_squared_error: 0.0032
# Epoch 5/1000
#  - 0s - loss: 0.0643 - mean_squared_error: 0.0065 - val_loss: 0.0474 - val_mean_squared_error: 0.0023
# Epoch 6/1000
#  - 0s - loss: 0.0555 - mean_squared_error: 0.0050 - val_loss: 0.0704 - val_mean_squared_error: 0.0053
# Epoch 7/1000
#  - 0s - loss: 0.0509 - mean_squared_error: 0.0042 - val_loss: 0.0853 - val_mean_squared_error: 0.0077
# Epoch 8/1000
#  - 0s - loss: 0.0479 - mean_squared_error: 0.0038 - val_loss: 0.0782 - val_mean_squared_error: 0.0062
# Epoch 9/1000
#  - 0s - loss: 0.0470 - mean_squared_error: 0.0037 - val_loss: 0.0820 - val_mean_squared_error: 0.0069
# Epoch 10/1000
#  - 0s - loss: 0.0469 - mean_squared_error: 0.0036 - val_loss: 0.0794 - val_mean_squared_error: 0.0067
# Epoch 11/1000
#  - 0s - loss: 0.0469 - mean_squared_error: 0.0036 - val_loss: 0.0613 - val_mean_squared_error: 0.0038
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0034 - val_loss: 0.0805 - val_mean_squared_error: 0.0065
# Epoch 13/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0034 - val_loss: 0.0794 - val_mean_squared_error: 0.0064
# Epoch 14/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0034 - val_loss: 0.0780 - val_mean_squared_error: 0.0061
# predict: [[33.29505036 20.19078582]]
# real:      [[31.  20.8]]
#
# Train on 1024 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.5921 - mean_squared_error: 8.0977 - val_loss: 1.3742 - val_mean_squared_error: 2.4420
# Epoch 2/1000
#  - 0s - loss: 0.9311 - mean_squared_error: 1.4500 - val_loss: 0.3588 - val_mean_squared_error: 0.2382
# Epoch 3/1000
#  - 0s - loss: 0.2024 - mean_squared_error: 0.0820 - val_loss: 0.1763 - val_mean_squared_error: 0.0550
# Epoch 4/1000
#  - 0s - loss: 0.0905 - mean_squared_error: 0.0134 - val_loss: 0.0564 - val_mean_squared_error: 0.0040
# Epoch 5/1000
#  - 0s - loss: 0.0574 - mean_squared_error: 0.0056 - val_loss: 0.0489 - val_mean_squared_error: 0.0024
# Epoch 6/1000
#  - 0s - loss: 0.0505 - mean_squared_error: 0.0042 - val_loss: 0.0574 - val_mean_squared_error: 0.0036
# Epoch 7/1000
#  - 0s - loss: 0.0484 - mean_squared_error: 0.0039 - val_loss: 0.0646 - val_mean_squared_error: 0.0047
# Epoch 8/1000
#  - 0s - loss: 0.0479 - mean_squared_error: 0.0038 - val_loss: 0.0534 - val_mean_squared_error: 0.0033
# Epoch 9/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0730 - val_mean_squared_error: 0.0058
# Epoch 10/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0737 - val_mean_squared_error: 0.0060
# Epoch 11/1000
#  - 0s - loss: 0.0468 - mean_squared_error: 0.0037 - val_loss: 0.0562 - val_mean_squared_error: 0.0033
# Epoch 12/1000
#  - 0s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0613 - val_mean_squared_error: 0.0039
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 0s - loss: 0.0458 - mean_squared_error: 0.0035 - val_loss: 0.0610 - val_mean_squared_error: 0.0039
# Epoch 14/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0606 - val_mean_squared_error: 0.0039
# Epoch 15/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0555 - val_mean_squared_error: 0.0033
# predict: [[33.048964   21.87083566]]
# real:      [[30.7 21. ]]
#
# Train on 1023 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.7538 - mean_squared_error: 8.3101 - val_loss: 2.0320 - val_mean_squared_error: 6.4757
# Epoch 2/1000
#  - 0s - loss: 1.8761 - mean_squared_error: 6.3045 - val_loss: 1.6484 - val_mean_squared_error: 5.1634
# Epoch 3/1000
#  - 0s - loss: 1.5523 - mean_squared_error: 4.5338 - val_loss: 1.2863 - val_mean_squared_error: 3.2503
# Epoch 4/1000
#  - 0s - loss: 1.0912 - mean_squared_error: 2.2915 - val_loss: 0.8166 - val_mean_squared_error: 1.1673
# Epoch 5/1000
#  - 0s - loss: 0.5133 - mean_squared_error: 0.5417 - val_loss: 0.1551 - val_mean_squared_error: 0.0258
# Epoch 6/1000
#  - 0s - loss: 0.0986 - mean_squared_error: 0.0165 - val_loss: 0.0582 - val_mean_squared_error: 0.0035
# Epoch 7/1000
#  - 0s - loss: 0.0646 - mean_squared_error: 0.0067 - val_loss: 0.0652 - val_mean_squared_error: 0.0043
# Epoch 8/1000
#  - 0s - loss: 0.0500 - mean_squared_error: 0.0041 - val_loss: 0.0515 - val_mean_squared_error: 0.0033
# Epoch 9/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0039 - val_loss: 0.0384 - val_mean_squared_error: 0.0027
# Epoch 10/1000
#  - 0s - loss: 0.0462 - mean_squared_error: 0.0036 - val_loss: 0.0287 - val_mean_squared_error: 0.0016
# Epoch 11/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0324 - val_mean_squared_error: 0.0020
# Epoch 12/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0392 - val_mean_squared_error: 0.0031
# Epoch 13/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0037 - val_loss: 0.0630 - val_mean_squared_error: 0.0059
# Epoch 14/1000
#  - 0s - loss: 0.0471 - mean_squared_error: 0.0037 - val_loss: 0.0747 - val_mean_squared_error: 0.0070
# Epoch 15/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0581 - val_mean_squared_error: 0.0040
# Epoch 16/1000
#  - 0s - loss: 0.0457 - mean_squared_error: 0.0035 - val_loss: 0.0243 - val_mean_squared_error: 9.1492e-04
# Epoch 17/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0525 - val_mean_squared_error: 0.0037
# Epoch 18/1000
#  - 0s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.0434 - val_mean_squared_error: 0.0029
# Epoch 19/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0034 - val_loss: 0.0583 - val_mean_squared_error: 0.0048
# Epoch 20/1000
#  - 0s - loss: 0.0450 - mean_squared_error: 0.0034 - val_loss: 0.0609 - val_mean_squared_error: 0.0058
# Epoch 21/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0037 - val_loss: 0.0537 - val_mean_squared_error: 0.0041
# Epoch 22/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0446 - val_mean_squared_error: 0.0036
# Epoch 23/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0369 - val_mean_squared_error: 0.0025
#
# Epoch 00023: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch
# Epoch 17/1000
#  - 0s - loss: 0.0460 - mean_squared_error: 0.0034 - val_loss: 0.0542 - val_mean_squared_error: 0.0057
# Epoch 18/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0035 - val_loss: 0.0474 - val_mean_squared_error: 0.0026
# Epoch 19/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0463 - val_mean_squared_error: 0.0025
# Epoch 20/1000
#  - 0s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0456 - val_mean_squared_error: 0.0029
# Epoch 21/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0431 - val_mean_squared_error: 0.0028
# Epoch 22/1000
#  - 0s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0431 - val_mean_squared_error: 0.0031
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 23/1000
#  - 0s - loss: 0.0442 - mean_squared_error: 0.0032 - val_loss: 0.0502 - val_mean_squared_error: 0.0041
# Epoch 24/1000
#  - 0s - loss: 0.0442 - mean_squared_error: 0.0032 - val_loss: 0.0482 - val_mean_squared_error: 0.0038
# Epoch 25/1000
#  - 0s - loss: 0.0445 - mean_squared_error: 0.0033 - val_loss: 0.0487 - val_mean_squared_error: 0.0035
# predict: [[30.72710745 22.63030375]]
# real:      [[30.3 22.3]]
#
# Train on 1021 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.3988 - mean_squared_error: 6.1648 - val_loss: 1.2130 - val_mean_squared_error: 1.4714
# Epoch 2/1000
#  - 0s - loss: 0.5437 - mean_squared_error: 0.4470 - val_loss: 0.3444 - val_mean_squared_error: 0.1197
# Epoch 3/1000
#  - 0s - loss: 0.1671 - mean_squared_error: 0.0393 - val_loss: 0.1231 - val_mean_squared_error: 0.0153
# Epoch 4/1000
#  - 0s - loss: 0.0756 - mean_squared_error: 0.0094 - val_loss: 0.0692 - val_mean_squared_error: 0.0049
# Epoch 5/1000
#  - 0s - loss: 0.0554 - mean_squared_error: 0.0051 - val_loss: 0.0396 - val_mean_squared_error: 0.0023
# Epoch 6/1000
#  - 0s - loss: 0.0484 - mean_squared_error: 0.0039 - val_loss: 0.0427 - val_mean_squared_error: 0.0025
# Epoch 7/1000
#  - 0s - loss: 0.0461 - mean_squared_error: 0.0036 - val_loss: 0.0503 - val_mean_squared_error: 0.0026
# Epoch 8/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0036 - val_loss: 0.0404 - val_mean_squared_error: 0.0017
# Epoch 9/1000
#  - 0s - loss: 0.0458 - mean_squared_error: 0.0035 - val_loss: 0.0371 - val_mean_squared_error: 0.0021
# Epoch 10/1000
#  - 0s - loss: 0.0452 - mean_squared_error: 0.0035 - val_loss: 0.0438 - val_mean_squared_error: 0.0025
# Epoch 11/1000
#  - 0s - loss: 0.0455 - mean_squared_error: 0.0034 - val_loss: 0.0385 - val_mean_squared_error: 0.0018
# Epoch 12/1000
#  - 0s - loss: 0.0448 - mean_squared_error: 0.0034 - val_loss: 0.0290 - val_mean_squared_error: 0.0010
# Epoch 13/1000
# Epoch 17/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0515 - val_mean_squared_error: 0.0033
# Epoch 18/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0332 - val_mean_squared_error: 0.0013
# Epoch 19/1000
#  - 0s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0260 - val_mean_squared_error: 0.0013
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 20/1000
#  - 0s - loss: 0.0456 - mean_squared_error: 0.0034 - val_loss: 0.0281 - val_mean_squared_error: 0.0014
# Epoch 21/1000
#  - 0s - loss: 0.0456 - mean_squared_error: 0.0034 - val_loss: 0.0280 - val_mean_squared_error: 0.0016
# Epoch 22/1000
#  - 0s - loss: 0.0454 - mean_squared_error: 0.0034 - val_loss: 0.0284 - val_mean_squared_error: 0.0014
# predict: [[31.13326501 22.01562305]]
# real:      [[31.1 22.3]]
#
# Train on 1018 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 3.1283 - mean_squared_error: 9.9100 - val_loss: 2.5109 - val_mean_squared_error: 6.3410
# Epoch 2/1000
#  - 0s - loss: 2.2048 - mean_squared_error: 5.0250 - val_loss: 1.5307 - val_mean_squared_error: 2.5020
# Epoch 3/1000
#  - 0s - loss: 0.9724 - mean_squared_error: 1.3280 - val_loss: 0.3968 - val_mean_squared_error: 0.1687
# Epoch 4/1000
#  - 0s - loss: 0.2243 - mean_squared_error: 0.0749 - val_loss: 0.1337 - val_mean_squared_error: 0.0238
# Epoch 5/1000
#  - 0s - loss: 0.0996 - mean_squared_error: 0.0175 - val_loss: 0.0614 - val_mean_squared_error: 0.0040
# Epoch 6/1000
#  - 0s - loss: 0.0540 - mean_squared_error: 0.0047 - val_loss: 0.0288 - val_mean_squared_error: 0.0014
# Epoch 7/1000
#  - 0s - loss: 0.0478 - mean_squared_error: 0.0037 - val_loss: 0.0645 - val_mean_squared_error: 0.0051
# Epoch 8/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0038 - val_loss: 0.0400 - val_mean_squared_error: 0.0018
# Epoch 9/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0384 - val_mean_squared_error: 0.0015
# Epoch 10/1000
#  - 0s - loss: 0.0452 - mean_squared_error: 0.0034 - val_loss: 0.0568 - val_mean_squared_error: 0.0034
# Epoch 11/1000
#  - 0s - loss: 0.0453 - mean_squared_error: 0.0034 - val_loss: 0.0388 - val_mean_squared_error: 0.0016
# Epoch 12/1000
#  - 0s - loss: 0.0461 - mean_squared_error: 0.0035 - val_loss: 0.0557 - val_mean_squared_error: 0.0032
# Epoch 13/1000
#  - 0s - loss: 0.0449 - mean_squared_error: 0.0034 - val_loss: 0.0526 - val_mean_squared_error: 0.0029
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 0s - loss: 0.0446 - mean_squared_error: 0.0033 - val_loss: 0.0496 - val_mean_squared_error: 0.0025
# Epoch 15/1000
#  - 0s - loss: 0.0447 - mean_squared_error: 0.0033 - val_loss: 0.0509 - val_mean_squared_error: 0.0027
# Epoch 16/1000
#  - 0s - loss: 0.0446 - mean_squared_error: 0.0033 - val_loss: 0.0499 - val_mean_squared_error: 0.0026
# predict: [[31.16084938 21.39175665]]
# real:      [[31.  22.8]]
#
# Train on 1017 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.4355 - mean_squared_error: 6.2683 - val_loss: 1.0918 - val_mean_squared_error: 1.1955
# Epoch 2/1000
#  - 0s - loss: 0.4951 - mean_squared_error: 0.3692 - val_loss: 0.2685 - val_mean_squared_error: 0.0721
# Epoch 3/1000
#  - 0s - loss: 0.1201 - mean_squared_error: 0.0217 - val_loss: 0.1470 - val_mean_squared_error: 0.0390
# Epoch 4/1000
#  - 0s - loss: 0.0712 - mean_squared_error: 0.0080 - val_loss: 0.1006 - val_mean_squared_error: 0.0170
# Epoch 5/1000
#  - 0s - loss: 0.0556 - mean_squared_error: 0.0050 - val_loss: 0.0874 - val_mean_squared_error: 0.0100
# Epoch 6/1000
#  - 0s - loss: 0.0515 - mean_squared_error: 0.0043 - val_loss: 0.1057 - val_mean_squared_error: 0.0134
# Epoch 7/1000
#  - 0s - loss: 0.0495 - mean_squared_error: 0.0040 - val_loss: 0.1050 - val_mean_squared_error: 0.0135
# Epoch 8/1000
#  - 0s - loss: 0.0500 - mean_squared_error: 0.0040 - val_loss: 0.0966 - val_mean_squared_error: 0.0122
# Epoch 9/1000
#  - 0s - loss: 0.0496 - mean_squared_error: 0.0040 - val_loss: 0.0934 - val_mean_squared_error: 0.0118
# Epoch 10/1000
#  - 0s - loss: 0.0488 - mean_squared_error: 0.0039 - val_loss: 0.0967 - val_mean_squared_error: 0.0129
# Epoch 11/1000
#  - 0s - loss: 0.0497 - mean_squared_error: 0.0039 - val_loss: 0.0865 - val_mean_squared_error: 0.0125
# Epoch 12/1000
#  - 0s - loss: 0.0492 - mean_squared_error: 0.0040 - val_loss: 0.0962 - val_mean_squared_error: 0.0142
# Epoch 13/1000
#  - 0s - loss: 0.0485 - mean_squared_error: 0.0038 - val_loss: 0.1002 - val_mean_squared_error: 0.0141
# Epoch 14/1000
#  - 0s - loss: 0.0490 - mean_squared_error: 0.0039 - val_loss: 0.0948 - val_mean_squared_error: 0.0144
# Epoch 15/1000
#  - 0s - loss: 0.0481 - mean_squared_error: 0.0038 - val_loss: 0.0915 - val_mean_squared_error: 0.0127
# Epoch 16/1000
#  - 0s - loss: 0.0477 - mean_squared_error: 0.0037 - val_loss: 0.0887 - val_mean_squared_error: 0.0119
# Epoch 17/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0853 - val_mean_squared_error: 0.0133
# Epoch 18/1000
#  - 0s - loss: 0.0490 - mean_squared_error: 0.0039 - val_loss: 0.0886 - val_mean_squared_error: 0.0123
# Epoch 19/1000
#  - 0s - loss: 0.0474 - mean_squared_error: 0.0037 - val_loss: 0.0886 - val_mean_squared_error: 0.0104
# Epoch 20/1000
#  - 0s - loss: 0.0479 - mean_squared_error: 0.0037 - val_loss: 0.0878 - val_mean_squared_error: 0.0119
# Epoch 21/1000
#  - 0s - loss: 0.0490 - mean_squared_error: 0.0040 - val_loss: 0.0440 - val_mean_squared_error: 0.0020
# Epoch 7/1000
#  - 0s - loss: 0.0476 - mean_squared_error: 0.0037 - val_loss: 0.0748 - val_mean_squared_error: 0.0058
# Epoch 8/1000
#  - 0s - loss: 0.0474 - mean_squared_error: 0.0037 - val_loss: 0.0445 - val_mean_squared_error: 0.0021
# Epoch 9/1000
#  - 0s - loss: 0.0479 - mean_squared_error: 0.0037 - val_loss: 0.0668 - val_mean_squared_error: 0.0045
# Epoch 10/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0893 - val_mean_squared_error: 0.0083
# Epoch 11/1000
#  - 0s - loss: 0.0508 - mean_squared_error: 0.0043 - val_loss: 0.0488 - val_mean_squared_error: 0.0030
# Epoch 12/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0035 - val_loss: 0.0746 - val_mean_squared_error: 0.0058
# Epoch 13/1000
#  - 0s - loss: 0.0477 - mean_squared_error: 0.0037 - val_loss: 0.0475 - val_mean_squared_error: 0.0023
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 0s - loss: 0.0468 - mean_squared_error: 0.0035 - val_loss: 0.0731 - val_mean_squared_error: 0.0058
# Epoch 15/1000
#  - 0s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0614 - val_mean_squared_error: 0.0041
# Epoch 16/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0660 - val_mean_squared_error: 0.0047
# predict: [[31.64512718 21.6583343 ]]
# real:      [[30.7 21.8]]
#
# Train on 1013 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 3.0676 - mean_squared_error: 9.5677 - val_loss: 2.4812 - val_mean_squared_error: 6.7290
# Epoch 2/1000
#  - 0s - loss: 2.1783 - mean_squared_error: 6.3345 - val_loss: 1.8564 - val_mean_squared_error: 5.4785
# Epoch 3/1000
#  - 0s - loss: 1.5893 - mean_squared_error: 4.6512 - val_loss: 1.4644 - val_mean_squared_error: 3.4376
# Epoch 4/1000
#  - 0s - loss: 1.2144 - mean_squared_error: 2.8191 - val_loss: 1.1069 - val_mean_squared_error: 2.0219
# Epoch 5/1000
#  - 0s - loss: 0.9302 - mean_squared_error: 1.6553 - val_loss: 0.8235 - val_mean_squared_error: 1.0043
# Epoch 6/1000
#  - 0s - loss: 0.6039 - mean_squared_error: 0.6951 - val_loss: 0.4672 - val_mean_squared_error: 0.2556
# Epoch 7/1000
#  - 0s - loss: 0.2024 - mean_squared_error: 0.0929 - val_loss: 0.2361 - val_mean_squared_error: 0.0564
# Epoch 8/1000
#  - 0s - loss: 0.0835 - mean_squared_error: 0.0116 - val_loss: 0.1296 - val_mean_squared_error: 0.0302
# Epoch 9/1000
#  - 0s - loss: 0.0545 - mean_squared_error: 0.0048 - val_loss: 0.1768 - val_mean_squared_error: 0.0382
# Epoch 10/1000
#  - 0s - loss: 0.0477 - mean_squared_error: 0.0037 - val_loss: 0.1804 - val_mean_squared_error: 0.0397
# Epoch 11/1000
#  - 0s - loss: 0.0492 - mean_squared_error: 0.0040 - val_loss: 0.1565 - val_mean_squared_error: 0.0326
# Epoch 12/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0037 - val_loss: 0.1548 - val_mean_squared_error: 0.0333
# Epoch 13/1000
#  - 0s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.1653 - val_mean_squared_error: 0.0360
# Epoch 14/1000
#  - 0s - loss: 0.0488 - mean_squared_error: 0.0039 - val_loss: 0.1697 - val_mean_squared_error: 0.0370
# Epoch 15/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.1603 - val_mean_squared_error: 0.0341
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 0s - loss: 0.0449 - mean_squared_error: 0.0034 - val_loss: 0.1573 - val_mean_squared_error: 0.0322
# Epoch 17/1000
#  - 0s - loss: 0.0449 - mean_squared_error: 0.0034 - val_loss: 0.1617 - val_mean_squared_error: 0.0343
# Epoch 18/1000
#  - 0s - loss: 0.0453 - mean_squared_error: 0.0035 - val_loss: 0.1526 - val_mean_squared_error: 0.0303
# predict: [[31.66925625 20.53447588]]
# real:      [[31.3 20.9]]
#
# Train on 1012 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 2.2565 - mean_squared_error: 5.7448 - val_loss: 1.0734 - val_mean_squared_error: 2.2549
# Epoch 2/1000
#  - 0s - loss: 0.9026 - mean_squared_error: 1.4246 - val_loss: 0.3413 - val_mean_squared_error: 0.2035
# Epoch 3/1000
#  - 0s - loss: 0.2006 - mean_squared_error: 0.0762 - val_loss: 0.2372 - val_mean_squared_error: 0.0685
# Epoch 4/1000
#  - 0s - loss: 0.0926 - mean_squared_error: 0.0140 - val_loss: 0.0779 - val_mean_squared_error: 0.0073
# Epoch 5/1000
#  - 0s - loss: 0.0623 - mean_squared_error: 0.0064 - val_loss: 0.0787 - val_mean_squared_error: 0.0063
# Epoch 6/1000
#  - 0s - loss: 0.0525 - mean_squared_error: 0.0046 - val_loss: 0.0781 - val_mean_squared_error: 0.0062
# Epoch 7/1000
#  - 0s - loss: 0.0482 - mean_squared_error: 0.0039 - val_loss: 0.0735 - val_mean_squared_error: 0.0055
# Epoch 8/1000
#  - 0s - loss: 0.0517 - mean_squared_error: 0.0042 - val_loss: 0.1084 - val_mean_squared_error: 0.0120
# Epoch 9/1000
#  - 0s - loss: 0.0484 - mean_squared_error: 0.0038 - val_loss: 0.0982 - val_mean_squared_error: 0.0097
# Epoch 10/1000
#  - 0s - loss: 0.0467 - mean_squared_error: 0.0037 - val_loss: 0.1004 - val_mean_squared_error: 0.0101
# Epoch 11/1000
#  - 0s - loss: 0.0475 - mean_squared_error: 0.0038 - val_loss: 0.0904 - val_mean_squared_error: 0.0082
# Epoch 12/1000
#  - 0s - loss: 0.0500 - mean_squared_error: 0.0040 - val_loss: 0.0796 - val_mean_squared_error: 0.0070
# Epoch 13/1000
#  - 0s - loss: 0.0469 - mean_squared_error: 0.0036 - val_loss: 0.1028 - val_mean_squared_error: 0.0123
# Epoch 14/1000
# ...
# Epoch 10/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0037 - val_loss: 0.0437 - val_mean_squared_error: 0.0030
samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.5280 - mean_squared_error: 6.6293 - val_loss: 1.5993 - val_mean_squared_error: 2.5983
# Epoch 2/1000
#  - 0s - loss: 0.8455 - mean_squared_error: 0.9937 - val_loss: 0.2633 - val_mean_squared_error: 0.1099
# Epoch 3/1000
#  - 0s - loss: 0.2026 - mean_squared_error: 0.0560 - val_loss: 0.1305 - val_mean_squared_error: 0.0170
# Epoch 4/1000
#  - 0s - loss: 0.0917 - mean_squared_error: 0.0123 - val_loss: 0.0487 - val_mean_squared_error: 0.0025
# Epoch 5/1000
#  - 0s - loss: 0.0628 - mean_squared_error: 0.0063 - val_loss: 0.0205 - val_mean_squared_error: 5.9950e-04
# Epoch 6/1000
#  - 0s - loss: 0.0521 - mean_squared_error: 0.0043 - val_loss: 0.0320 - val_mean_squared_error: 0.0010
# Epoch 7/1000
#  - 0s - loss: 0.0495 - mean_squared_error: 0.0040 - val_loss: 0.0314 - val_mean_squared_error: 0.0014
# Epoch 8/1000
#  - 0s - loss: 0.0477 - mean_squared_error: 0.0038 - val_loss: 0.0403 - val_mean_squared_error: 0.0021
# Epoch 9/1000
#  - 0s - loss: 0.0478 - mean_squared_error: 0.0037 - val_loss: 0.0402 - val_mean_squared_error: 0.0017
# Epoch 10/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0037 - val_loss: 0.0325 - val_mean_squared_error: 0.0011
# Epoch 11/1000
#  - 0s - loss: 0.0471 - mean_squared_error: 0.0037 - val_loss: 0.0407 - val_mean_squared_error: 0.0021
# Epoch 12/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0036 - val_loss: 0.0377 - val_mean_squared_error: 0.0015
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0036 - val_loss: 0.0316 - val_mean_squared_error: 0.0013
# Epoch 14/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0321 - val_mean_squared_error: 0.0013
# Epoch 15/1000
#  - 0s - loss: 0.0462 - mean_squared_error: 0.0035 - val_loss: 0.0349 - val_mean_squared_error: 0.0015
# predict: [[30.71263262 22.68419141]]
# real:      [[30.9 22.9]]
#
# Train on 1003 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.0189 - mean_squared_error: 4.7409 - val_loss: 0.5058 - val_mean_squared_error: 0.4543
# Epoch 2/1000
#  - 0s - loss: 0.4642 - mean_squared_error: 0.3191 - val_loss: 0.3116 - val_mean_squared_error: 0.1843
# Epoch 3/1000
#  - 0s - loss: 0.1597 - mean_squared_error: 0.0440 - val_loss: 0.1517 - val_mean_squared_error: 0.0276
# Epoch 4/1000
#  - 0s - loss: 0.0779 - mean_squared_error: 0.0096 - val_loss: 0.1130 - val_mean_squared_error: 0.0138
# Epoch 5/1000
#  - 0s - loss: 0.0546 - mean_squared_error: 0.0049 - val_loss: 0.0849 - val_mean_squared_error: 0.0074
# Epoch 6/1000
#  - 0s - loss: 0.0484 - mean_squared_error: 0.0039 - val_loss: 0.0613 - val_mean_squared_error: 0.0039
# Epoch 7/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0037 - val_loss: 0.0869 - val_mean_squared_error: 0.0076
# Epoch 8/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0036 - val_loss: 0.0672 - val_mean_squared_error: 0.0046
# Epoch 9/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0930 - val_mean_squared_error: 0.0087
# Epoch 10/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0675 - val_mean_squared_error: 0.0046
# Epoch 11/1000
#  - 0s - loss: 0.0457 - mean_squared_error: 0.0034 - val_loss: 0.0871 - val_mean_squared_error: 0.0076
# Epoch 12/1000
#  - 0s - loss: 0.0458 - mean_squared_error: 0.0034 - val_loss: 0.0622 - val_mean_squared_error: 0.0040
# Epoch 13/1000
#  - 0s - loss: 0.0474 - mean_squared_error: 0.0036 - val_loss: 0.0736 - val_mean_squared_error: 0.0055
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 0s - loss: 0.0449 - mean_squared_error: 0.0033 - val_loss: 0.0853 - val_mean_squared_error: 0.0074
# Epoch 15/1000
#  - 0s - loss: 0.0447 - mean_squared_error: 0.0033 - val_loss: 0.0820 - val_mean_squared_error: 0.0068
# Epoch 16/1000
#  - 0s - loss: 0.0447 - mean_squared_error: 0.0033 - val_loss: 0.0769 - val_mean_squared_error: 0.0060
# predict: [[31.27945752 21.09737856]]
# real:      [[31.2 23.2]]
#
# Train on 1002 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.6491 - mean_squared_error: 7.2637 - val_loss: 1.7018 - val_mean_squared_error: 2.9918
# Epoch 2/1000
#  - 0s - loss: 0.9306 - mean_squared_error: 1.2688 - val_loss: 0.2368 - val_mean_squared_error: 0.0584
# Epoch 3/1000
#  - 0s - loss: 0.1241 - mean_squared_error: 0.0261 - val_loss: 0.0250 - val_mean_squared_error: 6.3048e-04
# Epoch 4/1000
#  - 0s - loss: 0.0621 - mean_squared_error: 0.0062 - val_loss: 0.0567 - val_mean_squared_error: 0.0049
# Epoch 5/1000
#  - 0s - loss: 0.0515 - mean_squared_error: 0.0045 - val_loss: 0.0690 - val_mean_squared_error: 0.0063
# Epoch 6/1000
#  - 0s - loss: 0.0481 - mean_squared_error: 0.0039 - val_loss: 0.0636 - val_mean_squared_error: 0.0067
# Epoch 7/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0653 - val_mean_squared_error: 0.0070
# Epoch 8/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0732 - val_mean_squared_error: 0.0097
# Epoch 9/1000
#  - 0s - loss: 0.0465 - mean_squared_error: 0.0036 - val_loss: 0.0682 - val_mean_squared_error: 0.0078
# Epoch 10/1000
#  - 0s - loss: 0.0456 - mean_squared_error: 0.0035 - val_loss: 0.0730 - val_mean_squared_error: 0.0073
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0035 - val_loss: 0.0780 - val_mean_squared_error: 0.0092
# Epoch 12/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0034 - val_loss: 0.0601 - val_mean_squared_error: 0.0071
# Epoch 13/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0678 - val_mean_squared_error: 0.0083
# predict: [[27.14477077 19.99590665]]
# real:      [[31.  21.1]]
#
# Train on 1001 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.4348 - mean_squared_error: 6.1136 - val_loss: 1.7011 - val_mean_squared_error: 2.9531
# Epoch 2/1000
#  - 0s - loss: 1.1245 - mean_squared_error: 1.5268 - val_loss: 0.5076 - val_mean_squared_error: 0.3429
# Epoch 3/1000
#  - 0s - loss: 0.3588 - mean_squared_error: 0.1712 - val_loss: 0.2308 - val_mean_squared_error: 0.0918
# Epoch 4/1000
#  - 0s - loss: 0.1084 - mean_squared_error: 0.0184 - val_loss: 0.0738 - val_mean_squared_error: 0.0055
# Epoch 5/1000
#  - 0s - loss: 0.0685 - mean_squared_error: 0.0074 - val_loss: 0.1047 - val_mean_squared_error: 0.0122
# Epoch 6/1000
#  - 0s - loss: 0.0520 - mean_squared_error: 0.0044 - val_loss: 0.0525 - val_mean_squared_error: 0.0051
# Epoch 7/1000
#  - 0s - loss: 0.0490 - mean_squared_error: 0.0039 - val_loss: 0.0740 - val_mean_squared_error: 0.0088
# Epoch 8/1000
#  - 0s - loss: 0.0475 - mean_squared_error: 0.0038 - val_loss: 0.0628 - val_mean_squared_error: 0.0072
# Epoch 9/1000
#  - 0s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0642 - val_mean_squared_error: 0.0071
# Epoch 10/1000
#  - 0s - loss: 0.0470 - mean_squared_error: 0.0036 - val_loss: 0.0650 - val_mean_squared_error: 0.0069
# Epoch 11/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0036 - val_loss: 0.0650 - val_mean_squared_error: 0.0058
# Epoch 12/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0036 - val_loss: 0.0563 - val_mean_squared_error: 0.0062
# Epoch 13/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0036 - val_loss: 0.0589 - val_mean_squared_error: 0.0057
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 0s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0594 - val_mean_squared_error: 0.0060
# Epoch 15/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0035 - val_loss: 0.0595 - val_mean_squared_error: 0.0061
# Epoch 16/1000
#  - 0s - loss: 0.0460 - mean_squared_error: 0.0035 - val_loss: 0.0591 - val_mean_squared_error: 0.0058
# predict: [[32.68538604 22.26603544]]
# real:      [[28.7 22.8]]
#
# Train on 1000 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 2.9045 - mean_squared_error: 8.7426 - val_loss: 2.3887 - val_mean_squared_error: 6.0420
# Epoch 2/1000
#  - 0s - loss: 2.0420 - mean_squared_error: 4.5955 - val_loss: 1.5000 - val_mean_squared_error: 2.5192
# Epoch 3/1000
#  - 0s - loss: 1.0788 - mean_squared_error: 1.5614 - val_loss: 0.4908 - val_mean_squared_error: 0.4180
# Epoch 4/1000
#  - 0s - loss: 0.2402 - mean_squared_error: 0.1289 - val_loss: 0.1985 - val_mean_squared_error: 0.0500
# Epoch 5/1000
#  - 0s - loss: 0.0965 - mean_squared_error: 0.0140 - val_loss: 0.0721 - val_mean_squared_error: 0.0052
# Epoch 6/1000
#  - 0s - loss: 0.0598 - mean_squared_error: 0.0059 - val_loss: 0.0647 - val_mean_squared_error: 0.0070
# Epoch 7/1000
#  - 0s - loss: 0.0536 - mean_squared_error: 0.0045 - val_loss: 0.0837 - val_mean_squared_error: 0.0079
# Epoch 8/1000
#  - 0s - loss: 0.0502 - mean_squared_error: 0.0041 - val_loss: 0.0690 - val_mean_squared_error: 0.0056
# Epoch 9/1000
#  - 0s - loss: 0.0481 - mean_squared_error: 0.0038 - val_loss: 0.0638 - val_mean_squared_error: 0.0052
# Epoch 10/1000
#  - 0s - loss: 0.0472 - mean_squared_error: 0.0036 - val_loss: 0.0554 - val_mean_squared_error: 0.0040
# Epoch 11/1000
#  - 0s - loss: 0.0474 - mean_squared_error: 0.0036 - val_loss: 0.0527 - val_mean_squared_error: 0.0030
# Epoch 12/1000
#  - 0s - loss: 0.0469 - mean_squared_error: 0.0036 - val_loss: 0.0556 - val_mean_squared_error: 0.0033
# Epoch 13/1000
#  - 0s - loss: 0.0468 - mean_squared_error: 0.0035 - val_loss: 0.0652 - val_mean_squared_error: 0.0051
# Epoch 14/1000
#  - 0s - loss: 0.0471 - mean_squared_error: 0.0036 - val_loss: 0.0489 - val_mean_squared_error: 0.0026
# Epoch 15/1000
#  - 0s - loss: 0.0481 - mean_squared_error: 0.0037 - val_loss: 0.0522 - val_mean_squared_error: 0.0032
# Epoch 16/1000
#  - 0s - loss: 0.0466 - mean_squared_error: 0.0035 - val_loss: 0.0581 - val_mean_squared_error: 0.0036
# Epoch 17/1000
#  - 0s - loss: 0.0464 - mean_squared_error: 0.0035 - val_loss: 0.0650 - val_mean_squared_error: 0.0044
# Epoch 18/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0034 - val_loss: 0.0627 - val_mean_squared_error: 0.0041
# Epoch 19/1000
#  - 0s - loss: 0.0463 - mean_squared_error: 0.0035 - val_loss: 0.0539 - val_mean_squared_error: 0.0032
# Epoch 20/1000
#  - 0s - loss: 0.0457 - mean_squared_error: 0.0033 - val_loss: 0.0508 - val_mean_squared_error: 0.0029
# Epoch 21/1000
#  - 0s - loss: 0.0459 - mean_squared_error: 0.0033 - val_loss: 0.0528 - val_mean_squared_error: 0.0034
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 22/1000
#  - 0s - loss: 0.0453 - mean_squared_error: 0.0033 - val_loss: 0.0575 - val_mean_squared_error: 0.0034
# Epoch 23/1000
#  - 0s - loss: 0.0451 - mean_squared_error: 0.0033 - val_loss: 0.0555 - val_mean_squared_error: 0.0033
# Epoch 24/1000
#  - 0s - loss: 0.0449 - mean_squared_error: 0.0032 - val_loss: 0.0542 - val_mean_squared_error: 0.0031
# predict: [[31.83684345 22.38133283]]
# real:      [[30.1 22.9]]
#
# Test RMSE -------------------------- 0.6447
# Test VARIANCE ---------------------- 1.0
# Test MAX-ERROR --------------------- 0.7627
# Test MEAN-ABSOLUTE-ERROR ----------- 0.6311
# Test MEDIAN-ABSOLUTE-ERROR --------- 0.6311
