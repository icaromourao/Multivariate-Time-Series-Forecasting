# %%
# imports required for the algorithm
import os

from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from datetime import datetime
from math import sqrt
import numpy as np

from matplotlib import pyplot

from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# path to load and save data
data_input_path = '../../data_in/CE_Crateus.csv'
data_output_path = '../../data_out/weather.csv'
data_output_path_npsave = '../../data_out/weather.npy'

# %%
# transform date into appropriate format
def parse(x):
	return datetime.strptime(x, '%d/%m/%Y')

# %%
# load the input dataset and save like a output dataset
def format_dataset(data_input_path, output_path):
    try:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1')
    except:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1', skiprows=2)
    
    dataset.index.name = 'date'

    dataset.drop('Unnamed: 11', axis=1, inplace=True)
    dataset.drop('Estacao', axis=1, inplace=True)
    
    dataset['TempMinima'] = dataset['TempMinima'].shift(-1)
    dataset['Precipitacao'] = dataset['Precipitacao'].shift(-1)
    
    dataset.drop('Hora', axis=1, inplace=True)
    
    dataset = dataset.loc[~dataset.index.duplicated(keep='first')]
    
    # replaces first line NA values with next line value
    dataset.iloc[0,:].fillna(dataset.iloc[1,:], inplace=True)
    
    # replace all NA values with prev line value
    dataset.ffill(axis=0, inplace=True)

    # show the first 5 lines on the dataset
    print(dataset)
        
    # save file
    dataset.to_csv(output_path)

format_dataset(data_input_path, data_output_path)
# Out:
#             Precipitacao  TempMaxima  TempMinima  Insolacao  Evaporacao Piche  \
# date
# 2015-01-01           0.0        35.0        23.7        5.9              10.2
# 2015-01-02           0.0        35.8        23.0       10.6              10.2
# 2015-01-03          37.4        31.9        22.3        4.3               6.2
# 2015-01-04          12.4        27.3        20.7        1.9               3.5
# 2015-01-05          23.0        32.4        20.7        8.3               1.5
# ...                  ...         ...         ...        ...               ...
# 2018-04-26           0.0        31.0        20.8        8.9               0.5
# 2018-04-27           0.0        31.7        22.9       10.5               0.5
# 2018-04-28           0.0        31.3        21.5        9.5               0.5
# 2018-04-29           3.5        28.9        22.7        2.5               0.5
# 2018-04-30           0.4        28.9        21.9        2.5               0.5
#
#             Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media
# date
# 2015-01-01            28.76                   47.00                   2.633333
# 2015-01-02            26.72                   72.50                   1.866667
# 2015-01-03            26.32                   71.50                   1.600000
# 2015-01-04            23.50                   88.25                   2.266667
# 2015-01-05            26.64                   66.75                   3.166667
# ...                     ...                     ...                        ...
# 2018-04-26            25.66                   78.00                   1.286100
# 2018-04-27            26.26                   77.00                   1.800540
# 2018-04-28            26.38                   81.00                   1.028880
# 2018-04-29            24.64                   93.00                   1.543320
# 2018-04-30            24.64                   93.00                   2.057760
#
# [1091 rows x 8 columns]

# %%
# load dataset
def load_dataset(input_path):
    return read_csv(input_path, header=0, index_col=0)

dataset = load_dataset(data_output_path)
values = dataset.values

# %%
# plot each column in a graph
def plot_columns(values):
    groups = list(range(0,len(values[0])))
    i = 1
    
    pyplot.figure(dpi=120)
    for group in groups:
        pyplot.subplot(len(groups), 1, i)
        pyplot.plot(values[:, group])
        pyplot.title(dataset.columns[group], y=0.1, loc='right')
        i += 1
    pyplot.show()

plot_columns(values)

# %%
# convert series to supervised learning
def series_to_supervised(dataset, day):
    y_test = np.array([dataset.loc[day]['TempMaxima'], dataset.loc[day]['TempMinima']])
    y_test = y_test.reshape(1,2)
    
    dataset = dataset[:-1]
    
    x_test = np.array(dataset[-60:])
    x_test = x_test.reshape(1,60,8)
    
    lista = []
    
    for i in list(dataset.index):
        lista.append([dataset.loc[i]['TempMaxima'], dataset.loc[i]['TempMinima']])
    y_train = np.array(lista[60:])
    
    dataset = dataset[:-1]
    
    x_train = np.array(dataset[-60:])
    x_train = x_train.reshape(1,60,8)
    dataset = dataset[:-1]
    
    while len(dataset) >= 60:
        array_aux = np.array(dataset[-60:])
        array_aux = array_aux.reshape(1,60,8)
        x_train = np.concatenate((x_train, array_aux), axis=0)
        dataset = dataset[:-1]
    
    return [x_train, y_train, x_test, y_test]

# %%
# inner loop
def myLSTM(x_train, y_train, x_test, y_test, scaler):
    x_val = x_train[-1]
    y_val = y_train[-1]
    x_val = x_val.reshape(1,60,8)
    y_val = y_val.reshape(1,2)
    x_train = x_train[:-1]
    y_train = y_train[:-1]
    
    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dense(16, activation='relu'))   # worth it?
    model.add(Dense(2))
    model.compile(loss='mae', optimizer='adam', metrics=['mse'])
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')
    ]
    
    # fit network
    history = model.fit(x_train, y_train,
                        epochs=1000, 
                        batch_size=72, 
                        validation_data=(x_val, y_val), 
                        verbose=2, 
                        shuffle=True, 
                        callbacks=callbacks)
    
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()
    
    y = inverseScale(model, x_test, y_test, scaler)
    inv_y_hat = y[0]
    inv_y_test = y[1]
    
    print('\npredict: {}'.format(inv_y_hat))
    print('real:      {}\n'.format(inv_y_test))
    
    return [inv_y_hat, inv_y_test]

# %%
def inverseScale(model, x_test, y_test, scaler):
    # make a prediction
    y_hat = model.predict(x_test)
    
    new_x_test = x_test[:,-1,:]
    new_x_test = new_x_test.reshape((x_test.shape[0], x_test.shape[2]))
    new_x_test = np.concatenate((new_x_test[:, 0:1], new_x_test[:, 3:]), axis=1)
    
    # invert scaling for forecast
    inv_y_hat = np.concatenate((y_hat, new_x_test), axis=1)
    inv_y_hat = scaler * inv_y_hat
    inv_y_hat = inv_y_hat[:,:2]
    
    # invert scaling for actual value
    new_test_y = y_test.reshape((len(y_test), 2))
    inv_y_test = np.concatenate((new_test_y, new_x_test), axis=1)
    inv_y_test = scaler * inv_y_test
    inv_y_test = inv_y_test[:,:2]
    
    return [inv_y_hat, inv_y_test]

# %%
# Nested Cross Validation
def NCV(dataset, days_to_predict, scaler):
    i = len(days_to_predict) - 1
    y_hats = []
    y_tests = []
    
    # outer loop
    while(i >= 0):
        data = series_to_supervised(dataset, days_to_predict[i])
        x_train = data[0]
        y_train = data[1]
        x_test = data[2]
        y_test = data[3]
        
        result = myLSTM(x_train, y_train, x_test, y_test, scaler)
        
        y_hats += result[0].tolist()
        y_tests += result[1].tolist()
        
        i -= 1
        dataset = dataset[:-1]
        
    return [y_hats, y_tests]

# %%
def metrics(y_hats, y_tests):
    y_hats_max = []
    y_hats_min = []
    y_tests_max = []
    y_tests_min = []
    percentual = 100
    n = len(y_hats)
    j = 1
    
    for y in y_hats:
        y_hats_max += [y[0]]
        y_hats_min += [y[1]]
        
    for y in y_tests:
        y_tests_max += [y[0]]
        y_tests_min += [y[1]]
    
    rmse_max = sqrt(mean_squared_error(y_tests_max, y_hats_max))
    variance_max = explained_variance_score(y_tests_max, y_hats_max)
    maxError_max = max_error(y_tests_max, y_hats_max)
    meanAbsolutError_max = mean_absolute_error(y_tests_max, y_hats_max)
    medianAbsoluteError_max = median_absolute_error(y_tests_max, y_hats_max)
    
    rmse_min = sqrt(mean_squared_error(y_tests_min, y_hats_min))
    variance_min = explained_variance_score(y_tests_min, y_hats_min)
    maxError_min = max_error(y_tests_min, y_hats_min)
    meanAbsolutError_min = mean_absolute_error(y_tests_min, y_hats_min)
    medianAbsoluteError_min = median_absolute_error(y_tests_min, y_hats_min)
    
    print('Maximum metrics')
    print('Test RMSE -------------------------- {:.4}'.format(rmse_max))
    print('Test VARIANCE ---------------------- {:.4}'.format(variance_max))
    print('Test MAX-ERROR --------------------- {:.4}'.format(maxError_max))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError_max))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError_max))
    
    print('\nAccuracy')
    while percentual > 0:
        count = 0
        n = len(y_hats_max)
        
        for i in range(0,len(y_hats_max)):
            error = abs(y_hats_max[i] - y_tests_max[i])
            if  error > j-1 and error <= j:
                count += 1
        
        percentual = round((count/n)*100,2)
        if percentual > 0:
            print('{}% of predictions missed {} point(s) or less'.format(percentual, j))
        j += 1
    
    print('\nMinimum metrics')
    print('Test RMSE -------------------------- {:.4}'.format(rmse_min))
    print('Test VARIANCE ---------------------- {:.4}'.format(variance_min))
    print('Test MAX-ERROR --------------------- {:.4}'.format(maxError_min))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError_min))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError_min))
    
    j = 1
    percentual = 100
    print('\nAccuracy')
    while percentual > 0:
        count = 0
        n = len(y_hats_max)
        
        for i in range(0,len(y_hats_max)):
            error = abs(y_hats_min[i] - y_tests_min[i])
            if  error > j-1 and error <= j:
                count += 1
        
        percentual = round((count/n)*100,2)
        if percentual > 0:
            print('{}% of predictions missed {} point(s) or less'.format(percentual, j))
        j += 1

# %%
# to get index the last 30 days
days_to_predict = list(dataset.index[-30:])

mean_scaler = np.mean(values) + 1
dataset_scaled = dataset.div(mean_scaler)

result = NCV(dataset_scaled, days_to_predict, mean_scaler)
# Out:
# Train on 1029 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.5725 - mean_squared_error: 0.5190 - val_loss: 0.2663 - val_mean_squared_error: 0.0724
# Epoch 2/1000
#  - 1s - loss: 0.1140 - mean_squared_error: 0.0199 - val_loss: 0.0987 - val_mean_squared_error: 0.0140
# Epoch 3/1000
#  - 1s - loss: 0.0737 - mean_squared_error: 0.0084 - val_loss: 0.1069 - val_mean_squared_error: 0.0176
# Epoch 4/1000
#  - 1s - loss: 0.0620 - mean_squared_error: 0.0062 - val_loss: 0.0756 - val_mean_squared_error: 0.0114
# Epoch 5/1000
#  - 1s - loss: 0.0601 - mean_squared_error: 0.0059 - val_loss: 0.0872 - val_mean_squared_error: 0.0140
# Epoch 6/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0059 - val_loss: 0.0935 - val_mean_squared_error: 0.0149
# Epoch 7/1000
#  - 1s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.1127 - val_mean_squared_error: 0.0201
# Epoch 8/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0059 - val_loss: 0.0996 - val_mean_squared_error: 0.0173
# Epoch 9/1000
#  - 1s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0852 - val_mean_squared_error: 0.0135
# Epoch 10/1000
#  - 1s - loss: 0.0598 - mean_squared_error: 0.0059 - val_loss: 0.0692 - val_mean_squared_error: 0.0087
# Epoch 11/1000
#  - 1s - loss: 0.0599 - mean_squared_error: 0.0059 - val_loss: 0.0935 - val_mean_squared_error: 0.0136
# Epoch 12/1000
#  - 1s - loss: 0.0589 - mean_squared_error: 0.0058 - val_loss: 0.1001 - val_mean_squared_error: 0.0158
# Epoch 13/1000
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0813 - val_mean_squared_error: 0.0123
# Epoch 14/1000
#  - 1s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.0871 - val_mean_squared_error: 0.0138
# Epoch 15/1000
#  - 1s - loss: 0.0580 - mean_squared_error: 0.0056 - val_loss: 0.1041 - val_mean_squared_error: 0.0178
# Epoch 16/1000
#  - 1s - loss: 0.0595 - mean_squared_error: 0.0060 - val_loss: 0.0892 - val_mean_squared_error: 0.0152
# Epoch 17/1000
#  - 1s - loss: 0.0570 - mean_squared_error: 0.0054 - val_loss: 0.0896 - val_mean_squared_error: 0.0146
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/1000
#  - 1s - loss: 0.0561 - mean_squared_error: 0.0053 - val_loss: 0.0894 - val_mean_squared_error: 0.0148
# Epoch 19/1000
#  - 1s - loss: 0.0560 - mean_squared_error: 0.0053 - val_loss: 0.0908 - val_mean_squared_error: 0.0148
# Epoch 20/1000
#  - 1s - loss: 0.0560 - mean_squared_error: 0.0052 - val_loss: 0.0909 - val_mean_squared_error: 0.0152
# predict: [[31.2872259  22.54249794]]
# real:      [[28.9 21.9]]
#
# Train on 1028 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.6025 - mean_squared_error: 0.5331 - val_loss: 0.1737 - val_mean_squared_error: 0.0403
# Epoch 2/1000
#  - 1s - loss: 0.1100 - mean_squared_error: 0.0188 - val_loss: 0.1009 - val_mean_squared_error: 0.0118
# Epoch 3/1000
#  - 1s - loss: 0.0710 - mean_squared_error: 0.0080 - val_loss: 0.0738 - val_mean_squared_error: 0.0062
# Epoch 4/1000
#  - 1s - loss: 0.0607 - mean_squared_error: 0.0061 - val_loss: 0.0600 - val_mean_squared_error: 0.0036
# Epoch 5/1000
#  - 1s - loss: 0.0590 - mean_squared_error: 0.0058 - val_loss: 0.0493 - val_mean_squared_error: 0.0024
# Epoch 6/1000
#  - 1s - loss: 0.0578 - mean_squared_error: 0.0056 - val_loss: 0.0504 - val_mean_squared_error: 0.0026
# Epoch 7/1000
#  - 1s - loss: 0.0562 - mean_squared_error: 0.0054 - val_loss: 0.0492 - val_mean_squared_error: 0.0025
# Epoch 8/1000
#  - 1s - loss: 0.0554 - mean_squared_error: 0.0053 - val_loss: 0.0562 - val_mean_squared_error: 0.0032
# Epoch 9/1000
#  - 1s - loss: 0.0537 - mean_squared_error: 0.0050 - val_loss: 0.0613 - val_mean_squared_error: 0.0039
# Epoch 10/1000
#  - 1s - loss: 0.0545 - mean_squared_error: 0.0052 - val_loss: 0.0469 - val_mean_squared_error: 0.0024
# Epoch 11/1000
#  - 1s - loss: 0.0524 - mean_squared_error: 0.0048 - val_loss: 0.0553 - val_mean_squared_error: 0.0031
# Epoch 12/1000
#  - 1s - loss: 0.0524 - mean_squared_error: 0.0048 - val_loss: 0.0520 - val_mean_squared_error: 0.0027
# Epoch 13/1000
#  - 1s - loss: 0.0519 - mean_squared_error: 0.0047 - val_loss: 0.0574 - val_mean_squared_error: 0.0033
# Epoch 14/1000
#  - 1s - loss: 0.0513 - mean_squared_error: 0.0046 - val_loss: 0.0533 - val_mean_squared_error: 0.0030
# Epoch 15/1000
#  - 1s - loss: 0.0516 - mean_squared_error: 0.0047 - val_loss: 0.0561 - val_mean_squared_error: 0.0033
# Epoch 16/1000
#  - 1s - loss: 0.0508 - mean_squared_error: 0.0046 - val_loss: 0.0547 - val_mean_squared_error: 0.0030
# Epoch 17/1000
#  - 1s - loss: 0.0508 - mean_squared_error: 0.0046 - val_loss: 0.0442 - val_mean_squared_error: 0.0020
# Epoch 18/1000
#  - 1s - loss: 0.0510 - mean_squared_error: 0.0046 - val_loss: 0.0592 - val_mean_squared_error: 0.0037
# Epoch 19/1000
#  - 1s - loss: 0.0518 - mean_squared_error: 0.0047 - val_loss: 0.0645 - val_mean_squared_error: 0.0043
# Epoch 20/1000
#  - 1s - loss: 0.0506 - mean_squared_error: 0.0045 - val_loss: 0.0448 - val_mean_squared_error: 0.0022
# Epoch 21/1000
#  - 1s - loss: 0.0511 - mean_squared_error: 0.0045 - val_loss: 0.0611 - val_mean_squared_error: 0.0038
# Epoch 22/1000
#  - 1s - loss: 0.0509 - mean_squared_error: 0.0045 - val_loss: 0.0799 - val_mean_squared_error: 0.0066
# Epoch 23/1000
#  - 1s - loss: 0.0500 - mean_squared_error: 0.0045 - val_loss: 0.0584 - val_mean_squared_error: 0.0037
# Epoch 24/1000
#  - 1s - loss: 0.0500 - mean_squared_error: 0.0044 - val_loss: 0.0637 - val_mean_squared_error: 0.0041
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 25/1000
#  - 1s - loss: 0.0489 - mean_squared_error: 0.0043 - val_loss: 0.0628 - val_mean_squared_error: 0.0040
# Epoch 26/1000
#  - 1s - loss: 0.0486 - mean_squared_error: 0.0043 - val_loss: 0.0642 - val_mean_squared_error: 0.0041
# Epoch 27/1000
#  - 1s - loss: 0.0486 - mean_squared_error: 0.0043 - val_loss: 0.0627 - val_mean_squared_error: 0.0040
# predict: [[32.08754546 22.2570448 ]]
# real:      [[28.9 22.7]]
#
# Train on 1027 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.4432 - mean_squared_error: 0.3600 - val_loss: 0.1714 - val_mean_squared_error: 0.0564
# Epoch 2/1000
#  - 1s - loss: 0.0996 - mean_squared_error: 0.0159 - val_loss: 0.0625 - val_mean_squared_error: 0.0064
# Epoch 3/1000
#  - 1s - loss: 0.0650 - mean_squared_error: 0.0069 - val_loss: 0.0315 - val_mean_squared_error: 0.0010
# Epoch 4/1000
#  - 1s - loss: 0.0625 - mean_squared_error: 0.0065 - val_loss: 0.0370 - val_mean_squared_error: 0.0025
# Epoch 5/1000
#  - 1s - loss: 0.0593 - mean_squared_error: 0.0058 - val_loss: 0.0216 - val_mean_squared_error: 4.8535e-04
# Epoch 6/1000
#  - 1s - loss: 0.0595 - mean_squared_error: 0.0058 - val_loss: 0.0364 - val_mean_squared_error: 0.0018
# Epoch 7/1000
#  - 1s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0273 - val_mean_squared_error: 0.0011
# Epoch 8/1000
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0285 - val_mean_squared_error: 0.0010
# Epoch 9/1000
#  - 1s - loss: 0.0574 - mean_squared_error: 0.0056 - val_loss: 0.0240 - val_mean_squared_error: 0.0010
# Epoch 10/1000
#  - 1s - loss: 0.0568 - mean_squared_error: 0.0054 - val_loss: 0.0178 - val_mean_squared_error: 4.3420e-04
# Epoch 11/1000
#  - 1s - loss: 0.0558 - mean_squared_error: 0.0053 - val_loss: 0.0284 - val_mean_squared_error: 9.1129e-04
# Epoch 12/1000
#  - 1s - loss: 0.0558 - mean_squared_error: 0.0053 - val_loss: 0.0528 - val_mean_squared_error: 0.0041
# Epoch 13/1000
#  - 1s - loss: 0.0533 - mean_squared_error: 0.0049 - val_loss: 0.0777 - val_mean_squared_error: 0.0088
# Epoch 14/1000
#  - 1s - loss: 0.0541 - mean_squared_error: 0.0050 - val_loss: 0.0796 - val_mean_squared_error: 0.0079
# Epoch 15/1000
#  - 1s - loss: 0.0531 - mean_squared_error: 0.0049 - val_loss: 0.0600 - val_mean_squared_error: 0.0068
# Epoch 16/1000
#  - 1s - loss: 0.0515 - mean_squared_error: 0.0047 - val_loss: 0.0552 - val_mean_squared_error: 0.0043
# Epoch 17/1000
#  - 1s - loss: 0.0519 - mean_squared_error: 0.0047 - val_loss: 0.0562 - val_mean_squared_error: 0.0059
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/1000
#  - 1s - loss: 0.0490 - mean_squared_error: 0.0043 - val_loss: 0.0771 - val_mean_squared_error: 0.0087
# Epoch 19/1000
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0042 - val_loss: 0.0622 - val_mean_squared_error: 0.0062
# Epoch 20/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0043 - val_loss: 0.0672 - val_mean_squared_error: 0.0071
# predict: [[31.60843149 23.17513727]]
# real:      [[31.3 21.5]]
#
# Train on 1026 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.5833 - mean_squared_error: 0.4963 - val_loss: 0.1997 - val_mean_squared_error: 0.0661
# Epoch 2/1000
#  - 1s - loss: 0.1116 - mean_squared_error: 0.0190 - val_loss: 0.0891 - val_mean_squared_error: 0.0090
# Epoch 3/1000
#  - 1s - loss: 0.0662 - mean_squared_error: 0.0070 - val_loss: 0.0877 - val_mean_squared_error: 0.0077
# Epoch 4/1000
#  - 1s - loss: 0.0606 - mean_squared_error: 0.0060 - val_loss: 0.0873 - val_mean_squared_error: 0.0078
# Epoch 5/1000
#  - 1s - loss: 0.0603 - mean_squared_error: 0.0059 - val_loss: 0.0877 - val_mean_squared_error: 0.0077
# Epoch 6/1000
#  - 1s - loss: 0.0605 - mean_squared_error: 0.0060 - val_loss: 0.0756 - val_mean_squared_error: 0.0057
# Epoch 7/1000
#  - 1s - loss: 0.0598 - mean_squared_error: 0.0058 - val_loss: 0.0813 - val_mean_squared_error: 0.0066
# Epoch 8/1000
#  - 1s - loss: 0.0591 - mean_squared_error: 0.0057 - val_loss: 0.0880 - val_mean_squared_error: 0.0078
# Epoch 9/1000
#  - 1s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.0754 - val_mean_squared_error: 0.0057
# Epoch 10/1000
#  - 1s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0731 - val_mean_squared_error: 0.0054
# Epoch 11/1000
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0867 - val_mean_squared_error: 0.0076
# Epoch 12/1000
#  - 1s - loss: 0.0577 - mean_squared_error: 0.0055 - val_loss: 0.0982 - val_mean_squared_error: 0.0097
# Epoch 13/1000
#  - 1s - loss: 0.0577 - mean_squared_error: 0.0055 - val_loss: 0.0862 - val_mean_squared_error: 0.0074
# Epoch 14/1000
#  - 1s - loss: 0.0569 - mean_squared_error: 0.0054 - val_loss: 0.0941 - val_mean_squared_error: 0.0089
# Epoch 15/1000
#  - 0s - loss: 0.0554 - mean_squared_error: 0.0052 - val_loss: 0.1245 - val_mean_squared_error: 0.0157
# Epoch 16/1000
#  - 1s - loss: 0.0543 - mean_squared_error: 0.0050 - val_loss: 0.1303 - val_mean_squared_error: 0.0171
# Epoch 17/1000
#  - 1s - loss: 0.0563 - mean_squared_error: 0.0053 - val_loss: 0.1183 - val_mean_squared_error: 0.0140
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/1000
#  - 1s - loss: 0.0525 - mean_squared_error: 0.0048 - val_loss: 0.1178 - val_mean_squared_error: 0.0139
# Epoch 19/1000
#  - 1s - loss: 0.0524 - mean_squared_error: 0.0048 - val_loss: 0.1239 - val_mean_squared_error: 0.0154
# Epoch 20/1000
#  - 1s - loss: 0.0521 - mean_squared_error: 0.0047 - val_loss: 0.1225 - val_mean_squared_error: 0.0151
# predict: [[31.76595875 22.34092065]]
# real:      [[31.7 22.9]]
#
# Train on 1025 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.5987 - mean_squared_error: 0.5076 - val_loss: 0.2597 - val_mean_squared_error: 0.0791
# Epoch 2/1000
#  - 1s - loss: 0.1213 - mean_squared_error: 0.0229 - val_loss: 0.1539 - val_mean_squared_error: 0.0282
# Epoch 3/1000
#  - 1s - loss: 0.0737 - mean_squared_error: 0.0087 - val_loss: 0.0510 - val_mean_squared_error: 0.0026
# Epoch 4/1000
#  - 1s - loss: 0.0660 - mean_squared_error: 0.0070 - val_loss: 0.1047 - val_mean_squared_error: 0.0110
# Epoch 5/1000
#  - 1s - loss: 0.0607 - mean_squared_error: 0.0061 - val_loss: 0.0939 - val_mean_squared_error: 0.0088
# Epoch 6/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0058 - val_loss: 0.0835 - val_mean_squared_error: 0.0070
# Epoch 7/1000
#  - 1s - loss: 0.0593 - mean_squared_error: 0.0057 - val_loss: 0.0766 - val_mean_squared_error: 0.0059
# Epoch 8/1000
#  - 1s - loss: 0.0595 - mean_squared_error: 0.0058 - val_loss: 0.0894 - val_mean_squared_error: 0.0080
# Epoch 9/1000
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0852 - val_mean_squared_error: 0.0073
# Epoch 10/1000
#  - 1s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.1146 - val_mean_squared_error: 0.0133
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 1s - loss: 0.0569 - mean_squared_error: 0.0056 - val_loss: 0.0906 - val_mean_squared_error: 0.0083
# Epoch 12/1000
#  - 1s - loss: 0.0563 - mean_squared_error: 0.0052 - val_loss: 0.1009 - val_mean_squared_error: 0.0102
# Epoch 13/1000
#  - 1s - loss: 0.0562 - mean_squared_error: 0.0053 - val_loss: 0.1003 - val_mean_squared_error: 0.0101
# predict: [[31.31469399 22.19504575]]
# real:      [[31.  20.8]]
#
# Train on 1024 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.8481 - mean_squared_error: 0.9439 - val_loss: 0.4677 - val_mean_squared_error: 0.2881
# Epoch 2/1000
#  - 1s - loss: 0.2154 - mean_squared_error: 0.0962 - val_loss: 0.1976 - val_mean_squared_error: 0.0419
# Epoch 3/1000
#  - 1s - loss: 0.0815 - mean_squared_error: 0.0104 - val_loss: 0.0904 - val_mean_squared_error: 0.0085
# Epoch 4/1000
#  - 1s - loss: 0.0640 - mean_squared_error: 0.0065 - val_loss: 0.0923 - val_mean_squared_error: 0.0109
# Epoch 5/1000
#  - 1s - loss: 0.0606 - mean_squared_error: 0.0060 - val_loss: 0.0774 - val_mean_squared_error: 0.0064
# Epoch 6/1000
#  - 1s - loss: 0.0604 - mean_squared_error: 0.0060 - val_loss: 0.0904 - val_mean_squared_error: 0.0086
# Epoch 7/1000
#  - 1s - loss: 0.0604 - mean_squared_error: 0.0059 - val_loss: 0.0706 - val_mean_squared_error: 0.0061
# Epoch 8/1000
#  - 1s - loss: 0.0588 - mean_squared_error: 0.0057 - val_loss: 0.0873 - val_mean_squared_error: 0.0095
# Epoch 9/1000
#  - 1s - loss: 0.0591 - mean_squared_error: 0.0057 - val_loss: 0.0722 - val_mean_squared_error: 0.0067
# Epoch 10/1000
#  - 1s - loss: 0.0608 - mean_squared_error: 0.0061 - val_loss: 0.0776 - val_mean_squared_error: 0.0064
# Epoch 11/1000
#  - 1s - loss: 0.0607 - mean_squared_error: 0.0060 - val_loss: 0.1064 - val_mean_squared_error: 0.0119
# Epoch 12/1000
#  - 1s - loss: 0.0615 - mean_squared_error: 0.0063 - val_loss: 0.0893 - val_mean_squared_error: 0.0083
# Epoch 13/1000
#  - 1s - loss: 0.0584 - mean_squared_error: 0.0056 - val_loss: 0.0968 - val_mean_squared_error: 0.0103
# Epoch 14/1000
#  - 1s - loss: 0.0573 - mean_squared_error: 0.0055 - val_loss: 0.0772 - val_mean_squared_error: 0.0066
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 1s - loss: 0.0569 - mean_squared_error: 0.0054 - val_loss: 0.0855 - val_mean_squared_error: 0.0087
# Epoch 16/1000
#  - 1s - loss: 0.0567 - mean_squared_error: 0.0053 - val_loss: 0.0828 - val_mean_squared_error: 0.0080
# Epoch 17/1000
#  - 1s - loss: 0.0567 - mean_squared_error: 0.0054 - val_loss: 0.0823 - val_mean_squared_error: 0.0078
# predict: [[32.38434792 22.33828447]]
# real:      [[30.7 21. ]]
#
# Train on 1023 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.3335 - mean_squared_error: 1.8555 - val_loss: 1.0308 - val_mean_squared_error: 1.3868
# Epoch 2/1000
#  - 1s - loss: 1.0340 - mean_squared_error: 1.5747 - val_loss: 0.8206 - val_mean_squared_error: 1.2518
# Epoch 3/1000
#  - 1s - loss: 0.7009 - mean_squared_error: 0.8217 - val_loss: 0.4975 - val_mean_squared_error: 0.3678
# Epoch 4/1000
#  - 1s - loss: 0.2409 - mean_squared_error: 0.1186 - val_loss: 0.2060 - val_mean_squared_error: 0.0495
# Epoch 5/1000
#  - 1s - loss: 0.0925 - mean_squared_error: 0.0130 - val_loss: 0.0611 - val_mean_squared_error: 0.0044
# Epoch 6/1000
#  - 1s - loss: 0.0694 - mean_squared_error: 0.0076 - val_loss: 0.1003 - val_mean_squared_error: 0.0117
# Epoch 7/1000
#  - 1s - loss: 0.0654 - mean_squared_error: 0.0067 - val_loss: 0.0939 - val_mean_squared_error: 0.0130
# Epoch 8/1000
#  - 1s - loss: 0.0629 - mean_squared_error: 0.0064 - val_loss: 0.0694 - val_mean_squared_error: 0.0096
# Epoch 9/1000
#  - 1s - loss: 0.0617 - mean_squared_error: 0.0061 - val_loss: 0.0790 - val_mean_squared_error: 0.0081
# Epoch 10/1000
#  - 1s - loss: 0.0607 - mean_squared_error: 0.0059 - val_loss: 0.0795 - val_mean_squared_error: 0.0085
# Epoch 11/1000
#  - 1s - loss: 0.0601 - mean_squared_error: 0.0059 - val_loss: 0.0703 - val_mean_squared_error: 0.0061
# Epoch 12/1000
#  - 1s - loss: 0.0607 - mean_squared_error: 0.0060 - val_loss: 0.0815 - val_mean_squared_error: 0.0094
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0058 - val_loss: 0.0737 - val_mean_squared_error: 0.0079
# Epoch 14/1000
#  - 1s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0704 - val_mean_squared_error: 0.0076
# Epoch 15/1000
#  - 1s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0694 - val_mean_squared_error: 0.0074
# predict: [[31.87509528 21.68365453]]
# real:      [[30.6 21.7]]
#
# Train on 1022 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.9041 - mean_squared_error: 1.0618 - val_loss: 0.4629 - val_mean_squared_error: 0.3220
# Epoch 2/1000
#  - 1s - loss: 0.3838 - mean_squared_error: 0.2640 - val_loss: 0.1043 - val_mean_squared_error: 0.0151
# Epoch 3/1000
#  - 1s - loss: 0.1167 - mean_squared_error: 0.0269 - val_loss: 0.1719 - val_mean_squared_error: 0.0530
# Epoch 4/1000
#  - 1s - loss: 0.0739 - mean_squared_error: 0.0095 - val_loss: 0.0696 - val_mean_squared_error: 0.0084
# Epoch 5/1000
#  - 1s - loss: 0.0684 - mean_squared_error: 0.0079 - val_loss: 0.1118 - val_mean_squared_error: 0.0208
# Epoch 6/1000
#  - 1s - loss: 0.0641 - mean_squared_error: 0.0068 - val_loss: 0.1011 - val_mean_squared_error: 0.0160
# Epoch 7/1000
#  - 1s - loss: 0.0620 - mean_squared_error: 0.0064 - val_loss: 0.0890 - val_mean_squared_error: 0.0130
# Epoch 8/1000
#  - 1s - loss: 0.0608 - mean_squared_error: 0.0061 - val_loss: 0.0904 - val_mean_squared_error: 0.0130
# Epoch 9/1000
#  - 1s - loss: 0.0599 - mean_squared_error: 0.0059 - val_loss: 0.0760 - val_mean_squared_error: 0.0115
# Epoch 10/1000
#  - 1s - loss: 0.0587 - mean_squared_error: 0.0057 - val_loss: 0.0822 - val_mean_squared_error: 0.0113
# Epoch 11/1000
#  - 1s - loss: 0.0589 - mean_squared_error: 0.0057 - val_loss: 0.0875 - val_mean_squared_error: 0.0127
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0767 - val_mean_squared_error: 0.0101
# Epoch 13/1000
#  - 1s - loss: 0.0580 - mean_squared_error: 0.0056 - val_loss: 0.0752 - val_mean_squared_error: 0.0098
# Epoch 14/1000
#  - 1s - loss: 0.0578 - mean_squared_error: 0.0055 - val_loss: 0.0780 - val_mean_squared_error: 0.0101
# predict: [[32.85629446 22.74532186]]
# real:      [[30.3 22.3]]
#
# Train on 1021 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.1704 - mean_squared_error: 1.5234 - val_loss: 0.6072 - val_mean_squared_error: 0.4890
# Epoch 2/1000
#  - 1s - loss: 0.3057 - mean_squared_error: 0.2005 - val_loss: 0.2397 - val_mean_squared_error: 0.1001
# Epoch 3/1000
#  - 1s - loss: 0.1082 - mean_squared_error: 0.0211 - val_loss: 0.0495 - val_mean_squared_error: 0.0028
# Epoch 4/1000
#  - 1s - loss: 0.0712 - mean_squared_error: 0.0086 - val_loss: 0.0536 - val_mean_squared_error: 0.0051
# Epoch 5/1000
#  - 1s - loss: 0.0632 - mean_squared_error: 0.0064 - val_loss: 0.0538 - val_mean_squared_error: 0.0053
# Epoch 6/1000
#  - 1s - loss: 0.0595 - mean_squared_error: 0.0058 - val_loss: 0.0503 - val_mean_squared_error: 0.0047
# Epoch 7/1000
#  - 1s - loss: 0.0593 - mean_squared_error: 0.0058 - val_loss: 0.0535 - val_mean_squared_error: 0.0048
# Epoch 8/1000
#  - 1s - loss: 0.0592 - mean_squared_error: 0.0057 - val_loss: 0.0478 - val_mean_squared_error: 0.0041
# Epoch 9/1000
#  - 1s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.0489 - val_mean_squared_error: 0.0046
# Epoch 10/1000
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0055 - val_loss: 0.0477 - val_mean_squared_error: 0.0038
# Epoch 11/1000
#  - 1s - loss: 0.0581 - mean_squared_error: 0.0056 - val_loss: 0.0641 - val_mean_squared_error: 0.0065
# Epoch 12/1000
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0673 - val_mean_squared_error: 0.0086
# Epoch 13/1000
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0056 - val_loss: 0.0553 - val_mean_squared_error: 0.0060
# Epoch 14/1000
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0525 - val_mean_squared_error: 0.0053
# Epoch 15/1000
#  - 1s - loss: 0.0580 - mean_squared_error: 0.0056 - val_loss: 0.0636 - val_mean_squared_error: 0.0072
# Epoch 16/1000
#  - 1s - loss: 0.0572 - mean_squared_error: 0.0054 - val_loss: 0.0835 - val_mean_squared_error: 0.0102
# Epoch 17/1000
#  - 1s - loss: 0.0563 - mean_squared_error: 0.0053 - val_loss: 0.0827 - val_mean_squared_error: 0.0116
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 18/1000
#  - 1s - loss: 0.0551 - mean_squared_error: 0.0052 - val_loss: 0.0676 - val_mean_squared_error: 0.0091
# Epoch 19/1000
#  - 1s - loss: 0.0546 - mean_squared_error: 0.0050 - val_loss: 0.0703 - val_mean_squared_error: 0.0094
# Epoch 20/1000
#  - 1s - loss: 0.0546 - mean_squared_error: 0.0050 - val_loss: 0.0708 - val_mean_squared_error: 0.0099
# predict: [[31.42425665 22.19491342]]
# real:      [[30.  23.1]]
#
# Train on 1020 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.6266 - mean_squared_error: 0.6681 - val_loss: 0.2738 - val_mean_squared_error: 0.0799
# Epoch 2/1000
#  - 1s - loss: 0.1357 - mean_squared_error: 0.0354 - val_loss: 0.0875 - val_mean_squared_error: 0.0077
# Epoch 3/1000
#  - 1s - loss: 0.0878 - mean_squared_error: 0.0129 - val_loss: 0.1132 - val_mean_squared_error: 0.0220
# Epoch 4/1000
#  - 1s - loss: 0.0672 - mean_squared_error: 0.0074 - val_loss: 0.0491 - val_mean_squared_error: 0.0048
# Epoch 5/1000
#  - 1s - loss: 0.0611 - mean_squared_error: 0.0062 - val_loss: 0.0518 - val_mean_squared_error: 0.0043
# Epoch 6/1000
#  - 1s - loss: 0.0627 - mean_squared_error: 0.0062 - val_loss: 0.1373 - val_mean_squared_error: 0.0291
# Epoch 13/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0059 - val_loss: 0.1500 - val_mean_squared_error: 0.0375
# Epoch 14/1000
#  - 1s - loss: 0.0552 - mean_squared_error: 0.0050 - val_loss: 0.1273 - val_mean_squared_error: 0.0309
# Epoch 15/1000
#  - 1s - loss: 0.0534 - mean_squared_error: 0.0049 - val_loss: 0.1341 - val_mean_squared_error: 0.0342
# Epoch 16/1000
#  - 1s - loss: 0.0504 - mean_squared_error: 0.0045 - val_loss: 0.1171 - val_mean_squared_error: 0.0237
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/1000
#  - 1s - loss: 0.0482 - mean_squared_error: 0.0041 - val_loss: 0.1268 - val_mean_squared_error: 0.0310
# Epoch 18/1000
#  - 1s - loss: 0.0473 - mean_squared_error: 0.0041 - val_loss: 0.1332 - val_mean_squared_error: 0.0335
# Epoch 19/1000
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0039 - val_loss: 0.1268 - val_mean_squared_error: 0.0311
# predict: [[30.9894865  22.07969992]]
# real:      [[30.7 21.7]]
#
# Train on 1016 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.3533 - mean_squared_error: 0.2134 - val_loss: 0.1142 - val_mean_squared_error: 0.0194
# Epoch 2/1000
#  - 1s - loss: 0.0957 - mean_squared_error: 0.0143 - val_loss: 0.1098 - val_mean_squared_error: 0.0193
# Epoch 3/1000
#  - 1s - loss: 0.0723 - mean_squared_error: 0.0085 - val_loss: 0.1076 - val_mean_squared_error: 0.0204
# Epoch 4/1000
#  - 1s - loss: 0.0657 - mean_squared_error: 0.0070 - val_loss: 0.0938 - val_mean_squared_error: 0.0162
# Epoch 5/1000
#  - 1s - loss: 0.0634 - mean_squared_error: 0.0066 - val_loss: 0.0922 - val_mean_squared_error: 0.0119
# Epoch 6/1000
#  - 1s - loss: 0.0625 - mean_squared_error: 0.0063 - val_loss: 0.1098 - val_mean_squared_error: 0.0194
# Epoch 7/1000
#  - 1s - loss: 0.0642 - mean_squared_error: 0.0069 - val_loss: 0.0812 - val_mean_squared_error: 0.0095
# Epoch 8/1000
#  - 1s - loss: 0.0593 - mean_squared_error: 0.0058 - val_loss: 0.0904 - val_mean_squared_error: 0.0156
# Epoch 9/1000
#  - 1s - loss: 0.0540 - mean_squared_error: 0.0050 - val_loss: 0.0858 - val_mean_squared_error: 0.0133
# Epoch 10/1000
#  - 1s - loss: 0.0539 - mean_squared_error: 0.0052 - val_loss: 0.0824 - val_mean_squared_error: 0.0104
# Epoch 11/1000
#  - 1s - loss: 0.0529 - mean_squared_error: 0.0050 - val_loss: 0.0816 - val_mean_squared_error: 0.0119
# Epoch 12/1000
#  - 1s - loss: 0.0517 - mean_squared_error: 0.0047 - val_loss: 0.0776 - val_mean_squared_error: 0.0099
# Epoch 13/1000
#  - 1s - loss: 0.0507 - mean_squared_error: 0.0044 - val_loss: 0.0813 - val_mean_squared_error: 0.0088
# Epoch 14/1000
#  - 1s - loss: 0.0518 - mean_squared_error: 0.0046 - val_loss: 0.0810 - val_mean_squared_error: 0.0090
# Epoch 15/1000
#  - 1s - loss: 0.0492 - mean_squared_error: 0.0042 - val_loss: 0.0854 - val_mean_squared_error: 0.0140
# Epoch 16/1000
#  - 1s - loss: 0.0481 - mean_squared_error: 0.0041 - val_loss: 0.0861 - val_mean_squared_error: 0.0120
# Epoch 17/1000
#  - 1s - loss: 0.0477 - mean_squared_error: 0.0040 - val_loss: 0.0910 - val_mean_squared_error: 0.0164
# Epoch 18/1000
#  - 1s - loss: 0.0479 - mean_squared_error: 0.0042 - val_loss: 0.0877 - val_mean_squared_error: 0.0137
# Epoch 19/1000
#  - 1s - loss: 0.0483 - mean_squared_error: 0.0042 - val_loss: 0.0848 - val_mean_squared_error: 0.0098
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 20/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0039 - val_loss: 0.0844 - val_mean_squared_error: 0.0139
# Epoch 21/1000
#  - 1s - loss: 0.0460 - mean_squared_error: 0.0038 - val_loss: 0.0868 - val_mean_squared_error: 0.0131
# Epoch 22/1000
#  - 1s - loss: 0.0457 - mean_squared_error: 0.0038 - val_loss: 0.0855 - val_mean_squared_error: 0.0123
# predict: [[31.71134284 22.37593994]]
# real:      [[27.9 23. ]]
#
# Train on 1015 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.6262 - mean_squared_error: 0.6011 - val_loss: 0.1662 - val_mean_squared_error: 0.0332
# Epoch 2/1000
#  - 1s - loss: 0.1274 - mean_squared_error: 0.0297 - val_loss: 0.0477 - val_mean_squared_error: 0.0024
# Epoch 3/1000
#  - 1s - loss: 0.0822 - mean_squared_error: 0.0113 - val_loss: 0.1451 - val_mean_squared_error: 0.0237
# Epoch 4/1000
#  - 1s - loss: 0.0661 - mean_squared_error: 0.0071 - val_loss: 0.1209 - val_mean_squared_error: 0.0152
# Epoch 5/1000
#  - 1s - loss: 0.0634 - mean_squared_error: 0.0066 - val_loss: 0.0848 - val_mean_squared_error: 0.0081
# Epoch 6/1000
#  - 1s - loss: 0.0609 - mean_squared_error: 0.0060 - val_loss: 0.0899 - val_mean_squared_error: 0.0091
# Epoch 7/1000
#  - 1s - loss: 0.0612 - mean_squared_error: 0.0060 - val_loss: 0.0902 - val_mean_squared_error: 0.0093
# Epoch 8/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0058 - val_loss: 0.1006 - val_mean_squared_error: 0.0103
# Epoch 9/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0058 - val_loss: 0.0657 - val_mean_squared_error: 0.0043
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/1000
#  - 1s - loss: 0.0587 - mean_squared_error: 0.0056 - val_loss: 0.0873 - val_mean_squared_error: 0.0079
# Epoch 11/1000
#  - 1s - loss: 0.0578 - mean_squared_error: 0.0056 - val_loss: 0.0889 - val_mean_squared_error: 0.0083
# Epoch 12/1000
#  - 1s - loss: 0.0572 - mean_squared_error: 0.0054 - val_loss: 0.0824 - val_mean_squared_error: 0.0069
# predict: [[31.66452958 21.73451866]]
# real:      [[29.5 23. ]]
#
# Train on 1014 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0
# Epoch 5/1000
#  - 1s - loss: 0.0614 - mean_squared_error: 0.0060 - val_loss: 0.1858 - val_mean_squared_error: 0.0490
# Epoch 6/1000
#  - 1s - loss: 0.0587 - mean_squared_error: 0.0057 - val_loss: 0.2031 - val_mean_squared_error: 0.0587
# Epoch 7/1000
#  - 1s - loss: 0.0578 - mean_squared_error: 0.0054 - val_loss: 0.2129 - val_mean_squared_error: 0.0606
# Epoch 8/1000
#  - 1s - loss: 0.0556 - mean_squared_error: 0.0052 - val_loss: 0.2168 - val_mean_squared_error: 0.0639
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/1000
#  - 1s - loss: 0.0555 - mean_squared_error: 0.0051 - val_loss: 0.2151 - val_mean_squared_error: 0.0674
# Epoch 10/1000
#  - 1s - loss: 0.0546 - mean_squared_error: 0.0050 - val_loss: 0.2283 - val_mean_squared_error: 0.0744
# Epoch 11/1000
#  - 1s - loss: 0.0544 - mean_squared_error: 0.0050 - val_loss: 0.2228 - val_mean_squared_error: 0.0711
# predict: [[23.1719294  18.65898404]]
# real:      [[31.3 20.9]]
#
# Train on 1012 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.5228 - mean_squared_error: 0.3979 - val_loss: 0.3197 - val_mean_squared_error: 0.1052
# Epoch 2/1000
#  - 1s - loss: 0.1223 - mean_squared_error: 0.0228 - val_loss: 0.1279 - val_mean_squared_error: 0.0239
# Epoch 3/1000
#  - 1s - loss: 0.0694 - mean_squared_error: 0.0080 - val_loss: 0.1000 - val_mean_squared_error: 0.0111
# Epoch 4/1000
#  - 1s - loss: 0.0626 - mean_squared_error: 0.0065 - val_loss: 0.1056 - val_mean_squared_error: 0.0135
# Epoch 5/1000
#  - 1s - loss: 0.0620 - mean_squared_error: 0.0063 - val_loss: 0.0807 - val_mean_squared_error: 0.0074
# Epoch 6/1000
#  - 1s - loss: 0.0648 - mean_squared_error: 0.0068 - val_loss: 0.1027 - val_mean_squared_error: 0.0123
# Epoch 7/1000
#  - 1s - loss: 0.0644 - mean_squared_error: 0.0067 - val_loss: 0.0949 - val_mean_squared_error: 0.0110
# Epoch 8/1000
#  - 1s - loss: 0.0609 - mean_squared_error: 0.0061 - val_loss: 0.1160 - val_mean_squared_error: 0.0154
# Epoch 9/1000
#  - 1s - loss: 0.0601 - mean_squared_error: 0.0059 - val_loss: 0.1248 - val_mean_squared_error: 0.0174
# Epoch 10/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0059 - val_loss: 0.1049 - val_mean_squared_error: 0.0128
# Epoch 11/1000
#  - 1s - loss: 0.0623 - mean_squared_error: 0.0064 - val_loss: 0.1007 - val_mean_squared_error: 0.0115
# Epoch 12/1000
#  - 1s - loss: 0.0588 - mean_squared_error: 0.0058 - val_loss: 0.1232 - val_mean_squared_error: 0.0168
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 1s - loss: 0.0580 - mean_squared_error: 0.0056 - val_loss: 0.1236 - val_mean_squared_error: 0.0175
# Epoch 14/1000
#  - 1s - loss: 0.0577 - mean_squared_error: 0.0055 - val_loss: 0.1174 - val_mean_squared_error: 0.0157
# Epoch 15/1000
#  - 1s - loss: 0.0576 - mean_squared_error: 0.0055 - val_loss: 0.1187 - val_mean_squared_error: 0.0161
# predict: [[29.54918549 21.94343542]]
# real:      [[25.9 21.2]]
#
# Train on 1011 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.4812 - mean_squared_error: 0.3365 - val_loss: 0.2288 - val_mean_squared_error: 0.0551
# Epoch 2/1000
#  - 1s - loss: 0.0989 - mean_squared_error: 0.0150 - val_loss: 0.1160 - val_mean_squared_error: 0.0195
# Epoch 3/1000
#  - 1s - loss: 0.0690 - mean_squared_error: 0.0080 - val_loss: 0.0811 - val_mean_squared_error: 0.0093
# Epoch 4/1000
#  - 1s - loss: 0.0637 - mean_squared_error: 0.0067 - val_loss: 0.0481 - val_mean_squared_error: 0.0030
# Epoch 5/1000
#  - 1s - loss: 0.0638 - mean_squared_error: 0.0065 - val_loss: 0.0571 - val_mean_squared_error: 0.0033
# Epoch 6/1000
#  - 1s - loss: 0.0619 - mean_squared_error: 0.0062 - val_loss: 0.0657 - val_mean_squared_error: 0.0044
# Epoch 7/1000
#  - 1s - loss: 0.0613 - mean_squared_error: 0.0060 - val_loss: 0.0962 - val_mean_squared_error: 0.0094
# Epoch 8/1000
#  - 1s - loss: 0.0690 - mean_squared_error: 0.0076 - val_loss: 0.1167 - val_mean_squared_error: 0.0143
# Epoch 9/1000
#  - 1s - loss: 0.0638 - mean_squared_error: 0.0065 - val_loss: 0.0665 - val_mean_squared_error: 0.0044
# Epoch 10/1000
#  - 1s - loss: 0.0622 - mean_squared_error: 0.0064 - val_loss: 0.0755 - val_mean_squared_error: 0.0059
# Epoch 11/1000
#  - 1s - loss: 0.0596 - mean_squared_error: 0.0059 - val_loss: 0.0943 - val_mean_squared_error: 0.0095
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0595 - mean_squared_error: 0.0060 - val_loss: 0.0686 - val_mean_squared_error: 0.0049
# Epoch 13/1000
#  - 1s - loss: 0.0581 - mean_squared_error: 0.0056 - val_loss: 0.0718 - val_mean_squared_error: 0.0055
# Epoch 14/1000
#  - 1s - loss: 0.0577 - mean_squared_error: 0.0055 - val_loss: 0.0733 - val_mean_squared_error: 0.0058
# predict: [[32.25648555 22.00247803]]
# real:      [[29.2 21.1]]
#
# Train on 1010 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.9269 - mean_squared_error: 1.0125 - val_loss: 0.1861 - val_mean_squared_error: 0.0425
# Epoch 2/1000
#  - 1s - loss: 0.1396 - mean_squared_error: 0.0282 - val_loss: 0.1312 - val_mean_squared_error: 0.0172
# Epoch 3/1000
#  - 1s - loss: 0.0835 - mean_squared_error: 0.0108 - val_loss: 0.1158 - val_mean_squared_error: 0.0244
# Epoch 4/1000
#  - 1s - loss: 0.0603 - mean_squared_error: 0.0060 - val_loss: 0.1098 - val_mean_squared_error: 0.0219
# Epoch 5/1000
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0056 - val_loss: 0.0916 - val_mean_squared_error: 0.0141
# Epoch 6/1000
#  - 1s - loss: 0.0586 - mean_squared_error: 0.0057 - val_loss: 0.1037 - val_mean_squared_error: 0.0179
# Epoch 7/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0060 - val_loss: 0.1180 - val_mean_squared_error: 0.0271
# Epoch 8/1000
#  - 1s - loss: 0.0596 - mean_squared_error: 0.0059 - val_loss: 0.1162 - val_mean_squared_error: 0.0238
# Epoch 9/1000
#  - 1s - loss: 0.0578 - mean_squared_error: 0.0056 - val_loss: 0.1118 - val_mean_squared_error: 0.0232
# Epoch 10/1000
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0057 - val_loss: 0.1077 - val_mean_squared_error: 0.0215
# Epoch 11/1000
#  - 1s - loss: 0.0571 - mean_squared_error: 0.0054 - val_loss: 0.1023 - val_mean_squared_error: 0.0154
# Epoch 12/1000
#  - 1s - loss: 0.0638 - mean_squared_error: 0.0068 - val_loss: 0.0757 - val_mean_squared_error: 0.0099
# Epoch 13/1000
#  - 1s - loss: 0.0623 - mean_squared_error: 0.0064 - val_loss: 0.0717 - val_mean_squared_error: 0.0101
# Epoch 14/1000
#  - 1s - loss: 0.0623 - mean_squared_error: 0.0066 - val_loss: 0.0810 - val_mean_squared_error: 0.0101
# Epoch 15/1000
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0057 - val_loss: 0.1048 - val_mean_squared_error: 0.0173
# Epoch 16/1000
#  - 1s - loss: 0.0561 - mean_squared_error: 0.0052 - val_loss: 0.1269 - val_mean_squared_error: 0.0282
# Epoch 17/1000
#  - 1s - loss: 0.0576 - mean_squared_error: 0.0056 - val_loss: 0.1122 - val_mean_squared_error: 0.0221
# Epoch 18/1000
#  - 1s - loss: 0.0538 - mean_squared_error: 0.0050 - val_loss: 0.0958 - val_mean_squared_error: 0.0163
# Epoch 19/1000
#  - 1s - loss: 0.0513 - mean_squared_error: 0.0045 - val_loss: 0.1114 - val_mean_squared_error: 0.0229
# Epoch 20/1000
#  - 1s - loss: 0.0492 - mean_squared_error: 0.0042 - val_loss: 0.1230 - val_mean_squared_error: 0.0258
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 21/1000
#  - 1s - loss: 0.0486 - mean_squared_error: 0.0041 - val_loss: 0.1097 - val_mean_squared_error: 0.0240
# Epoch 22/1000
#  - 1s - loss: 0.0474 - mean_squared_error: 0.0040 - val_loss: 0.1199 - val_mean_squared_error: 0.0279
# Epoch 23/1000
#  - 1s - loss: 0.0471 - mean_squared_error: 0.0039 - val_loss: 0.1181 - val_mean_squared_error: 0.0270
# predict: [[30.31820446 22.93176233]]
# real:      [[31.1 21.7]]
#
# Train on 1009 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 1.2953 - mean_squared_error: 1.7626 - val_loss: 1.1014 - val_mean_squared_error: 1.3846
# Epoch 2/1000
#  - 1s - loss: 1.0830 - mean_squared_error: 1.6404 - val_loss: 0.9077 - val_mean_squared_error: 1.5491
# Epoch 3/1000
#  - 1s - loss: 0.9550 - mean_squared_error: 1.7120 - val_loss: 0.8499 - val_mean_squared_error: 1.4047
# Epoch 4/1000
#  - 1s - loss: 0.9226 - mean_squared_error: 1.6143 - val_loss: 0.8189 - val_mean_squared_error: 1.3251
# Epoch 5/1000
#  - 1s - loss: 0.8961 - mean_squared_error: 1.5244 - val_loss: 0.7932 - val_mean_squared_error: 1.2520
# Epoch 6/1000
#  - 1s - loss: 0.8715 - mean_squared_error: 1.4410 - val_loss: 0.7756 - val_mean_squared_error: 1.1826
# Epoch 7/1000
#  - 1s - loss: 0.8483 - mean_squared_error: 1.3651 - val_loss: 0.7478 - val_mean_squared_error: 1.1097
# Epoch 8/1000
#  - 1s - loss: 0.8280 - mean_squared_error: 1.2938 - val_loss: 0.7251 - val_mean_squared_error: 1.0494
# Epoch 9/1000
#  - 1s - loss: 0.8084 - mean_squared_error: 1.2263 - val_loss: 0.7293 - val_mean_squared_error: 1.0020
# Epoch 10/1000
#  - 1s - loss: 0.7850 - mean_squared_error: 1.1669 - val_loss: 0.6943 - val_mean_squared_error: 0.9406
# Epoch 11/1000
#  - 1s - loss: 0.7650 - mean_squared_error: 1.1083 - val_loss: 0.6670 - val_mean_squared_error: 0.8863
# Epoch 12/1000
#  - 1s - loss: 0.7463 - mean_squared_error: 1.0519 - val_loss: 0.6563 - val_mean_squared_error: 0.8385
# Epoch 13/1000
#  - 1s - loss: 0.7246 - mean_squared_error: 0.9984 - val_loss: 0.6499 - val_mean_squared_error: 0.7928
# Epoch 14/1000
#  - 1s - loss: 0.7092 - mean_squared_error: 0.9470 - val_loss: 0.6315 - val_mean_squared_error: 0.7463
# Epoch 15/1000
#  - 1s - loss: 0.6872 - mean_squared_error: 0.8960 - val_loss: 0.6034 - val_mean_squared_error: 0.7008
# Epoch 16/1000
#  - 1s - loss: 0.6692 - mean_squared_error: 0.8474 - val_loss: 0.5780 - val_mean_squared_error: 0.6583
# Epoch 17/1000
#  - 1s - loss: 0.6534 - mean_squared_error: 0.8006 - val_loss: 0.5700 - val_mean_squared_error: 0.6189
# Epoch 18/1000
#  - 1s - loss: 0.6371 - mean_squared_error: 0.7552 - val_loss: 0.5399 - val_mean_squared_error: 0.5771
# Epoch 19/1000
#  - 1s - loss: 0.6167 - mean_squared_error: 0.7104 - val_loss: 0.5354 - val_mean_squared_error: 0.5362
# Epoch 20/1000
#  - 1s - loss: 0.5934 - mean_squared_error: 0.6650 - val_loss: 0.5123 - val_mean_squared_error: 0.4983
# Epoch 21/1000
#  - 1s - loss: 0.5753 - mean_squared_error: 0.6208 - val_loss: 0.4940 - val_mean_squared_error: 0.4601
# Epoch 22/1000
#  - 1s - loss: 0.5543 - mean_squared_error: 0.5784 - val_loss: 0.4777 - val_mean_squared_error: 0.4217
# ...
# Epoch 4/1000
#  - 1s - loss: 0.0683 - mean_squared_error: 0.0073 - val_loss: 0.0670 - val_mean_squared_error: 0.0076
# Epoch 5/1000
#  - 1s - loss: 0.0624 - mean_squared_error: 0.0063 - val_loss: 0.0635 - val_mean_squared_error: 0.0063
# Epoch 6/1000
#  - 1s - loss: 0.0595 - mean_squared_error: 0.0058 - val_loss: 0.0397 - val_mean_squared_error: 0.0026
# Epoch 7/1000
#  - 1s - loss: 0.0589 - mean_squared_error: 0.0057 - val_loss: 0.0386 - val_mean_squared_error: 0.0028
# Epoch 8/1000
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0464 - val_mean_squared_error: 0.0034
samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.8913 - mean_squared_error: 1.0088 - val_loss: 0.2474 - val_mean_squared_error: 0.0829
# Epoch 2/1000
#  - 1s - loss: 0.1650 - mean_squared_error: 0.0445 - val_loss: 0.1598 - val_mean_squared_error: 0.0278
# Epoch 3/1000
#  - 1s - loss: 0.0824 - mean_squared_error: 0.0104 - val_loss: 0.0410 - val_mean_squared_error: 0.0024
# Epoch 4/1000
#  - 1s - loss: 0.0645 - mean_squared_error: 0.0068 - val_loss: 0.0457 - val_mean_squared_error: 0.0027
# Epoch 5/1000
#  - 1s - loss: 0.0615 - mean_squared_error: 0.0061 - val_loss: 0.0518 - val_mean_squared_error: 0.0053
# Epoch 6/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0058 - val_loss: 0.0418 - val_mean_squared_error: 0.0035
# Epoch 7/1000
#  - 1s - loss: 0.0592 - mean_squared_error: 0.0057 - val_loss: 0.0416 - val_mean_squared_error: 0.0029
# Epoch 8/1000
#  - 1s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0429 - val_mean_squared_error: 0.0023
# Epoch 9/1000
#  - 1s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0472 - val_mean_squared_error: 0.0026
# Epoch 10/1000
#  - 1s - loss: 0.0578 - mean_squared_error: 0.0055 - val_loss: 0.0456 - val_mean_squared_error: 0.0031
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 1s - loss: 0.0571 - mean_squared_error: 0.0054 - val_loss: 0.0462 - val_mean_squared_error: 0.0032
# Epoch 12/1000
#  - 1s - loss: 0.0570 - mean_squared_error: 0.0054 - val_loss: 0.0445 - val_mean_squared_error: 0.0030
# Epoch 13/1000
#  - 1s - loss: 0.0569 - mean_squared_error: 0.0054 - val_loss: 0.0462 - val_mean_squared_error: 0.0030
# predict: [[32.12605319 23.53735441]]
# real:      [[30.9 22.9]]
#
# Train on 1003 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.7752 - mean_squared_error: 0.7405 - val_loss: 0.2881 - val_mean_squared_error: 0.0853
# Epoch 2/1000
#  - 1s - loss: 0.1561 - mean_squared_error: 0.0344 - val_loss: 0.0892 - val_mean_squared_error: 0.0129
# Epoch 3/1000
#  - 1s - loss: 0.0795 - mean_squared_error: 0.0100 - val_loss: 0.0984 - val_mean_squared_error: 0.0100
# Epoch 4/1000
#  - 1s - loss: 0.0645 - mean_squared_error: 0.0066 - val_loss: 0.1046 - val_mean_squared_error: 0.0117
# Epoch 5/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0058 - val_loss: 0.0904 - val_mean_squared_error: 0.0083
# Epoch 6/1000
#  - 1s - loss: 0.0584 - mean_squared_error: 0.0056 - val_loss: 0.0873 - val_mean_squared_error: 0.0077
# Epoch 7/1000
#  - 1s - loss: 0.0567 - mean_squared_error: 0.0053 - val_loss: 0.0797 - val_mean_squared_error: 0.0064
# Epoch 8/1000
#  - 1s - loss: 0.0562 - mean_squared_error: 0.0052 - val_loss: 0.0689 - val_mean_squared_error: 0.0048
# Epoch 9/1000
#  - 1s - loss: 0.0556 - mean_squared_error: 0.0052 - val_loss: 0.0907 - val_mean_squared_error: 0.0083
# Epoch 10/1000
#  - 1s - loss: 0.0518 - mean_squared_error: 0.0047 - val_loss: 0.0869 - val_mean_squared_error: 0.0076
# Epoch 11/1000
#  - 1s - loss: 0.0503 - mean_squared_error: 0.0043 - val_loss: 0.1036 - val_mean_squared_error: 0.0107
# Epoch 12/1000
#  - 1s - loss: 0.0506 - mean_squared_error: 0.0044 - val_loss: 0.0693 - val_mean_squared_error: 0.0049
# Epoch 13/1000
#  - 1s - loss: 0.0501 - mean_squared_error: 0.0043 - val_loss: 0.0798 - val_mean_squared_error: 0.0064
# Epoch 14/1000
#  - 1s - loss: 0.0499 - mean_squared_error: 0.0043 - val_loss: 0.0874 - val_mean_squared_error: 0.0077
# Epoch 15/1000
#  - 1s - loss: 0.0496 - mean_squared_error: 0.0043 - val_loss: 0.0596 - val_mean_squared_error: 0.0039
# Epoch 16/1000
#  - 1s - loss: 0.0511 - mean_squared_error: 0.0044 - val_loss: 0.0875 - val_mean_squared_error: 0.0077
# Epoch 17/1000
#  - 1s - loss: 0.0489 - mean_squared_error: 0.0041 - val_loss: 0.0974 - val_mean_squared_error: 0.0095
# Epoch 18/1000
#  - 1s - loss: 0.0491 - mean_squared_error: 0.0042 - val_loss: 0.0833 - val_mean_squared_error: 0.0071
# Epoch 19/1000
#  - 1s - loss: 0.0483 - mean_squared_error: 0.0041 - val_loss: 0.0761 - val_mean_squared_error: 0.0060
# Epoch 20/1000
#  - 1s - loss: 0.0487 - mean_squared_error: 0.0041 - val_loss: 0.0894 - val_mean_squared_error: 0.0080
# Epoch 21/1000
#  - 1s - loss: 0.0480 - mean_squared_error: 0.0040 - val_loss: 0.0919 - val_mean_squared_error: 0.0085
# Epoch 22/1000
#  - 1s - loss: 0.0478 - mean_squared_error: 0.0041 - val_loss: 0.0819 - val_mean_squared_error: 0.0068
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 23/1000
#  - 1s - loss: 0.0473 - mean_squared_error: 0.0039 - val_loss: 0.0955 - val_mean_squared_error: 0.0091
# Epoch 24/1000
#  - 1s - loss: 0.0469 - mean_squared_error: 0.0039 - val_loss: 0.0917 - val_mean_squared_error: 0.0084
# Epoch 25/1000
#  - 1s - loss: 0.0470 - mean_squared_error: 0.0039 - val_loss: 0.0979 - val_mean_squared_error: 0.0096
# predict: [[30.81873073 22.29051309]]
# real:      [[31.2 23.2]]
#
# Train on 1002 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.4067 - mean_squared_error: 0.2729 - val_loss: 0.2215 - val_mean_squared_error: 0.0786
# Epoch 2/1000
#  - 1s - loss: 0.1201 - mean_squared_error: 0.0288 - val_loss: 0.1591 - val_mean_squared_error: 0.0435
# Epoch 3/1000
#  - 1s - loss: 0.0860 - mean_squared_error: 0.0118 - val_loss: 0.1522 - val_mean_squared_error: 0.0444
# Epoch 4/1000
#  - 1s - loss: 0.0688 - mean_squared_error: 0.0082 - val_loss: 0.1215 - val_mean_squared_error: 0.0282
# Epoch 5/1000
#  - 1s - loss: 0.0625 - mean_squared_error: 0.0063 - val_loss: 0.1274 - val_mean_squared_error: 0.0269
# Epoch 6/1000
#  - 1s - loss: 0.0600 - mean_squared_error: 0.0059 - val_loss: 0.0963 - val_mean_squared_error: 0.0160
# Epoch 7/1000
#  - 1s - loss: 0.0609 - mean_squared_error: 0.0059 - val_loss: 0.1135 - val_mean_squared_error: 0.0202
# Epoch 8/1000
#  - 1s - loss: 0.0594 - mean_squared_error: 0.0058 - val_loss: 0.1037 - val_mean_squared_error: 0.0198
# Epoch 9/1000
#  - 1s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.1080 - val_mean_squared_error: 0.0210
# Epoch 10/1000
#  - 1s - loss: 0.0589 - mean_squared_error: 0.0057 - val_loss: 0.1025 - val_mean_squared_error: 0.0193
# Epoch 11/1000
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0056 - val_loss: 0.1099 - val_mean_squared_error: 0.0206
# Epoch 12/1000
#  - 1s - loss: 0.0553 - mean_squared_error: 0.0051 - val_loss: 0.1019 - val_mean_squared_error: 0.0204
# Epoch 13/1000
#  - 1s - loss: 0.0542 - mean_squared_error: 0.0050 - val_loss: 0.1006 - val_mean_squared_error: 0.0163
#
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 14/1000
#  - 1s - loss: 0.0544 - mean_squared_error: 0.0049 - val_loss: 0.1105 - val_mean_squared_error: 0.0212
# Epoch 15/1000
#  - 1s - loss: 0.0530 - mean_squared_error: 0.0048 - val_loss: 0.1029 - val_mean_squared_error: 0.0202
# Epoch 16/1000
#  - 1s - loss: 0.0526 - mean_squared_error: 0.0048 - val_loss: 0.1057 - val_mean_squared_error: 0.0203
# predict: [[31.25763247 22.13924807]]
# real:      [[31.  21.1]]
#
# Train on 1001 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.9908 - mean_squared_error: 1.1682 - val_loss: 0.4799 - val_mean_squared_error: 0.3797
# Epoch 2/1000
#  - 1s - loss: 0.3002 - mean_squared_error: 0.1547 - val_loss: 0.2385 - val_mean_squared_error: 0.0589
# Epoch 3/1000
#  - 1s - loss: 0.0953 - mean_squared_error: 0.0144 - val_loss: 0.0455 - val_mean_squared_error: 0.0028
# Epoch 4/1000
#  - 1s - loss: 0.0689 - mean_squared_error: 0.0077 - val_loss: 0.0868 - val_mean_squared_error: 0.0121
# Epoch 5/1000
#  - 1s - loss: 0.0642 - mean_squared_error: 0.0065 - val_loss: 0.0709 - val_mean_squared_error: 0.0099
# Epoch 6/1000
#  - 1s - loss: 0.0624 - mean_squared_error: 0.0062 - val_loss: 0.0561 - val_mean_squared_error: 0.0060
# Epoch 7/1000
#  - 1s - loss: 0.0613 - mean_squared_error: 0.0060 - val_loss: 0.0642 - val_mean_squared_error: 0.0067
# Epoch 8/1000
#  - 1s - loss: 0.0605 - mean_squared_error: 0.0059 - val_loss: 0.0716 - val_mean_squared_error: 0.0099
# Epoch 9/1000
#  - 1s - loss: 0.0596 - mean_squared_error: 0.0057 - val_loss: 0.0726 - val_mean_squared_error: 0.0092
# Epoch 10/1000
#  - 1s - loss: 0.0592 - mean_squared_error: 0.0056 - val_loss: 0.0678 - val_mean_squared_error: 0.0080
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 1s - loss: 0.0582 - mean_squared_error: 0.0055 - val_loss: 0.0662 - val_mean_squared_error: 0.0084
# Epoch 12/1000
#  - 1s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0664 - val_mean_squared_error: 0.0081
# Epoch 13/1000
#  - 1s - loss: 0.0577 - mean_squared_error: 0.0054 - val_loss: 0.0630 - val_mean_squared_error: 0.0076
# predict: [[31.59054997 22.55852937]]
# real:      [[28.7 22.8]]
#
# Train on 1000 samples, validate on 1 samples
# Epoch 1/1000
#  - 3s - loss: 0.8128 - mean_squared_error: 0.7795 - val_loss: 0.1991 - val_mean_squared_error: 0.0615
# Epoch 2/1000
#  - 1s - loss: 0.1576 - mean_squared_error: 0.0383 - val_loss: 0.0281 - val_mean_squared_error: 8.0948e-04
# Epoch 3/1000
#  - 1s - loss: 0.0887 - mean_squared_error: 0.0127 - val_loss: 0.1349 - val_mean_squared_error: 0.0201
# Epoch 4/1000
#  - 1s - loss: 0.0675 - mean_squared_error: 0.0073 - val_loss: 0.0865 - val_mean_squared_error: 0.0092
# Epoch 5/1000
#  - 1s - loss: 0.0617 - mean_squared_error: 0.0062 - val_loss: 0.0740 - val_mean_squared_error: 0.0062
# Epoch 6/1000
#  - 1s - loss: 0.0597 - mean_squared_error: 0.0058 - val_loss: 0.0872 - val_mean_squared_error: 0.0084
# Epoch 7/1000
#  - 1s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0638 - val_mean_squared_error: 0.0047
# Epoch 8/1000
#  - 1s - loss: 0.0565 - mean_squared_error: 0.0053 - val_loss: 0.0904 - val_mean_squared_error: 0.0090
# Epoch 9/1000
#  - 1s - loss: 0.0552 - mean_squared_error: 0.0051 - val_loss: 0.0882 - val_mean_squared_error: 0.0080
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/1000
#  - 1s - loss: 0.0538 - mean_squared_error: 0.0049 - val_loss: 0.0920 - val_mean_squared_error: 0.0089
# Epoch 11/1000
#  - 0s - loss: 0.0529 - mean_squared_error: 0.0048 - val_loss: 0.0999 - val_mean_squared_error: 0.0106
# Epoch 12/1000
#  - 0s - loss: 0.0526 - mean_squared_error: 0.0048 - val_loss: 0.0930 - val_mean_squared_error: 0.0093
# predict: [[31.70117928 22.15477264]]
# real:      [[30.1 22.9]]

# %%
y_hats = result[0]
y_tests = result[1]

metrics(y_hats, y_tests)
# Out:
# Maximum metrics
# Test RMSE -------------------------- 2.314
# Test VARIANCE ---------------------- -1.698
# Test MAX-ERROR --------------------- 8.128
# Test MEAN-ABSOLUTE-ERROR ----------- 1.612
# Test MEDIAN-ABSOLUTE-ERROR --------- 1.103
#
# Accuracy
# 50.0% of predictions missed 1 point(s) or less
# 16.67% of predictions missed 2 point(s) or less
# 16.67% of predictions missed 3 point(s) or less
# 13.33% of predictions missed 4 point(s) or less
#
# Minimum metrics
# Test RMSE -------------------------- 0.9402
# Test VARIANCE ---------------------- -0.4759
# Test MAX-ERROR --------------------- 2.241
# Test MEAN-ABSOLUTE-ERROR ----------- 0.767
# Test MEDIAN-ABSOLUTE-ERROR --------- 0.693
#
# Accuracy
# 73.33% of predictions missed 1 point(s) or less
# 23.33% of predictions missed 2 point(s) or less
# 3.33% of predictions missed 3 point(s) or less
