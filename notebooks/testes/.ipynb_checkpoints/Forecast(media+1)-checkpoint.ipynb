# %%
# imports required for the algorithm
import os

from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from datetime import datetime
from math import sqrt
import numpy as np

from matplotlib import pyplot

from sklearn.metrics import mean_squared_error
from sklearn.metrics import explained_variance_score
from sklearn.metrics import max_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import median_absolute_error
from sklearn.metrics import r2_score
from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau
# Out:
# Using TensorFlow backend.

# %%
# path to load and save data
data_input_path = '../data_in/CE_Crateus.csv'
data_output_path = '../data_out/weather.csv'
data_output_path_npsave = '../data_out/weather.npy'

# %%
# transform date into appropriate format
def parse(x):
	return datetime.strptime(x, '%d/%m/%Y')

# %%
# load the input dataset and save like a output dataset
def format_dataset(data_input_path, output_path):
    try:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1')
    except:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1', skiprows=2)
    
    dataset.index.name = 'date'

    dataset.drop('Unnamed: 11', axis=1, inplace=True)
    dataset.drop('Estacao', axis=1, inplace=True)
    
    dataset['TempMinima'] = dataset['TempMinima'].shift(-1)
    dataset['Precipitacao'] = dataset['Precipitacao'].shift(-1)
    
    dataset.drop('Hora', axis=1, inplace=True)
    
    dataset = dataset.loc[~dataset.index.duplicated(keep='first')]
    
    # replaces first line NA values with next line value
    dataset.iloc[0,:].fillna(dataset.iloc[1,:], inplace=True)
    
    # replace all NA values with prev line value
    dataset.ffill(axis=0, inplace=True)

    # show the first 5 lines on the dataset
    print(dataset)
        
    # save file
    dataset.to_csv(output_path)

format_dataset(data_input_path, data_output_path)
# Out:
#             Precipitacao  TempMaxima  TempMinima  Insolacao  Evaporacao Piche  \
# date
# 2015-01-01           0.0        35.0        23.7        5.9              10.2
# 2015-01-02           0.0        35.8        23.0       10.6              10.2
# 2015-01-03          37.4        31.9        22.3        4.3               6.2
# 2015-01-04          12.4        27.3        20.7        1.9               3.5
# 2015-01-05          23.0        32.4        20.7        8.3               1.5
# ...                  ...         ...         ...        ...               ...
# 2018-04-26           0.0        31.0        20.8        8.9               0.5
# 2018-04-27           0.0        31.7        22.9       10.5               0.5
# 2018-04-28           0.0        31.3        21.5        9.5               0.5
# 2018-04-29           3.5        28.9        22.7        2.5               0.5
# 2018-04-30           0.4        28.9        21.9        2.5               0.5
#
#             Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media
# date
# 2015-01-01            28.76                   47.00                   2.633333
# 2015-01-02            26.72                   72.50                   1.866667
# 2015-01-03            26.32                   71.50                   1.600000
# 2015-01-04            23.50                   88.25                   2.266667
# 2015-01-05            26.64                   66.75                   3.166667
# ...                     ...                     ...                        ...
# 2018-04-26            25.66                   78.00                   1.286100
# 2018-04-27            26.26                   77.00                   1.800540
# 2018-04-28            26.38                   81.00                   1.028880
# 2018-04-29            24.64                   93.00                   1.543320
# 2018-04-30            24.64                   93.00                   2.057760
#
# [1091 rows x 8 columns]

# %%
# load dataset
def load_dataset(input_path):
    return read_csv(input_path, header=0, index_col=0)

dataset = load_dataset(data_output_path)
values = dataset.values

# %%
# plot each column in a graph
def plot_columns(values):
    groups = list(range(0,len(values[0])))
    i = 1
    
    pyplot.figure(dpi=120)
    for group in groups:
        pyplot.subplot(len(groups), 1, i)
        pyplot.plot(values[:, group])
        pyplot.title(dataset.columns[group], y=0.1, loc='right')
        i += 1
    pyplot.show()

plot_columns(values)

# %%
# convert series to supervised learning
def series_to_supervised(dataset, day):
    y_test = np.array([dataset.loc[day]['TempMaxima'], dataset.loc[day]['TempMinima']])
    y_test = y_test.reshape(1,2)
    
    dataset = dataset[:-1]
    
    x_test = np.array(dataset[-60:])
    x_test = x_test.reshape(1,60,8)
    
    lista = []
    
    for i in list(dataset.index):
        lista.append([dataset.loc[i]['TempMaxima'], dataset.loc[i]['TempMinima']])
    y_train = np.array(lista[60:])
    
    dataset = dataset[:-1]
    
    x_train = np.array(dataset[-60:])
    x_train = x_train.reshape(1,60,8)
    dataset = dataset[:-1]
    
    while len(dataset) >= 60:
        array_aux = np.array(dataset[-60:])
        array_aux = array_aux.reshape(1,60,8)
        x_train = np.concatenate((x_train, array_aux), axis=0)
        dataset = dataset[:-1]
    
    return (x_train, y_train, x_test, y_test)

# %%
# inner loop
def myLSTM(x_train, y_train, x_test, y_test, scaler):
    x_val = x_train[-1]
    y_val = y_train[-1]
    x_val = x_val.reshape(1,60,8)
    y_val = y_val.reshape(1,2)
    x_train = x_train[:-1]
    y_train = y_train[:-1]
    
    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dense(16, activation='relu'))   # worth it?
    model.add(Dense(2))
    model.compile(loss='mae', optimizer='adam', metrics=['mse'])
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')
    ]
    
    # fit network
    history = model.fit(x_train, y_train,
                        epochs=1000, 
                        batch_size=72, 
                        validation_data=(x_val, y_val), 
                        verbose=2, 
                        shuffle=True, 
                        callbacks=callbacks)
    
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()
    
    y = inverseScale(model, x_test, y_test, scaler)
    inv_y_hat = y[0]
    inv_y_test = y[1]
    
    print('\npredict: {}'.format(inv_y_hat))
    print('real:      {}\n'.format(inv_y_test))
    
    return model

# %%
def inverseScale(model, x_test, y_test, scaler):
    # make a prediction
    y_hat = model.predict(x_test)
    
    new_x_test = x_test[:,-1,:]
    new_x_test = new_x_test.reshape((x_test.shape[0], x_test.shape[2]))
    new_x_test = np.concatenate((new_x_test[:, 0:1], new_x_test[:, 3:]), axis=1)
    
    # invert scaling for forecast
    inv_y_hat = np.concatenate((y_hat, new_x_test), axis=1)
    inv_y_hat = scaler * inv_y_hat
    inv_y_hat = inv_y_hat[:,:2]
    
    # invert scaling for actual value
    new_test_y = y_test.reshape((len(y_test), 2))
    inv_y_test = np.concatenate((new_test_y, new_x_test), axis=1)
    inv_y_test = scaler * inv_y_test
    inv_y_test = inv_y_test[:,:2]
    
    return [inv_y_hat, inv_y_test]

# %%
# Nested Cross Validation
def NCV(dataset, days_to_predict, scaler):
    i = len(days_to_predict) - 1
    y_hats = []
    y_tests = []
    y_hats_max = []
    y_hats_min = []
    y_tests_max = []
    y_tests_min = []
    
    # outer loop
    while(i >= 0):
        data = series_to_supervised(dataset, days_to_predict[i])
        x_train = data[0]
        y_train = data[1]
        x_test = data[2]
        y_test = data[3]
        
        result = myLSTM(x_train, y_train, x_test, y_test, scaler)
        
        y_hats += result[0].tolist()
        y_tests += result[1].tolist()
        
        i -= 1
        dataset = dataset[:-1]
    
    for y in y_hats:
        y_hats_max += [y[0]]
        y_hats_min += [y[1]]
        
    for y in y_tests:
        y_tests_max += [y[0]]
        y_tests_min += [y[1]]
    
    rmse_max = sqrt(mean_squared_error(y_tests_max, y_hats_max))
    variance_max = explained_variance_score(y_tests_max, y_hats_max)
    maxError_max = max_error(y_tests_max, y_hats_max)
    meanAbsolutError_max = mean_absolute_error(y_tests_max, y_hats_max)
    medianAbsoluteError_max = median_absolute_error(y_tests_max, y_hats_max)
    
    rmse_min = sqrt(mean_squared_error(y_tests_min, y_hats_min))
    variance_min = explained_variance_score(y_tests_min, y_hats_min)
    maxError_min = max_error(y_tests_min, y_hats_min)
    meanAbsolutError_min = mean_absolute_error(y_tests_min, y_hats_min)
    medianAbsoluteError_min = median_absolute_error(y_tests_min, y_hats_min)
    
    print('Maximum temperature')
    print('Test RMSE -------------------------- {:.4}'.format(rmse_max))
    print('Test VARIANCE ---------------------- {:.4}'.format(variance_max))
    print('Test MAX-ERROR --------------------- {:.4}'.format(maxError_max))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError_max))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError_max))
    
    print('\nMinimum temperature')
    print('Test RMSE -------------------------- {:.4}'.format(rmse_min))
    print('Test VARIANCE ---------------------- {:.4}'.format(variance_min))
    print('Test MAX-ERROR --------------------- {:.4}'.format(maxError_min))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError_min))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError_min))

# %%
# to get index the last 30 days
days_to_predict = list(dataset.index[-30:])

mean_scaler = np.mean(values) + 1
dataset_scaled = dataset.div(mean_scaler)

NCV(dataset_scaled, days_to_predict, mean_scaler)
# Out:
# Train on 1029 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.8397 - mean_squared_error: 0.8439 - val_loss: 0.4013 - val_mean_squared_error: 0.1644
# Epoch 2/1000
#  - 0s - loss: 0.1548 - mean_squared_error: 0.0348 - val_loss: 0.1078 - val_mean_squared_error: 0.0137
# Epoch 3/1000
#  - 0s - loss: 0.0791 - mean_squared_error: 0.0095 - val_loss: 0.0726 - val_mean_squared_error: 0.0085
# Epoch 4/1000
#  - 0s - loss: 0.0655 - mean_squared_error: 0.0069 - val_loss: 0.0804 - val_mean_squared_error: 0.0117
# Epoch 5/1000
#  - 0s - loss: 0.0621 - mean_squared_error: 0.0063 - val_loss: 0.0934 - val_mean_squared_error: 0.0162
# Epoch 6/1000
#  - 0s - loss: 0.0602 - mean_squared_error: 0.0060 - val_loss: 0.0914 - val_mean_squared_error: 0.0161
# Epoch 7/1000
#  - 0s - loss: 0.0593 - mean_squared_error: 0.0058 - val_loss: 0.0881 - val_mean_squared_error: 0.0132
# Epoch 8/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0058 - val_loss: 0.0809 - val_mean_squared_error: 0.0115
# Epoch 9/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0844 - val_mean_squared_error: 0.0132
# Epoch 10/1000
#  - 0s - loss: 0.0591 - mean_squared_error: 0.0058 - val_loss: 0.0844 - val_mean_squared_error: 0.0118
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0856 - val_mean_squared_error: 0.0145
# Epoch 12/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0056 - val_loss: 0.0854 - val_mean_squared_error: 0.0138
# Epoch 13/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0056 - val_loss: 0.0844 - val_mean_squared_error: 0.0135
# predict: [[31.25045446 22.47195912]]
# real:      [[28.9 21.9]]
#
# Train on 1028 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.8215 - mean_squared_error: 0.8821 - val_loss: 0.2151 - val_mean_squared_error: 0.0539
# Epoch 2/1000
#  - 0s - loss: 0.1280 - mean_squared_error: 0.0291 - val_loss: 0.0951 - val_mean_squared_error: 0.0091
# Epoch 3/1000
#  - 0s - loss: 0.0685 - mean_squared_error: 0.0074 - val_loss: 0.0810 - val_mean_squared_error: 0.0073
# Epoch 4/1000
#  - 0s - loss: 0.0622 - mean_squared_error: 0.0064 - val_loss: 0.0518 - val_mean_squared_error: 0.0027
# Epoch 5/1000
#  - 0s - loss: 0.0609 - mean_squared_error: 0.0061 - val_loss: 0.0480 - val_mean_squared_error: 0.0024
# Epoch 6/1000
#  - 0s - loss: 0.0616 - mean_squared_error: 0.0061 - val_loss: 0.0674 - val_mean_squared_error: 0.0045
# Epoch 7/1000
#  - 0s - loss: 0.0608 - mean_squared_error: 0.0060 - val_loss: 0.0534 - val_mean_squared_error: 0.0029
# Epoch 8/1000
#  - 0s - loss: 0.0610 - mean_squared_error: 0.0060 - val_loss: 0.0543 - val_mean_squared_error: 0.0031
# Epoch 9/1000
#  - 0s - loss: 0.0606 - mean_squared_error: 0.0060 - val_loss: 0.0715 - val_mean_squared_error: 0.0051
# Epoch 10/1000
#  - 0s - loss: 0.0595 - mean_squared_error: 0.0058 - val_loss: 0.0646 - val_mean_squared_error: 0.0044
# Epoch 11/1000
#  - 0s - loss: 0.0591 - mean_squared_error: 0.0057 - val_loss: 0.0750 - val_mean_squared_error: 0.0056
# Epoch 12/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0587 - val_mean_squared_error: 0.0034
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 0s - loss: 0.0578 - mean_squared_error: 0.0055 - val_loss: 0.0618 - val_mean_squared_error: 0.0038
# Epoch 14/1000
#  - 0s - loss: 0.0577 - mean_squared_error: 0.0055 - val_loss: 0.0593 - val_mean_squared_error: 0.0035
# Epoch 15/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0561 - val_mean_squared_error: 0.0032
# predict: [[32.40365074 22.26428369]]
# real:      [[28.9 22.7]]
#
# Train on 1027 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.6966 - mean_squared_error: 0.6071 - val_loss: 0.2350 - val_mean_squared_error: 0.0678
# Epoch 2/1000
#  - 0s - loss: 0.1025 - mean_squared_error: 0.0171 - val_loss: 0.0256 - val_mean_squared_error: 9.2241e-04
# Epoch 3/1000
#  - 0s - loss: 0.0666 - mean_squared_error: 0.0069 - val_loss: 0.0409 - val_mean_squared_error: 0.0019
# Epoch 4/1000
#  - 0s - loss: 0.0608 - mean_squared_error: 0.0059 - val_loss: 0.0302 - val_mean_squared_error: 0.0018
# Epoch 5/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0058 - val_loss: 0.0290 - val_mean_squared_error: 8.8061e-04
# Epoch 6/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0056 - val_loss: 0.0328 - val_mean_squared_error: 0.0015
# Epoch 7/1000
#  - 0s - loss: 0.0593 - mean_squared_error: 0.0057 - val_loss: 0.0210 - val_mean_squared_error: 7.3097e-04
# Epoch 8/1000
#  - 0s - loss: 0.0594 - mean_squared_error: 0.0059 - val_loss: 0.0364 - val_mean_squared_error: 0.0019
# Epoch 9/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0288 - val_mean_squared_error: 0.0014
# Epoch 10/1000
#  - 0s - loss: 0.0567 - mean_squared_error: 0.0054 - val_loss: 0.0428 - val_mean_squared_error: 0.0028
# Epoch 11/1000
#  - 0s - loss: 0.0546 - mean_squared_error: 0.0050 - val_loss: 0.0509 - val_mean_squared_error: 0.0041
# Epoch 12/1000
#  - 0s - loss: 0.0538 - mean_squared_error: 0.0049 - val_loss: 0.0582 - val_mean_squared_error: 0.0059
# Epoch 13/1000
#  - 0s - loss: 0.0530 - mean_squared_error: 0.0050 - val_loss: 0.0220 - val_mean_squared_error: 4.8611e-04
# Epoch 14/1000
#  - 0s - loss: 0.0567 - mean_squared_error: 0.0054 - val_loss: 0.0562 - val_mean_squared_error: 0.0061
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 0s - loss: 0.0526 - mean_squared_error: 0.0049 - val_loss: 0.0328 - val_mean_squared_error: 0.0021
# Epoch 16/1000
#  - 0s - loss: 0.0509 - mean_squared_error: 0.0046 - val_loss: 0.0411 - val_mean_squared_error: 0.0034
# Epoch 17/1000
#  - 0s - loss: 0.0503 - mean_squared_error: 0.0045 - val_loss: 0.0350 - val_mean_squared_error: 0.0024
# predict: [[32.12199305 22.78765944]]
# real:      [[31.3 21.5]]
#
# Train on 1026 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.1434 - mean_squared_error: 1.4823 - val_loss: 0.8339 - val_mean_squared_error: 1.2204
# Epoch 2/1000
#  - 0s - loss: 0.7547 - mean_squared_error: 1.0390 - val_loss: 0.5358 - val_mean_squared_error: 0.4691
# Epoch 3/1000
#  - 0s - loss: 0.3608 - mean_squared_error: 0.2637 - val_loss: 0.0956 - val_mean_squared_error: 0.0100
# Epoch 4/1000
#  - 0s - loss: 0.0938 - mean_squared_error: 0.0152 - val_loss: 0.0649 - val_mean_squared_error: 0.0042
# Epoch 5/1000
#  - 0s - loss: 0.0746 - mean_squared_error: 0.0091 - val_loss: 0.1494 - val_mean_squared_error: 0.0234
# Epoch 6/1000
#  - 0s - loss: 0.0661 - mean_squared_error: 0.0072 - val_loss: 0.1131 - val_mean_squared_error: 0.0129
# Epoch 7/1000
#  - 0s - loss: 0.0624 - mean_squared_error: 0.0064 - val_loss: 0.1116 - val_mean_squared_error: 0.0125
# Epoch 8/1000
#  - 0s - loss: 0.0615 - mean_squared_error: 0.0062 - val_loss: 0.1015 - val_mean_squared_error: 0.0105
# Epoch 9/1000
#  - 0s - loss: 0.0598 - mean_squared_error: 0.0059 - val_loss: 0.0834 - val_mean_squared_error: 0.0070
# Epoch 10/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0895 - val_mean_squared_error: 0.0080
# Epoch 11/1000
#  - 0s - loss: 0.0588 - mean_squared_error: 0.0057 - val_loss: 0.0826 - val_mean_squared_error: 0.0069
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0923 - val_mean_squared_error: 0.0087
# Epoch 13/1000
#  - 0s - loss: 0.0582 - mean_squared_error: 0.0056 - val_loss: 0.0923 - val_mean_squared_error: 0.0085
# Epoch 14/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0900 - val_mean_squared_error: 0.0081
# predict: [[32.53126166 21.7536415 ]]
# real:      [[31.7 22.9]]
#
# Train on 1025 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.7110 - mean_squared_error: 0.8564 - val_loss: 0.1735 - val_mean_squared_error: 0.0315
# Epoch 2/1000
#  - 0s - loss: 0.1188 - mean_squared_error: 0.0293 - val_loss: 0.1225 - val_mean_squared_error: 0.0232
# Epoch 3/1000
#  - 0s - loss: 0.0698 - mean_squared_error: 0.0081 - val_loss: 0.1021 - val_mean_squared_error: 0.0109
# Epoch 4/1000
#  - 0s - loss: 0.0618 - mean_squared_error: 0.0063 - val_loss: 0.0938 - val_mean_squared_error: 0.0097
# Epoch 5/1000
#  - 0s - loss: 0.0597 - mean_squared_error: 0.0060 - val_loss: 0.0977 - val_mean_squared_error: 0.0098
# Epoch 6/1000
#  - 0s - loss: 0.0594 - mean_squared_error: 0.0060 - val_loss: 0.0806 - val_mean_squared_error: 0.0068
# Epoch 7/1000
#  - 0s - loss: 0.0595 - mean_squared_error: 0.0059 - val_loss: 0.0764 - val_mean_squared_error: 0.0063
# Epoch 8/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0057 - val_loss: 0.0885 - val_mean_squared_error: 0.0079
# Epoch 9/1000
#  - 0s - loss: 0.0580 - mean_squared_error: 0.0056 - val_loss: 0.1040 - val_mean_squared_error: 0.0113
# Epoch 10/1000
#  - 0s - loss: 0.0581 - mean_squared_error: 0.0057 - val_loss: 0.0880 - val_mean_squared_error: 0.0078
# Epoch 11/1000
#  - 0s - loss: 0.0578 - mean_squared_error: 0.0055 - val_loss: 0.1112 - val_mean_squared_error: 0.0127
# Epoch 12/1000
#  - 0s - loss: 0.0575 - mean_squared_error: 0.0055 - val_loss: 0.0968 - val_mean_squared_error: 0.0097
# Epoch 13/1000
#  - 0s - loss: 0.0565 - mean_squared_error: 0.0054 - val_loss: 0.0914 - val_mean_squared_error: 0.0085
# Epoch 14/1000
#  - 0s - loss: 0.0558 - mean_squared_error: 0.0052 - val_loss: 0.1465 - val_mean_squared_error: 0.0223
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch
#  - 0s - loss: 0.0490 - mean_squared_error: 0.0043 - val_loss: 0.0654 - val_mean_squared_error: 0.0070
# Epoch 16/1000
#  - 0s - loss: 0.0488 - mean_squared_error: 0.0042 - val_loss: 0.0710 - val_mean_squared_error: 0.0072
# Epoch 17/1000
#  - 0s - loss: 0.0491 - mean_squared_error: 0.0043 - val_loss: 0.1024 - val_mean_squared_error: 0.0130
# Epoch 18/1000
#  - 0s - loss: 0.0514 - mean_squared_error: 0.0046 - val_loss: 0.0949 - val_mean_squared_error: 0.0107
#
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 19/1000
#  - 0s - loss: 0.0514 - mean_squared_error: 0.0046 - val_loss: 0.0594 - val_mean_squared_error: 0.0056
# Epoch 20/1000
#  - 0s - loss: 0.0483 - mean_squared_error: 0.0042 - val_loss: 0.0731 - val_mean_squared_error: 0.0074
# Epoch 21/1000
#  - 0s - loss: 0.0473 - mean_squared_error: 0.0041 - val_loss: 0.0768 - val_mean_squared_error: 0.0078
# predict: [[31.30201071 21.58255754]]
# real:      [[30.6 21.7]]
#
# Train on 1022 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.1515 - mean_squared_error: 1.6963 - val_loss: 0.7592 - val_mean_squared_error: 1.0078
# Epoch 2/1000
#  - 0s - loss: 0.7093 - mean_squared_error: 0.9330 - val_loss: 0.4331 - val_mean_squared_error: 0.3469
# Epoch 3/1000
#  - 0s - loss: 0.3640 - mean_squared_error: 0.2618 - val_loss: 0.0128 - val_mean_squared_error: 1.8663e-04
# Epoch 4/1000
#  - 0s - loss: 0.0734 - mean_squared_error: 0.0092 - val_loss: 0.0672 - val_mean_squared_error: 0.0079
# Epoch 5/1000
#  - 0s - loss: 0.0632 - mean_squared_error: 0.0065 - val_loss: 0.0936 - val_mean_squared_error: 0.0128
# Epoch 6/1000
#  - 0s - loss: 0.0630 - mean_squared_error: 0.0064 - val_loss: 0.0537 - val_mean_squared_error: 0.0051
# Epoch 7/1000
#  - 0s - loss: 0.0598 - mean_squared_error: 0.0058 - val_loss: 0.0791 - val_mean_squared_error: 0.0078
# Epoch 8/1000
#  - 0s - loss: 0.0614 - mean_squared_error: 0.0061 - val_loss: 0.0438 - val_mean_squared_error: 0.0038
# Epoch 9/1000
#  - 0s - loss: 0.0606 - mean_squared_error: 0.0060 - val_loss: 0.0600 - val_mean_squared_error: 0.0068
# Epoch 10/1000
#  - 0s - loss: 0.0594 - mean_squared_error: 0.0057 - val_loss: 0.0730 - val_mean_squared_error: 0.0074
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0594 - mean_squared_error: 0.0057 - val_loss: 0.0695 - val_mean_squared_error: 0.0073
# Epoch 12/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0056 - val_loss: 0.0609 - val_mean_squared_error: 0.0072
# Epoch 13/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0632 - val_mean_squared_error: 0.0071
# predict: [[30.31957019 22.74225691]]
# real:      [[30.3 22.3]]
#
# Train on 1021 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.0794 - mean_squared_error: 1.3642 - val_loss: 0.5346 - val_mean_squared_error: 0.4514
# Epoch 2/1000
#  - 0s - loss: 0.3101 - mean_squared_error: 0.2138 - val_loss: 0.1627 - val_mean_squared_error: 0.0465
# Epoch 3/1000
#  - 0s - loss: 0.0975 - mean_squared_error: 0.0152 - val_loss: 0.0694 - val_mean_squared_error: 0.0050
# Epoch 4/1000
#  - 0s - loss: 0.0702 - mean_squared_error: 0.0079 - val_loss: 0.0958 - val_mean_squared_error: 0.0148
# Epoch 5/1000
#  - 0s - loss: 0.0639 - mean_squared_error: 0.0065 - val_loss: 0.0603 - val_mean_squared_error: 0.0072
# Epoch 6/1000
#  - 0s - loss: 0.0609 - mean_squared_error: 0.0061 - val_loss: 0.0545 - val_mean_squared_error: 0.0059
# Epoch 7/1000
#  - 0s - loss: 0.0597 - mean_squared_error: 0.0058 - val_loss: 0.0488 - val_mean_squared_error: 0.0046
# Epoch 8/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0057 - val_loss: 0.0439 - val_mean_squared_error: 0.0029
# Epoch 9/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0529 - val_mean_squared_error: 0.0053
# Epoch 10/1000
#  - 0s - loss: 0.0588 - mean_squared_error: 0.0057 - val_loss: 0.0637 - val_mean_squared_error: 0.0055
# Epoch 11/1000
#  - 0s - loss: 0.0591 - mean_squared_error: 0.0057 - val_loss: 0.0509 - val_mean_squared_error: 0.0052
# Epoch 12/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0058 - val_loss: 0.0536 - val_mean_squared_error: 0.0043
# Epoch 13/1000
#  - 0s - loss: 0.0592 - mean_squared_error: 0.0058 - val_loss: 0.0530 - val_mean_squared_error: 0.0046
# Epoch 14/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0480 - val_mean_squared_error: 0.0040
# Epoch 15/1000
#  - 0s - loss: 0.0582 - mean_squared_error: 0.0056 - val_loss: 0.0459 - val_mean_squared_error: 0.0030
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0479 - val_mean_squared_error: 0.0043
# Epoch 17/1000
#  - 0s - loss: 0.0575 - mean_squared_error: 0.0055 - val_loss: 0.0519 - val_mean_squared_error: 0.0044
# Epoch 18/1000
#  - 0s - loss: 0.0575 - mean_squared_error: 0.0055 - val_loss: 0.0468 - val_mean_squared_error: 0.0042
# predict: [[32.2522772  23.10257368]]
# real:      [[30.  23.1]]
#
# Train on 1020 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.3166 - mean_squared_error: 1.7721 - val_loss: 1.1913 - val_mean_squared_error: 1.4452
# Epoch 2/1000
#  - 0s - loss: 1.0694 - mean_squared_error: 1.1964 - val_loss: 0.6135 - val_mean_squared_error: 0.4700
# Epoch 3/1000
#  - 0s - loss: 0.5304 - mean_squared_error: 0.4064 - val_loss: 0.4353 - val_mean_squared_error: 0.3120
# Epoch 4/1000
#  - 0s - loss: 0.4184 - mean_squared_error: 0.2850 - val_loss: 0.4124 - val_mean_squared_error: 0.2178
# Epoch 5/1000
#  - 0s - loss: 0.3332 - mean_squared_error: 0.1808 - val_loss: 0.3063 - val_mean_squared_error: 0.1217
# Epoch 6/1000
#  - 0s - loss: 0.0599 - mean_squared_error: 0.0059 - val_loss: 0.1907 - val_mean_squared_error: 0.0518
# Epoch 11/1000
#  - 0s - loss: 0.0581 - mean_squared_error: 0.0056 - val_loss: 0.1908 - val_mean_squared_error: 0.0513
# Epoch 12/1000
#  - 0s - loss: 0.0620 - mean_squared_error: 0.0061 - val_loss: 0.2225 - val_mean_squared_error: 0.0636
# Epoch 13/1000
#  - 0s - loss: 0.0576 - mean_squared_error: 0.0055 - val_loss: 0.1801 - val_mean_squared_error: 0.0494
# Epoch 14/1000
#  - 0s - loss: 0.0598 - mean_squared_error: 0.0058 - val_loss: 0.2372 - val_mean_squared_error: 0.0681
# Epoch 15/1000
#  - 0s - loss: 0.0569 - mean_squared_error: 0.0055 - val_loss: 0.2143 - val_mean_squared_error: 0.0635
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 0s - loss: 0.0549 - mean_squared_error: 0.0052 - val_loss: 0.2216 - val_mean_squared_error: 0.0645
# Epoch 17/1000
#  - 0s - loss: 0.0545 - mean_squared_error: 0.0050 - val_loss: 0.2123 - val_mean_squared_error: 0.0593
# Epoch 18/1000
#  - 0s - loss: 0.0544 - mean_squared_error: 0.0050 - val_loss: 0.2214 - val_mean_squared_error: 0.0639
# predict: [[30.53885961 21.12453427]]
# real:      [[31.3 20.9]]
#
# Train on 1012 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.6490 - mean_squared_error: 0.6349 - val_loss: 0.3786 - val_mean_squared_error: 0.1437
# Epoch 2/1000
#  - 0s - loss: 0.1277 - mean_squared_error: 0.0251 - val_loss: 0.1740 - val_mean_squared_error: 0.0335
# Epoch 3/1000
#  - 0s - loss: 0.0741 - mean_squared_error: 0.0086 - val_loss: 0.1213 - val_mean_squared_error: 0.0180
# Epoch 4/1000
#  - 0s - loss: 0.0641 - mean_squared_error: 0.0066 - val_loss: 0.1359 - val_mean_squared_error: 0.0201
# Epoch 5/1000
#  - 0s - loss: 0.0624 - mean_squared_error: 0.0063 - val_loss: 0.1271 - val_mean_squared_error: 0.0177
# Epoch 6/1000
#  - 0s - loss: 0.0623 - mean_squared_error: 0.0062 - val_loss: 0.1253 - val_mean_squared_error: 0.0166
# Epoch 7/1000
#  - 0s - loss: 0.0615 - mean_squared_error: 0.0062 - val_loss: 0.1242 - val_mean_squared_error: 0.0174
# Epoch 8/1000
#  - 0s - loss: 0.0620 - mean_squared_error: 0.0063 - val_loss: 0.1225 - val_mean_squared_error: 0.0165
# Epoch 9/1000
#  - 0s - loss: 0.0613 - mean_squared_error: 0.0061 - val_loss: 0.1392 - val_mean_squared_error: 0.0204
# Epoch 10/1000
#  - 0s - loss: 0.0623 - mean_squared_error: 0.0063 - val_loss: 0.1270 - val_mean_squared_error: 0.0177
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0601 - mean_squared_error: 0.0059 - val_loss: 0.1320 - val_mean_squared_error: 0.0193
# Epoch 12/1000
#  - 0s - loss: 0.0594 - mean_squared_error: 0.0058 - val_loss: 0.1338 - val_mean_squared_error: 0.0206
# Epoch 13/1000
#  - 0s - loss: 0.0593 - mean_squared_error: 0.0059 - val_loss: 0.1300 - val_mean_squared_error: 0.0190
# predict: [[31.0486019  20.76257387]]
# real:      [[25.9 21.2]]
#
# Train on 1011 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss:
samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 1.0007 - mean_squared_error: 1.2543 - val_loss: 0.3822 - val_mean_squared_error: 0.2029
# Epoch 2/1000
#  - 0s - loss: 0.2420 - mean_squared_error: 0.1400 - val_loss: 0.2328 - val_mean_squared_error: 0.0972
# Epoch 3/1000
#  - 0s - loss: 0.0844 - mean_squared_error: 0.0118 - val_loss: 0.1006 - val_mean_squared_error: 0.0191
# Epoch 4/1000
#  - 0s - loss: 0.0631 - mean_squared_error: 0.0066 - val_loss: 0.1181 - val_mean_squared_error: 0.0252
# Epoch 5/1000
#  - 0s - loss: 0.0599 - mean_squared_error: 0.0059 - val_loss: 0.1224 - val_mean_squared_error: 0.0268
# Epoch 6/1000
#  - 0s - loss: 0.0628 - mean_squared_error: 0.0065 - val_loss: 0.1109 - val_mean_squared_error: 0.0229
# Epoch 7/1000
#  - 0s - loss: 0.0584 - mean_squared_error: 0.0057 - val_loss: 0.1173 - val_mean_squared_error: 0.0225
# Epoch 8/1000
#  - 0s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.1051 - val_mean_squared_error: 0.0175
# Epoch 9/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.1107 - val_mean_squared_error: 0.0199
# Epoch 10/1000
#  - 0s - loss: 0.0574 - mean_squared_error: 0.0054 - val_loss: 0.1291 - val_mean_squared_error: 0.0318
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0060 - val_loss: 0.1095 - val_mean_squared_error: 0.0201
# Epoch 12/1000
#  - 0s - loss: 0.0572 - mean_squared_error: 0.0054 - val_loss: 0.1001 - val_mean_squared_error: 0.0195
# Epoch 13/1000
#  - 0s - loss: 0.0564 - mean_squared_error: 0.0053 - val_loss: 0.1095 - val_mean_squared_error: 0.0224
# Epoch 14/1000
#  - 0s - loss: 0.0565 - mean_squared_error: 0.0054 - val_loss: 0.1101 - val_mean_squared_error: 0.0220
# Epoch 15/1000
#  - 0s - loss: 0.0562 - mean_squared_error: 0.0053 - val_loss: 0.1060 - val_mean_squared_error: 0.0200
# Epoch 16/1000
#  - 0s - loss: 0.0567 - mean_squared_error: 0.0053 - val_loss: 0.1069 - val_mean_squared_error: 0.0216
# Epoch 17/1000
#  - 0s - loss: 0.0563 - mean_squared_error: 0.0053 - val_loss: 0.1075 - val_mean_squared_error: 0.0211
# Epoch 18/1000
#  - 0s - loss: 0.0561 - mean_squared_error: 0.0053 - val_loss: 0.1065 - val_mean_squared_error: 0.0210
# Epoch 19/1000
#  - 0s - loss: 0.0560 - mean_squared_error: 0.0052 - val_loss: 0.1070 - val_mean_squared_error: 0.0212
#
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 20/1000
#  - 0s - loss: 0.0560 - mean_squared_error: 0.0053 - val_loss: 0.1066 - val_mean_squared_error: 0.0214
# Epoch 21/1000
#  - 0s - loss: 0.0560 - mean_squared_error: 0.0053 - val_loss: 0.1061 - val_mean_squared_error: 0.0213
# Epoch 22/1000
#  - 0s - loss: 0.0560 - mean_squared_error: 0.0053 - val_loss: 0.1063 - val_mean_squared_error: 0.0213
# predict: [[31.52057227 22.78376871]]
# real:      [[31.1 21.7]]
#
# Train on 1009 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.7040 - mean_squared_error: 0.6703 - val_loss: 0.1296 - val_mean_squared_error: 0.0297
# Epoch 2/1000
#  - 0s - loss: 0.1673 - mean_squared_error: 0.0421 - val_loss: 0.0235 - val_mean_squared_error: 0.0011
# Epoch 3/1000
#  - 0s - loss: 0.0865 - mean_squared_error: 0.0121 - val_loss: 0.0874 - val_mean_squared_error: 0.0135
# Epoch 4/1000
#  - 0s - loss: 0.0689 - mean_squared_error: 0.0077 - val_loss: 0.0763 - val_mean_squared_error: 0.0081
# Epoch 5/1000
#  - 0s - loss: 0.0667 - mean_squared_error: 0.0073 - val_loss: 0.0930 - val_mean_squared_error: 0.0109
# Epoch 6/1000
#  - 0s - loss: 0.0694 - mean_squared_error: 0.0078 - val_loss: 0.0637 - val_mean_squared_error: 0.0071
# Epoch 7/1000
#  - 0s - loss: 0.0642 - mean_squared_error: 0.0068 - val_loss: 0.0791 - val_mean_squared_error: 0.0082
# Epoch 8/1000
#  - 0s - loss: 0.0664 - mean_squared_error: 0.0072 - val_loss: 0.0575 - val_mean_squared_error: 0.0052
# Epoch 9/1000
#  - 0s - loss: 0.0616 - mean_squared_error: 0.0062 - val_loss: 0.0310 - val_mean_squared_error: 0.0018
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/1000
#  - 0s - loss: 0.0630 - mean_squared_error: 0.0063 - val_loss: 0.0466 - val_mean_squared_error: 0.0033
# Epoch 11/1000
#  - 0s - loss: 0.0613 - mean_squared_error: 0.0063 - val_loss: 0.0655 - val_mean_squared_error: 0.0056
# Epoch 12/1000
#  - 0s - loss: 0.0611 - mean_squared_error: 0.0063 - val_loss: 0.0544 - val_mean_squared_error: 0.0043
# predict: [[31.75739647 21.46735198]]
# real:      [[28.7 23.2]]
#
# Train on 1008 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.3954 - mean_squared_error: 0.2534 - val_loss: 0.2132 - val_mean_squared_error: 0.0457
# Epoch 2/1000
#  - 0s - loss: 0.1044 - mean_squared_error: 0.0164 - val_loss: 0.1041 - val_mean_squared_error: 0.0193
# Epoch 3/1000
#  - 0s - loss: 0.0697 - mean_squared_error: 0.0079 - val_loss: 0.0670 - val_mean_squared_error: 0.0054
# Epoch 4/1000
#  - 0s - loss: 0.0642 - mean_squared_error: 0.0067 - val_loss: 0.0507 - val_mean_squared_error: 0.0045
# Epoch 5/1000
#  - 0s - loss: 0.0618 - mean_squared_error: 0.0062 - val_loss: 0.0550 - val_mean_squared_error: 0.0045
# Epoch 6/1000
#  - 0s - loss: 0.0603 - mean_squared_error: 0.0060 - val_loss: 0.0639 - val_mean_squared_error: 0.0051
# Epoch 7/1000
#  - 0s - loss: 0.0596 - mean_squared_error: 0.0058 - val_loss: 0.0657 - val_mean_squared_error: 0.0058
# Epoch 8/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0718 - val_mean_squared_error: 0.0060
# Epoch 9/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0057 - val_loss: 0.0976 - val_mean_squared_error: 0.0105
# Epoch 10/1000
#  - 0s - loss: 0.0576 - mean_squared_error: 0.0056 - val_loss: 0.0605 - val_mean_squared_error: 0.0044
# Epoch 11/1000
#  - 0s - loss: 0.0552 - mean_squared_error: 0.0051 - val_loss: 0.0484 - val_mean_squared_error: 0.0031
# Epoch 12/1000
#  - 0s - loss: 0.0519 - mean_squared_error: 0.0047 - val_loss: 0.0636 - val_mean_squared_error: 0.0050
# Epoch 13/1000
#  - 0s - loss: 0.0511 - mean_squared_error: 0.0045 - val_loss: 0.0410 - val_mean_squared_error: 0.0025
# Epoch 14/1000
#  - 0s - loss: 0.0481 - mean_squared_error: 0.0041 - val_loss: 0.0391 - val_mean_squared_error: 0.0021
# Epoch 15/1000
# ...
# Epoch 9/1000
#  - 0s - loss: 0.0577 - mean_squared_error: 0.0055 - val_loss: 0.0412 - val_mean_squared_error: 0.0032
# Epoch 10/1000
#  - 0s - loss: 0.0576 - mean_squared_error: 0.0055 - val_loss: 0.0480 - val_mean_squared_error: 0.0038
# Epoch 11/1000
#  - 0s - loss: 0.0567 - mean_squared_error: 0.0053 - val_loss: 0.0503 - val_mean_squared_error: 0.0041
# Epoch 12/1000
#  - 0s - loss: 0.0559 - mean_squared_error: 0.0052 - val_loss: 0.0539 - val_mean_squared_error: 0.0047
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 13/1000
#  - 0s - loss: 0.0550 - mean_squared_error: 0.0051 - val_loss: 0.0533 - val_mean_squared_error: 0.0048
# Epoch 14/1000
#  - 0s - loss: 0.0549 - mean_squared_error: 0.0050 - val_loss: 0.0509 - val_mean_squared_error: 0.0047
# Epoch 15/1000
#  - 0s - loss: 0.0547 - mean_squared_error: 0.0050 - val_loss: 0.0519 - val_mean_squared_error: 0.0047
# predict: [[31.81125011 22.44912287]]
# real:      [[31.1 22.3]]
#
# Train on 1006 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 1.3007 - mean_squared_error: 2.0064 - val_loss: 0.9617 - val_mean_squared_error: 1.2545
# Epoch 2/1000
#  - 0s - loss: 0.8093 - mean_squared_error: 1.0751 - val_loss: 0.5920 - val_mean_squared_error: 0.5944
# Epoch 3/1000
#  - 0s - loss: 0.5082 - mean_squared_error: 0.4593 - val_loss: 0.3624 - val_mean_squared_error: 0.1839
# Epoch 4/1000
#  - 0s - loss: 0.3870 - mean_squared_error: 0.2354 - val_loss: 0.2819 - val_mean_squared_error: 0.1554
# Epoch 5/1000
#  - 0s - loss: 0.3271 - mean_squared_error: 0.1763 - val_loss: 0.2309 - val_mean_squared_error: 0.0820
# Epoch 6/1000
#  - 0s - loss: 0.2640 - mean_squared_error: 0.1088 - val_loss: 0.1653 - val_mean_squared_error: 0.0361
# Epoch 7/1000
#  - 0s - loss: 0.1925 - mean_squared_error: 0.0519 - val_loss: 0.0885 - val_mean_squared_error: 0.0079
# Epoch 8/1000
#  - 0s - loss: 0.1180 - mean_squared_error: 0.0192 - val_loss: 0.0103 - val_mean_squared_error: 1.8968e-04
# Epoch 9/1000
#  - 0s - loss: 0.0687 - mean_squared_error: 0.0078 - val_loss: 0.0486 - val_mean_squared_error: 0.0028
# Epoch 10/1000
#  - 0s - loss: 0.0617 - mean_squared_error: 0.0063 - val_loss: 0.0690 - val_mean_squared_error: 0.0062
# Epoch 11/1000
#  - 0s - loss: 0.0617 - mean_squared_error: 0.0064 - val_loss: 0.0619 - val_mean_squared_error: 0.0052
# Epoch 12/1000
#  - 0s - loss: 0.0601 - mean_squared_error: 0.0060 - val_loss: 0.0549 - val_mean_squared_error: 0.0037
# Epoch 13/1000
#  - 0s - loss: 0.0574 - mean_squared_error: 0.0056 - val_loss: 0.0548 - val_mean_squared_error: 0.0047
# Epoch 14/1000
#  - 0s - loss: 0.0551 - mean_squared_error: 0.0052 - val_loss: 0.0573 - val_mean_squared_error: 0.0055
# Epoch 15/1000
#  - 0s - loss: 0.0524 - mean_squared_error: 0.0048 - val_loss: 0.0561 - val_mean_squared_error: 0.0044
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 0s - loss: 0.0506 - mean_squared_error: 0.0047 - val_loss: 0.0552 - val_mean_squared_error: 0.0042
# Epoch 17/1000
#  - 0s - loss: 0.0502 - mean_squared_error: 0.0045 - val_loss: 0.0539 - val_mean_squared_error: 0.0037
# Epoch 18/1000
#  - 0s - loss: 0.0503 - mean_squared_error: 0.0046 - val_loss: 0.0535 - val_mean_squared_error: 0.0038
# predict: [[31.2418419 23.236071 ]]
# real:      [[31.  22.8]]
#
# Train on 1005 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.9083 - mean_squared_error: 1.0202 - val_loss: 0.3920 - val_mean_squared_error: 0.2669
# Epoch 2/1000
#  - 0s - loss: 0.3787 - mean_squared_error: 0.2137 - val_loss: 0.0937 - val_mean_squared_error: 0.0108
# Epoch 3/1000
#  - 0s - loss: 0.1066 - mean_squared_error: 0.0209 - val_loss: 0.1449 - val_mean_squared_error: 0.0303
# Epoch 4/1000
#  - 0s - loss: 0.0747 - mean_squared_error: 0.0092 - val_loss: 0.0399 - val_mean_squared_error: 0.0031
# Epoch 5/1000
#  - 0s - loss: 0.0652 - mean_squared_error: 0.0070 - val_loss: 0.0826 - val_mean_squared_error: 0.0098
# Epoch 6/1000
#  - 0s - loss: 0.0612 - mean_squared_error: 0.0061 - val_loss: 0.0551 - val_mean_squared_error: 0.0053
# Epoch 7/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0057 - val_loss: 0.0538 - val_mean_squared_error: 0.0043
# Epoch 8/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0055 - val_loss: 0.0498 - val_mean_squared_error: 0.0041
# Epoch 9/1000
#  - 0s - loss: 0.0561 - mean_squared_error: 0.0052 - val_loss: 0.0671 - val_mean_squared_error: 0.0065
# Epoch 10/1000
#  - 0s - loss: 0.0542 - mean_squared_error: 0.0050 - val_loss: 0.0557 - val_mean_squared_error: 0.0056
# Epoch 11/1000
#  - 0s - loss: 0.0516 - mean_squared_error: 0.0045 - val_loss: 0.0546 - val_mean_squared_error: 0.0045
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 0s - loss: 0.0500 - mean_squared_error: 0.0043 - val_loss: 0.0566 - val_mean_squared_error: 0.0055
# Epoch 13/1000
#  - 0s - loss: 0.0494 - mean_squared_error: 0.0043 - val_loss: 0.0586 - val_mean_squared_error: 0.0061
# Epoch 14/1000
#  - 0s - loss: 0.0496 - mean_squared_error: 0.0043 - val_loss: 0.0565 - val_mean_squared_error: 0.0058
# predict: [[32.61776839 22.72907075]]
# real:      [[31.5 23. ]]
#
# Train on 1004 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.6947 - mean_squared_error: 0.6650 - val_loss: 0.2228 - val_mean_squared_error: 0.0514
# Epoch 2/1000
#  - 0s - loss: 0.1655 - mean_squared_error: 0.0397 - val_loss: 0.1536 - val_mean_squared_error: 0.0263
# Epoch 3/1000
#  - 0s - loss: 0.0850 - mean_squared_error: 0.0115 - val_loss: 0.0235 - val_mean_squared_error: 5.5459e-04
# Epoch 4/1000
#  - 0s - loss: 0.0670 - mean_squared_error: 0.0072 - val_loss: 0.0613 - val_mean_squared_error: 0.0043
# Epoch 5/1000
#  - 0s - loss: 0.0628 - mean_squared_error: 0.0064 - val_loss: 0.0663 - val_mean_squared_error: 0.0055
# Epoch 6/1000
#  - 0s - loss: 0.0628 - mean_squared_error: 0.0064 - val_loss: 0.0514 - val_mean_squared_error: 0.0043
# Epoch 7/1000
#  - 0s - loss: 0.0611 - mean_squared_error: 0.0061 - val_loss: 0.0522 - val_mean_squared_error: 0.0055
# Epoch 8/1000
#  - 0s - loss: 0.0600 - mean_squared_error: 0.0059 - val_loss: 0.0495 - val_mean_squared_error: 0.0039
# Epoch 9/1000
#  - 0s - loss: 0.0591 - mean_squared_error: 0.0058 - val_loss: 0.0427 - val_mean_squared_error: 0.0036
# Epoch 10/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0453 - val_mean_squared_error: 0.0037
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0571 - mean_squared_error: 0.0054 - val_loss: 0.0476 - val_mean_squared_error: 0.0045
# Epoch 12/1000
#  - 0s - loss: 0.0568 - mean_squared_error: 0.0054 - val_loss: 0.0508 - val_mean_squared_error: 0.0047
# Epoch 13/1000
#  - 0s - loss: 0.0567 - mean_squared_error: 0.0053 - val_loss: 0.0496 - val_mean_squared_error: 0.0047
# predict: [[30.74974291 22.06229482]]
# real:      [[30.9 22.9]]
#
# Train on 1003 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.9534 - mean_squared_error: 1.0530 - val_loss: 0.2889 - val_mean_squared_error: 0.1097
# Epoch 2/1000
#  - 0s - loss: 0.2252 - mean_squared_error: 0.0824 - val_loss: 0.2333 - val_mean_squared_error: 0.0555
# Epoch 3/1000
#  - 0s - loss: 0.0925 - mean_squared_error: 0.0139 - val_loss: 0.1345 - val_mean_squared_error: 0.0192
# Epoch 4/1000
#  - 0s - loss: 0.0722 - mean_squared_error: 0.0080 - val_loss: 0.0962 - val_mean_squared_error: 0.0097
# Epoch 5/1000
#  - 0s - loss: 0.0664 - mean_squared_error: 0.0072 - val_loss: 0.1005 - val_mean_squared_error: 0.0110
# Epoch 6/1000
#  - 0s - loss: 0.0629 - mean_squared_error: 0.0063 - val_loss: 0.1061 - val_mean_squared_error: 0.0118
# Epoch 7/1000
#  - 0s - loss: 0.0615 - mean_squared_error: 0.0061 - val_loss: 0.1082 - val_mean_squared_error: 0.0119
# Epoch 8/1000
#  - 0s - loss: 0.0611 - mean_squared_error: 0.0060 - val_loss: 0.1079 - val_mean_squared_error: 0.0119
# Epoch 9/1000
#  - 0s - loss: 0.0603 - mean_squared_error: 0.0059 - val_loss: 0.1058 - val_mean_squared_error: 0.0113
# Epoch 10/1000
#  - 0s - loss: 0.0600 - mean_squared_error: 0.0058 - val_loss: 0.0990 - val_mean_squared_error: 0.0098
# Epoch 11/1000
#  - 0s - loss: 0.0595 - mean_squared_error: 0.0057 - val_loss: 0.1000 - val_mean_squared_error: 0.0100
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 0s - loss: 0.0589 - mean_squared_error: 0.0056 - val_loss: 0.0955 - val_mean_squared_error: 0.0092
# Epoch 13/1000
#  - 0s - loss: 0.0588 - mean_squared_error: 0.0056 - val_loss: 0.0951 - val_mean_squared_error: 0.0091
# Epoch 14/1000
#  - 0s - loss: 0.0588 - mean_squared_error: 0.0056 - val_loss: 0.0969 - val_mean_squared_error: 0.0095
# Epoch 15/1000
#  - 0s - loss: 0.0587 - mean_squared_error: 0.0056 - val_loss: 0.0948 - val_mean_squared_error: 0.0091
# Epoch 16/1000
#  - 0s - loss: 0.0587 - mean_squared_error: 0.0056 - val_loss: 0.0970 - val_mean_squared_error: 0.0095
# Epoch 17/1000
#  - 0s - loss: 0.0587 - mean_squared_error: 0.0056 - val_loss: 0.0936 - val_mean_squared_error: 0.0088
# Epoch 18/1000
#  - 0s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.0986 - val_mean_squared_error: 0.0098
# Epoch 19/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0947 - val_mean_squared_error: 0.0090
# Epoch 20/1000
#  - 0s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.0959 - val_mean_squared_error: 0.0092
# Epoch 21/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0056 - val_loss: 0.0953 - val_mean_squared_error: 0.0091
# Epoch 22/1000
#  - 0s - loss: 0.0586 - mean_squared_error: 0.0056 - val_loss: 0.0917 - val_mean_squared_error: 0.0085
# Epoch 23/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0995 - val_mean_squared_error: 0.0100
# Epoch 24/1000
#  - 0s - loss: 0.0583 - mean_squared_error: 0.0056 - val_loss: 0.0929 - val_mean_squared_error: 0.0087
# Epoch 25/1000
#  - 0s - loss: 0.0584 - mean_squared_error: 0.0055 - val_loss: 0.0925 - val_mean_squared_error: 0.0086
# Epoch 26/1000
#  - 0s - loss: 0.0581 - mean_squared_error: 0.0055 - val_loss: 0.0998 - val_mean_squared_error: 0.0100
# Epoch 27/1000
#  - 0s - loss: 0.0581 - mean_squared_error: 0.0055 - val_loss: 0.0937 - val_mean_squared_error: 0.0088
# Epoch 28/1000
#  - 0s - loss: 0.0580 - mean_squared_error: 0.0055 - val_loss: 0.0947 - val_mean_squared_error: 0.0090
# Epoch 29/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0950 - val_mean_squared_error: 0.0091
#
# Epoch 00029: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
# Epoch 30/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0949 - val_mean_squared_error: 0.0090
# Epoch 31/1000
#  - 0s - loss: 0.0579 - mean_squared_error: 0.0055 - val_loss: 0.0953 - val_mean_squared_error: 0.0091
# Epoch 32/1000
#  - 0s - loss: 0.0578 - mean_squared_error: 0.0055 - val_loss: 0.0953 - val_mean_squared_error: 0.0091
# predict: [[31.70044083 22.2091199 ]]
# real:      [[31.2 23.2]]
#
# Train on 1002 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 1.2960 - mean_squared_error: 1.7508 - val_loss: 0.9609 - val_mean_squared_error: 0.9233
# Epoch 2/1000
#  - 0s - loss: 0.9762 - mean_squared_error: 0.9737 - val_loss: 0.6635 - val_mean_squared_error: 0.5192
# Epoch 3/1000
#  - 0s - loss: 0.4247 - mean_squared_error: 0.2595 - val_loss: 0.2064 - val_mean_squared_error: 0.0521
# Epoch 4/1000
#  - 0s - loss: 0.1172 - mean_squared_error: 0.0207 - val_loss: 0.0789 - val_mean_squared_error: 0.0092
# Epoch 5/1000
#  - 0s - loss: 0.0793 - mean_squared_error: 0.0105 - val_loss: 0.1750 - val_mean_squared_error: 0.0449
# Epoch 6/1000
#  - 0s - loss: 0.0666 - mean_squared_error: 0.0072 - val_loss: 0.1071 - val_mean_squared_error: 0.0228
# Epoch 7/1000
#  - 0s - loss: 0.0633 - mean_squared_error: 0.0064 - val_loss: 0.1197 - val_mean_squared_error: 0.0242
# Epoch 8/1000
#  - 0s - loss: 0.0617 - mean_squared_error: 0.0061 - val_loss: 0.1170 - val_mean_squared_error: 0.0250
# Epoch 9/1000
#  - 0s - loss: 0.0609 - mean_squared_error: 0.0060 - val_loss: 0.1075 - val_mean_squared_error: 0.0219
# Epoch 10/1000
#  - 0s - loss: 0.0602 - mean_squared_error: 0.0059 - val_loss: 0.1139 - val_mean_squared_error: 0.0217
# Epoch 11/1000
#  - 0s - loss: 0.0600 - mean_squared_error: 0.0059 - val_loss: 0.1168 - val_mean_squared_error: 0.0240
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 0s - loss: 0.0595 - mean_squared_error: 0.0058 - val_loss: 0.1098 - val_mean_squared_error: 0.0213
# Epoch 13/1000
#  - 0s - loss: 0.0593 - mean_squared_error: 0.0057 - val_loss: 0.1095 - val_mean_squared_error: 0.0217
# Epoch 14/1000
#  - 0s - loss: 0.0592 - mean_squared_error: 0.0057 - val_loss: 0.1116 - val_mean_squared_error: 0.0220
# predict: [[31.48352026 22.34163527]]
# real:      [[31.  21.1]]
#
# Train on 1001 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 1.0638 - mean_squared_error: 1.2317 - val_loss: 0.6288 - val_mean_squared_error: 0.3996
# Epoch 2/1000
#  - 0s - loss: 0.3855 - mean_squared_error: 0.2136 - val_loss: 0.1106 - val_mean_squared_error: 0.0192
# Epoch 3/1000
#  - 0s - loss: 0.1061 - mean_squared_error: 0.0205 - val_loss: 0.0569 - val_mean_squared_error: 0.0057
# Epoch 4/1000
#  - 0s - loss: 0.0737 - mean_squared_error: 0.0084 - val_loss: 0.1117 - val_mean_squared_error: 0.0198
# Epoch 5/1000
#  - 0s - loss: 0.0648 - mean_squared_error: 0.0069 - val_loss: 0.0726 - val_mean_squared_error: 0.0076
# Epoch 6/1000
#  - 0s - loss: 0.0616 - mean_squared_error: 0.0060 - val_loss: 0.0891 - val_mean_squared_error: 0.0148
# Epoch 7/1000
#  - 0s - loss: 0.0605 - mean_squared_error: 0.0058 - val_loss: 0.0741 - val_mean_squared_error: 0.0101
# Epoch 8/1000
#  - 0s - loss: 0.0601 - mean_squared_error: 0.0057 - val_loss: 0.0714 - val_mean_squared_error: 0.0081
# Epoch 9/1000
#  - 0s - loss: 0.0590 - mean_squared_error: 0.0056 - val_loss: 0.0704 - val_mean_squared_error: 0.0098
# Epoch 10/1000
#  - 0s - loss: 0.0592 - mean_squared_error: 0.0056 - val_loss: 0.0656 - val_mean_squared_error: 0.0085
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 0s - loss: 0.0586 - mean_squared_error: 0.0055 - val_loss: 0.0668 - val_mean_squared_error: 0.0089
# Epoch 12/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0055 - val_loss: 0.0680 - val_mean_squared_error: 0.0089
# Epoch 13/1000
#  - 0s - loss: 0.0585 - mean_squared_error: 0.0055 - val_loss: 0.0693 - val_mean_squared_error: 0.0092
# predict: [[32.332392   23.02750625]]
# real:      [[28.7 22.8]]
#
# Train on 1000 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.6964 - mean_squared_error: 0.8789 - val_loss: 0.1136 - val_mean_squared_error: 0.0242
# Epoch 2/1000
#  - 0s - loss: 0.1166 - mean_squared_error: 0.0229 - val_loss: 0.0040 - val_mean_squared_error: 2.2710e-05
# Epoch 3/1000
#  - 0s - loss: 0.0765 - mean_squared_error: 0.0092 - val_loss: 0.0901 - val_mean_squared_error: 0.0086
# Epoch 4/1000
#  - 0s - loss: 0.0630 - mean_squared_error: 0.0064 - val_loss: 0.0863 - val_mean_squared_error: 0.0076
# Epoch 5/1000
#  - 0s - loss: 0.0605 - mean_squared_error: 0.0060 - val_loss: 0.0765 - val_mean_squared_error: 0.0063
# Epoch 6/1000
#  - 0s - loss: 0.0588 - mean_squared_error: 0.0056 - val_loss: 0.0633 - val_mean_squared_error: 0.0051
# Epoch 7/1000
#  - 0s - loss: 0.0580 - mean_squared_error: 0.0055 - val_loss: 0.0666 - val_mean_squared_error: 0.0045
# Epoch 8/1000
#  - 0s - loss: 0.0572 - mean_squared_error: 0.0054 - val_loss: 0.0624 - val_mean_squared_error: 0.0040
# Epoch 9/1000
#  - 0s - loss: 0.0562 - mean_squared_error: 0.0053 - val_loss: 0.0593 - val_mean_squared_error: 0.0035
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/1000
#  - 0s - loss: 0.0560 - mean_squared_error: 0.0051 - val_loss: 0.0645 - val_mean_squared_error: 0.0044
# Epoch 11/1000
#  - 0s - loss: 0.0554 - mean_squared_error: 0.0051 - val_loss: 0.0706 - val_mean_squared_error: 0.0051
# Epoch 12/1000
#  - 0s - loss: 0.0554 - mean_squared_error: 0.0051 - val_loss: 0.0651 - val_mean_squared_error: 0.0045
# predict: [[30.44705407 22.1127884 ]]
# real:      [[30.1 22.9]]
#
# Test RMSE -------------------------- 1.711
# Test VARIANCE ---------------------- 1.0
# Test MAX-ERROR --------------------- 2.35
# Test MEAN-ABSOLUTE-ERROR ----------- 1.461
# Test MEDIAN-ABSOLUTE-ERROR --------- 1.461
