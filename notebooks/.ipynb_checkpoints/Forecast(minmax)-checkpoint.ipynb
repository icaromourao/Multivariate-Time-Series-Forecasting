# %%
# imports required for the algorithm
import os

import time

from pandas import read_csv
from pandas import DataFrame
from pandas import concat

from datetime import datetime
from math import sqrt
import numpy as np

from matplotlib import pyplot

from sklearn import preprocessing

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from keras.callbacks import ReduceLROnPlateau

city = 'AL_Maceio'
# Out:
# Using TensorFlow backend.

# %%
def getFileNameIn(path):
    files_names = []
    for dirname, dirnames, filenames in os.walk(path):
        # print path to all subdirectories first.
        for subdirname in dirnames:
            files_names.append(os.path.join(dirname, subdirname))

        # print path to all filenames.
        for filename in filenames:
            files_names.append(os.path.join(dirname, filename))
        
        return files_names

# %%
# transform date into appropriate format
def parse(x):
	return datetime.strptime(x, '%d/%m/%Y')

# %%
# load the input dataset and save like a output dataset
def format_dataset(data_input_path):
    try:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1')
    except:
        dataset = read_csv(data_input_path, parse_dates=['Data'], index_col=1, date_parser=parse, encoding='latin-1', skiprows=2)
    
    dataset.index.name = 'date'

    dataset.drop('Unnamed: 11', axis=1, inplace=True)
    dataset.drop('Estacao', axis=1, inplace=True)
    
    dataset['TempMinima'] = dataset['TempMinima'].shift(-1)
    dataset['Precipitacao'] = dataset['Precipitacao'].shift(-1)
    
    dataset.drop('Hora', axis=1, inplace=True)
    
    dataset = dataset.loc[~dataset.index.duplicated(keep='first')]
    
    # replaces first line NA values with next line value
    dataset.iloc[0,:].fillna(dataset.iloc[1,:], inplace=True)
    
    # replace all NA values with prev line value
    dataset.ffill(axis=0, inplace=True)
    
    dataset.fillna(0, inplace=True)
    
    dataset.drop('Precipitacao', axis=1, inplace=True)

    # show the first 5 lines on the dataset
    print(dataset)
    
    output_path = '../data_out/' + data_input_path[11:]
    # save file
    dataset.to_csv(output_path)
    
    return output_path

# %%
# load dataset
def load_dataset(input_path):
    return read_csv(input_path, header=0, index_col=0)

# %%
# plot each column in a graph
def plot_columns(dataset, values):
    groups = list(range(0,len(values[0])))
    i = 1
    
    pyplot.figure(dpi=120)
    for group in groups:
        pyplot.subplot(len(groups), 1, i)
        pyplot.plot(values[:, group])
        pyplot.title(dataset.columns[group], y=0.1, loc='right')
        i += 1
    pyplot.show()

# %%
# convert series to supervised learning
def series_to_supervised(dataset, day):
    y_test = np.array([dataset.loc[day]['TempMaxima'], dataset.loc[day]['TempMinima']])
    y_test = y_test.reshape(1,2)
    
    dataset = dataset[:-1]
    
    x_test = np.array(dataset[-60:])
    x_test = x_test.reshape(1,60,7)
    
    lista = []
    
    for i in list(dataset.index):
        lista.append([dataset.loc[i]['TempMaxima'], dataset.loc[i]['TempMinima']])
    y_train = np.array(lista[60:])
    
    dataset = dataset[:-1]
    
    x_train = np.array(dataset[-60:])
    x_train = x_train.reshape(1,60,7)
    dataset = dataset[:-1]
    
    while len(dataset) >= 60:
        array_aux = np.array(dataset[-60:])
        array_aux = array_aux.reshape(1,60,7)
        x_train = np.concatenate((x_train, array_aux), axis=0)
        dataset = dataset[:-1]
    
    return [x_train, y_train, x_test, y_test]

# %%
# inner loop
def myLSTM(x_train, y_train, x_test, y_test, scaler):
    x_val = x_train[-1]
    y_val = y_train[-1]
    x_val = x_val.reshape(1,60,7)
    y_val = y_val.reshape(1,2)
    x_train = x_train[:-1]
    y_train = y_train[:-1]
    
    # design network
    model = Sequential()
    model.add(LSTM(50, input_shape=(x_train.shape[1], x_train.shape[2])))
    model.add(Dense(16, activation='relu'))   # worth it?
    model.add(Dense(2))
    model.compile(loss='mae', optimizer='adam', metrics=['mse'])
    
    callbacks = [
        EarlyStopping(monitor='val_loss', patience=10, verbose=0, restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=7, verbose=1, min_delta=1e-4, mode='min')
    ]
    
    # fit network
    history = model.fit(x_train, y_train,
                        epochs=1000, 
                        batch_size=72, 
                        validation_data=(x_val, y_val), 
                        verbose=2, 
                        shuffle=True, 
                        callbacks=callbacks)
    
    # plot history
    pyplot.plot(history.history['loss'], label='train')
    pyplot.plot(history.history['val_loss'], label='validation')
    pyplot.legend()
    pyplot.show()
    
    y = inverseScale(model, x_test, y_test, scaler)
    inv_y_hat = y[0]
    inv_y_test = y[1]
    
    print('\npredict: {}'.format(inv_y_hat))
    print('real:      {}\n'.format(inv_y_test))
    
    return [inv_y_hat, inv_y_test]

# %%
def inverseScale(model, x_test, y_test, scaler):
    # make a prediction
    y_hat = model.predict(x_test)
    
    new_x_test = x_test[:,-1,:]
    new_x_test = new_x_test.reshape((x_test.shape[0], x_test.shape[2]))
    new_x_test = np.concatenate((new_x_test[:, 0:1], new_x_test[:, 3:]), axis=1)
    
    # invert scaling for forecast
    inv_y_hat = np.concatenate((y_hat, new_x_test), axis=1)
    inv_y_hat = scaler.inverse_transform(inv_y_hat)
    inv_y_hat = inv_y_hat[:,:2]
    
    # invert scaling for actual value
    new_test_y = y_test.reshape((len(y_test), 2))
    inv_y_test = np.concatenate((new_test_y, new_x_test), axis=1)
    inv_y_test = scaler.inverse_transform(inv_y_test)
    inv_y_test = inv_y_test[:,:2]
    
    return [inv_y_hat, inv_y_test]

# %%
# Nested Cross Validation
def NCV(dataset, days_to_predict, scaler):
    i = len(days_to_predict) - 1
    y_hats = []
    y_tests = []
    
    # outer loop
    while(i >= 0):
        data = series_to_supervised(dataset, days_to_predict[i])
        x_train = data[0]
        y_train = data[1]
        x_test = data[2]
        y_test = data[3]
        
        result = myLSTM(x_train, y_train, x_test, y_test, scaler)
        
        y_hats += result[0].tolist()
        y_tests += result[1].tolist()
        
        i -= 1
        dataset = dataset[:-1]
    
    return [y_hats, y_tests]

# %%
def metrics(y_hats, y_tests, days_to_predict):
    temps_splited = splitTemperature(y_hats, y_tests, city)
    y_hats_max = temps_splited[0]
    y_tests_max = temps_splited[1]
    y_hats_min = temps_splited[2]
    y_tests_min = temps_splited[3]
    
    errors_max = abs(np.subtract(y_hats_max,y_tests_max))
    errors_min = abs(np.subtract(y_hats_min,y_tests_min))
    
    print('Maximum temperatures metrics')
    printMetrics(errors_max, 'max', city)
    day_errors(days_to_predict, errors_max, city)
    accuracy(errors_max, city)
    
    print('\nMinimum temperatures metrics')
    printMetrics(errors_min, 'min', city)
    day_errors(days_to_predict, errors_min, city)
    accuracy(errors_min, city)

# %%
def splitTemperature(y_hats, y_tests, city):
    y_hats_max = []
    y_hats_min = []
    y_tests_max = []
    y_tests_min = []
    
    for y in y_hats:
        y_hats_max.append(y[0])
        y_hats_min.append(y[1])
        
    for y in y_tests:
        y_tests_max.append(y[0])
        y_tests_min.append(y[1])
    
    file_path = '../results/'+city+'_minmax_normalization_predictions_results.csv'
    file = open(file_path, 'r')
    content = file.readlines()
    
    for i,j,k,l in zip(y_hats_max, y_tests_max, y_hats_min, y_tests_min):
        content.append('{},{},{},{}\n'.format(i,j,k,l))

    file = open(file_path, 'w')
    file.writelines(content)
    file.close()
    
    return [y_hats_max, y_tests_max, y_hats_min, y_tests_min]

# %%
def printMetrics(errors, temperature, city):
    mse = np.mean(np.square(errors))
    std = np.std(errors)
    meanAbsolutError = np.mean(errors)
    medianAbsoluteError = np.median(errors)
    
    file_path = '../results/'+city+'_minmax_normalization_metrics_results.csv'
    if temperature == 'max':
        file = open(file_path, 'r')
        content = file.readlines()

        content.append('{},{},{},{}\n'.format(mse,std,meanAbsolutError,medianAbsoluteError))

        file = open(file_path, 'w')
        file.writelines(content)
        file.close()
    elif temperature == 'min':
        file = open(file_path, 'r')
        content = file.readlines()
        
        content[1] = content[1].replace('\n', ',')+'{},{},{},{}\n'.format(mse,std,meanAbsolutError,medianAbsoluteError)

        file = open(file_path, 'w')
        file.writelines(content)
        file.close()
    
    print('Test MEAN-SQUARED-ERROR ------------ {:.4}'.format(mse))
    print('Test STANDART-DEVIATION ------------ {:.4}'.format(std))
    print('Test MEAN-ABSOLUTE-ERROR ----------- {:.4}'.format(meanAbsolutError))
    print('Test MEDIAN-ABSOLUTE-ERROR --------- {:.4}'.format(medianAbsoluteError))

# %%
def accuracy(errors, city):
    j = 1
    sum_percentual = 0
    accuracys = []
    sets = []
    
    print('\nAccuracy')
    while sum_percentual <= 99:
        count = 0
        n = len(errors)
        
        for error in errors:
            if  error > j-1 and error <= j:
                count += 1
        
        percentual = (count/n)*100
        sum_percentual += percentual
        if percentual > 0:
            accuracys.append(percentual)
            sets.append('({}, {}]'.format(j-1, j))
            print('{:.2f}% of predictions missed between ({}, {}] point(s)'.format(percentual, j-1, j))
        j += 1
    print('\n')
    
    file_path = '../results/'+city+'_minmax_normalization_accuracy_results.csv'
    file = open(file_path, 'r')
    content = file.readlines()

    for i,j in zip(accuracys, sets):
        content.append('{},{}\n'.format(i,j))

    file = open(file_path, 'w')
    file.writelines(content)
    file.close()

# %%
def day_errors(days_to_predict, errors, city):
    i = 0
    
    file_path = '../results/'+city+'_minmax_normalization_predictions_results.csv'
    file = open(file_path, 'r')
    content = file.readlines()
    
    print('\nErrors')
    for error in errors:
        content[i+1] = content[i+1].replace('\n', ',')+'{}\n'.format(error)
        print('{} = {}'.format(days_to_predict[29-i],error))
        i += 1
    
    file = open(file_path, 'w')
    file.writelines(content)
    file.close()

# %%
def main():
    input_path = '../data_in/'+city+'.csv'
    output_path = format_dataset(input_path)
    dataset = load_dataset(output_path)
    values = dataset.values
    plot_columns(dataset, values)

    # to get index the last 30 days
    days_to_predict = list(dataset.index[-30:])

    min_max_scaler = preprocessing.MinMaxScaler()
    values_scaled = min_max_scaler.fit_transform(values)
    dataset_scaled = DataFrame(values_scaled)
    dataset_scaled.index = dataset.index
    dataset_scaled.columns = dataset.columns

    inicio = time.time()
    result = NCV(dataset_scaled, days_to_predict, min_max_scaler)
    fim = time.time()
    print('Train and validation time: {}\n'.format((fim - inicio)/60))

    y_hats = result[0]
    y_tests = result[1]

    metrics(y_hats, y_tests, days_to_predict)
    
if __name__ == "__main__":
    main()
# Out:
#             TempMaxima  TempMinima  Insolacao  Evaporacao Piche  \
# date
# 2014-01-01        30.9        22.2       10.5               3.0
# 2014-01-02        30.9        22.3       10.4               4.6
# 2014-01-03        31.1        21.1        8.2               3.2
# 2014-01-04        32.4        22.8       10.6               4.6
# 2014-01-05        30.6        21.9        7.9               4.4
# ...                ...         ...        ...               ...
# 2018-12-27        33.4        23.6        9.9               2.8
# 2018-12-28        33.0        23.6        9.6               2.8
# 2018-12-29        33.2        23.4        8.7               2.8
# 2018-12-30        33.0        23.1        3.4               2.8
# 2018-12-31        32.2        23.3        9.6               2.8
#
#             Temp Comp Media  Umidade Relativa Media  Velocidade do Vento Media
# date
# 2014-01-01            26.26                   79.75                        0.0
# 2014-01-02            26.32                   81.50                        0.0
# 2014-01-03            26.20                   74.50                        0.0
# 2014-01-04            27.50                   78.25                        0.0
# 2014-01-05            26.52                   80.00                        0.0
# ...                     ...                     ...                        ...
# 2018-12-27            27.84                   73.50                        0.0
# 2018-12-28            27.16                   77.75                        0.0
# 2018-12-29            27.20                   77.25                        0.0
# 2018-12-30            27.26                   74.50                        0.0
# 2018-12-31            26.90                   77.25                        0.0
#
# [1824 rows x 7 columns]
# Train on 1762 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.2073 - mean_squared_error: 0.0763 - val_loss: 0.1691 - val_mean_squared_error: 0.0417
# Epoch 2/1000
#  - 1s - loss: 0.1024 - mean_squared_error: 0.0174 - val_loss: 0.1171 - val_mean_squared_error: 0.0245
# Epoch 3/1000
#  - 1s - loss: 0.0957 - mean_squared_error: 0.0158 - val_loss: 0.1079 - val_mean_squared_error: 0.0188
# Epoch 4/1000
#  - 1s - loss: 0.0926 - mean_squared_error: 0.0147 - val_loss: 0.1080 - val_mean_squared_error: 0.0203
# Epoch 5/1000
#  - 1s - loss: 0.0894 - mean_squared_error: 0.0138 - val_loss: 0.1079 - val_mean_squared_error: 0.0232
# Epoch 6/1000
#  - 1s - loss: 0.0866 - mean_squared_error: 0.0131 - val_loss: 0.1496 - val_mean_squared_error: 0.0386
# Epoch 7/1000
#  - 1s - loss: 0.0863 - mean_squared_error: 0.0130 - val_loss: 0.1300 - val_mean_squared_error: 0.0300
# Epoch 8/1000
#  - 1s - loss: 0.0857 - mean_squared_error: 0.0128 - val_loss: 0.0990 - val_mean_squared_error: 0.0191
# Epoch 9/1000
#  - 1s - loss: 0.0869 - mean_squared_error: 0.0131 - val_loss: 0.1023 - val_mean_squared_error: 0.0207
# Epoch 10/1000
#  - 1s - loss: 0.0869 - mean_squared_error: 0.0131 - val_loss: 0.1157 - val_mean_squared_error: 0.0261
# Epoch 11/1000
#  - 1s - loss: 0.0870 - mean_squared_error: 0.0133 - val_loss: 0.1869 - val_mean_squared_error: 0.0491
# Epoch 12/1000
#  - 1s - loss: 0.0891 - mean_squared_error: 0.0137 - val_loss: 0.1129 - val_mean_squared_error: 0.0233
# Epoch 13/1000
#  - 1s - loss: 0.0852 - mean_squared_error: 0.0127 - val_loss: 0.1198 - val_mean_squared_error: 0.0250
# Epoch 14/1000
#  - 1s - loss: 0.0848 - mean_squared_error: 0.0126 - val_loss: 0.1252 - val_mean_squared_error: 0.0260
# Epoch 15/1000
#  - 1s - loss: 0.0848 - mean_squared_error: 0.0126 - val_loss: 0.1157 - val_mean_squared_error: 0.0256
#
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 16/1000
#  - 1s - loss: 0.0842 - mean_squared_error: 0.0125 - val_loss: 0.1248 - val_mean_squared_error: 0.0259
# Epoch 17/1000
#  - 1s - loss: 0.0838 - mean_squared_error: 0.0124 - val_loss: 0.1169 - val_mean_squared_error: 0.0245
# Epoch 18/1000
#  - 1s - loss: 0.0834 - mean_squared_error: 0.0123 - val_loss: 0.1216 - val_mean_squared_error: 0.0251
# predict: [[31.785147   23.34687335]]
# real:      [[32.2 23.3]]
#
# Train on 1761 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.3350 - mean_squared_error: 0.1751 - val_loss: 0.1353 - val_mean_squared_error: 0.0277
# Epoch 2/1000
#  - 1s - loss: 0.1014 - mean_squared_error: 0.0178 - val_loss: 0.1521 - val_mean_squared_error: 0.0343
# Epoch 3/1000
#  - 1s - loss: 0.0920 - mean_squared_error: 0.0145 - val_loss: 0.1375 - val_mean_squared_error: 0.0293
# Epoch 4/1000
#  - 1s - loss: 0.0899 - mean_squared_error: 0.0139 - val_loss: 0.1520 - val_mean_squared_error: 0.0336
# Epoch 5/1000
#  - 1s - loss: 0.0886 - mean_squared_error: 0.0136 - val_loss: 0.1851 - val_mean_squared_error: 0.0458
# Epoch 6/1000
#  - 1s - loss: 0.0876 - mean_squared_error: 0.0134 - val_loss: 0.1773 - val_mean_squared_error: 0.0440
# Epoch 7/1000
#  - 1s - loss: 0.0868 - mean_squared_error: 0.0131 - val_loss: 0.1699 - val_mean_squared_error: 0.0406
# Epoch 8/1000
#  - 1s - loss: 0.0877 - mean_squared_error: 0.0135 - val_loss: 0.1213 - val_mean_squared_error: 0.0232
# Epoch 9/1000
#  - 1s - loss: 0.0864 - mean_squared_error: 0.0131 - val_loss: 0.1537 - val_mean_squared_error: 0.0326
# Epoch 10/1000
#  - 1s - loss: 0.0858 - mean_squared_error: 0.0129 - val_loss: 0.1253 - val_mean_squared_error: 0.0238
# Epoch 11/1000
#  - 1s - loss: 0.0858 - mean_squared_error: 0.0130 - val_loss: 0.1461 - val_mean_squared_error: 0.0294
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 10/1000
#  - 1s - loss: 0.0862 - mean_squared_error: 0.0131 - val_loss: 0.0709 - val_mean_squared_error: 0.0052
# Epoch 11/1000
#  - 1s - loss: 0.0862 - mean_squared_error: 0.0131 - val_loss: 0.0654 - val_mean_squared_error: 0.0044
# Epoch 12/1000
#  - 1s - loss: 0.0861 - mean_squared_error: 0.0129 - val_loss: 0.0614 - val_mean_squared_error: 0.0038
# predict: [[30.30238743 22.9351615 ]]
# real:      [[30.5 23.6]]
#
# Train on 1754 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.2145 - mean_squared_error: 0.0826 - val_loss: 0.0910 - val_mean_squared_error: 0.0084
# Epoch 2/1000
#  - 1s - loss: 0.0973 - mean_squared_error: 0.0160 - val_loss: 0.0238 - val_mean_squared_error: 0.0011
# Epoch 3/1000
#  - 1s - loss: 0.0933 - mean_squared_error: 0.0148 - val_loss: 0.0183 - val_mean_squared_error: 3.8348e-04
# Epoch 4/1000
#  - 1s - loss: 0.0916 - mean_squared_error: 0.0144 - val_loss: 0.0491 - val_mean_squared_error: 0.0024
# Epoch 5/1000
#  - 1s - loss: 0.0904 - mean_squared_error: 0.0141 - val_loss: 0.0382 - val_mean_squared_error: 0.0018
# Epoch 6/1000
#  - 1s - loss: 0.0894 - mean_squared_error: 0.0138 - val_loss: 0.0398 - val_mean_squared_error: 0.0016
# Epoch 7/1000
#  - 1s - loss: 0.0889 - mean_squared_error: 0.0136 - val_loss: 0.0540 - val_mean_squared_error: 0.0029
# Epoch 8/1000
#  - 1s - loss: 0.0894 - mean_squared_error: 0.0138 - val_loss: 0.0875 - val_mean_squared_error: 0.0077
# Epoch 9/1000
#  - 1s - loss: 0.0881 - mean_squared_error: 0.0135 - val_loss: 0.0704 - val_mean_squared_error: 0.0050
# Epoch 10/1000
#  - 1s - loss: 0.0874 - mean_squared_error: 0.0133 - val_loss: 0.0390 - val_mean_squared_error: 0.0016
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 11/1000
#  - 1s - loss: 0.0865 - mean_squared_error: 0.0133 - val_loss: 0.0760 - val_mean_squared_error: 0.0058
# Epoch 12/1000
#  - 1s - loss: 0.0863 - mean_squared_error: 0.0131 - val_loss: 0.0680 - val_mean_squared_error: 0.0046
# Epoch 13/1000
#  - 1s - loss: 0.0861 - mean_squared_error: 0.0130 - val_loss: 0.0647 - val_mean_squared_error: 0.0042
# predict: [[30.40293312 22.9328784 ]]
# real:      [[30.8 23.3]]
#
# Train on 1753 samples, validate on 1 samples
# Epoch 1/1000
#  - 1s - loss: 0.2690 - mean_squared_error: 0.1109 - val_loss: 0.0262 - val_mean_squared_error: 7.1545e-04
# Epoch 2/1000
#  - 1s - loss: 0.1009 - mean_squared_error: 0.0169 - val_loss: 0.0247 - val_mean_squared_error: 8.4260e-04
# Epoch 3/1000
#  - 1s - loss: 0.0958 - mean_squared_error: 0.0155 - val_loss: 0.0072 - val_mean_squared_error: 6.3653e-05
# Epoch 4/1000
#  - 1s - loss: 0.0928 - mean_squared_error: 0.0147 - val_loss: 0.0167 - val_mean_squared_error: 2.8432e-04
# Epoch 5/1000
#  - 1s - loss: 0.0897 - mean_squared_error: 0.0140 - val_loss: 0.0203 - val_mean_squared_error: 5.5606e-04
# Epoch 6/1000
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 23/1000
#  - 1s - loss: 0.0856 - mean_squared_error: 0.0130 - val_loss: 0.0827 - val_mean_squared_error: 0.0101
# Epoch 24/1000
#  - 1s - loss: 0.0850 - mean_squared_error: 0.0129 - val_loss: 0.0834 - val_mean_squared_error: 0.0100
# Epoch 25/1000
#  - 1s - loss: 0.0849 - mean_squared_error: 0.0129 - val_loss: 0.0863 - val_mean_squared_error: 0.0097
# predict: [[30.80185547 23.19511354]]
# real:      [[29.2 22.6]]
#
# Train on 1748 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.3439 - mean_squared_error: 0.1684 - val_loss: 0.1314 - val_mean_squared_error: 0.0296
# Epoch 2/1000
#  - 1s - loss: 0.1032 - mean_squared_error: 0.0179 - val_loss: 0.1298 - val_mean_squared_error: 0.0182
# Epoch 3/1000
#  - 1s - loss: 0.0952 - mean_squared_error: 0.0156 - val_loss: 0.1325 - val_mean_squared_error: 0.0190
# Epoch 4/1000
#  - 1s - loss: 0.0924 - mean_squared_error: 0.0148 - val_loss: 0.1205 - val_mean_squared_error: 0.0160
# Epoch 5/1000
#  - 1s - loss: 0.0896 - mean_squared_error: 0.0140 - val_loss: 0.1088 - val_mean_squared_error: 0.0181
# Epoch 6/1000
#  - 1s - loss: 0.0887 - mean_squared_error: 0.0139 - val_loss: 0.0975 - val_mean_squared_error: 0.0108
# Epoch 7/1000
#  - 1s - loss: 0.0880 - mean_squared_error: 0.0136 - val_loss: 0.0833 - val_mean_squared_error: 0.0130
# Epoch 8/1000
#  - 1s - loss: 0.0878 - mean_squared_error: 0.0137 - val_loss: 0.0964 - val_mean_squared_error: 0.0143
# Epoch 9/1000
#  - 1s - loss: 0.0878 - mean_squared_error: 0.0137 - val_loss: 0.0983 - val_mean_squared_error: 0.0145
# Epoch 10/1000
#  - 1s - loss: 0.0870 - mean_squared_error: 0.0134 - val_loss: 0.1260 - val_mean_squared_error: 0.0160
# Epoch 11/1000
#  - 1s - loss: 0.0880 - mean_squared_error: 0.0137 - val_loss: 0.1127 - val_mean_squared_error: 0.0164
# Epoch 12/1000
#  - 1s - loss: 0.0882 - mean_squared_error: 0.0137 - val_loss: 0.1101 - val_mean_squared_error: 0.0145
# Epoch 13/1000
#  - 1s - loss: 0.0872 - mean_squared_error: 0.0134 - val_loss: 0.1010 - val_mean_squared_error: 0.0135
# Epoch 14/1000
#  - 1s - loss: 0.0863 - mean_squared_error: 0.0133 - val_loss: 0.1124 - val_mean_squared_error: 0.0140
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 1s - loss: 0.0860 - mean_squared_error: 0.0132 - val_loss: 0.1130 - val_mean_squared_error: 0.0138
# Epoch 16/1000
#  - 1s - loss: 0.0861 - mean_squared_error: 0.0132 - val_loss: 0.1070 - val_mean_squared_error: 0.0132
# Epoch 17/1000
#  - 1s - loss: 0.0859 - mean_squared_error: 0.0132 - val_loss: 0.1127 - val_mean_squared_error: 0.0136
# predict: [[31.66499872 23.07172921]]
# real:      [[28.6 23.1]]
#
# Train on 1747 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0871 - mean_squared_error: 0.0134 - val_loss: 0.0507 - val_mean_squared_error: 0.0032
# Epoch 13/1000
#  - 1s - loss: 0.0857 - mean_squared_error: 0.0131 - val_loss: 0.0565 - val_mean_squared_error: 0.0035
# Epoch 14/1000
#  - 1s - loss: 0.0856 - mean_squared_error: 0.0132 - val_loss: 0.0568 - val_mean_squared_error: 0.0036
# predict: [[30.67944078 22.60854554]]
# real:      [[31.8 22. ]]
#
# Train on 1745 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.2610 - mean_squared_error: 0.1090 - val_loss: 0.1248 - val_mean_squared_error: 0.0170
# Epoch 2/1000
#  - 1s - loss: 0.0993 - mean_squared_error: 0.0168 - val_loss: 0.0688 - val_mean_squared_error: 0.0067
# Epoch 3/1000
#  - 1s - loss: 0.0920 - mean_squared_error: 0.0145 - val_loss: 0.0602 - val_mean_squared_error: 0.0041
# Epoch 4/1000
#  - 1s - loss: 0.0912 - mean_squared_error: 0.0143 - val_loss: 0.0465 - val_mean_squared_error: 0.0030
# Epoch 5/1000
#  - 1s - loss: 0.0894 - mean_squared_error: 0.0139 - val_loss: 0.0487 - val_mean_squared_error: 0.0027
# Epoch 6/1000
#  - 1s - loss: 0.0888 - mean_squared_error: 0.0137 - val_loss: 0.0522 - val_mean_squared_error: 0.0040
# Epoch 7/1000
#  - 1s - loss: 0.0897 - mean_squared_error: 0.0140 - val_loss: 0.0415 - val_mean_squared_error: 0.0031
# Epoch 8/1000
#  - 1s - loss: 0.0886 - mean_squared_error: 0.0137 - val_loss: 0.0550 - val_mean_squared_error: 0.0031
# Epoch 9/1000
#  - 1s - loss: 0.0884 - mean_squared_error: 0.0137 - val_loss: 0.0578 - val_mean_squared_error: 0.0036
# Epoch 10/1000
#  - 1s - loss: 0.0892 - mean_squared_error: 0.0139 - val_loss: 0.0445 - val_mean_squared_error: 0.0038
# Epoch 11/1000
#  - 1s - loss: 0.0876 - mean_squared_error: 0.0135 - val_loss: 0.0502 - val_mean_squared_error: 0.0026
# Epoch 12/1000
#  - 1s - loss: 0.0874 - mean_squared_error: 0.0135 - val_loss: 0.0530 - val_mean_squared_error: 0.0028
# Epoch 13/1000
#  - 1s - loss: 0.0878 - mean_squared_error: 0.0137 - val_loss: 0.0439 - val_mean_squared_error: 0.0029
# Epoch 14/1000
#  - 1s - loss: 0.0872 - mean_squared_error: 0.0135 - val_loss: 0.0676 - val_mean_squared_error: 0.0048
#
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 15/1000
#  - 1s - loss: 0.0868 - mean_squared_error: 0.0134 - val_loss: 0.0503 - val_mean_squared_error: 0.0027
# Epoch 16/1000
#  - 1s - loss: 0.0862 - mean_squared_error: 0.0133 - val_loss: 0.0581 - val_mean_squared_error: 0.0034
# Epoch 17/1000
#  - 1s - loss: 0.0863 - mean_squared_error: 0.0133 - val_loss: 0.0536 - val_mean_squared_error: 0.0029
# predict: [[31.79720535 23.22933846]]
# real:      [[30.4 23. ]]
#
# Train on 1744 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0
samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.2400 - mean_squared_error: 0.0923 - val_loss: 0.1359 - val_mean_squared_error: 0.0187
# Epoch 2/1000
#  - 1s - loss: 0.1014 - mean_squared_error: 0.0172 - val_loss: 0.0962 - val_mean_squared_error: 0.0098
# Epoch 3/1000
#  - 1s - loss: 0.0958 - mean_squared_error: 0.0159 - val_loss: 0.0595 - val_mean_squared_error: 0.0037
# Epoch 4/1000
#  - 1s - loss: 0.0924 - mean_squared_error: 0.0150 - val_loss: 0.0509 - val_mean_squared_error: 0.0027
# Epoch 5/1000
#  - 1s - loss: 0.0913 - mean_squared_error: 0.0147 - val_loss: 0.0595 - val_mean_squared_error: 0.0036
# Epoch 6/1000
#  - 1s - loss: 0.0911 - mean_squared_error: 0.0148 - val_loss: 0.0555 - val_mean_squared_error: 0.0031
# Epoch 7/1000
#  - 1s - loss: 0.0902 - mean_squared_error: 0.0145 - val_loss: 0.0936 - val_mean_squared_error: 0.0089
# Epoch 8/1000
#  - 1s - loss: 0.0919 - mean_squared_error: 0.0148 - val_loss: 0.0952 - val_mean_squared_error: 0.0091
# Epoch 9/1000
#  - 1s - loss: 0.0914 - mean_squared_error: 0.0147 - val_loss: 0.1107 - val_mean_squared_error: 0.0131
# Epoch 10/1000
#  - 1s - loss: 0.0905 - mean_squared_error: 0.0145 - val_loss: 0.0964 - val_mean_squared_error: 0.0094
# Epoch 11/1000
#  - 1s - loss: 0.0907 - mean_squared_error: 0.0147 - val_loss: 0.0825 - val_mean_squared_error: 0.0074
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0900 - mean_squared_error: 0.0141 - val_loss: 0.0740 - val_mean_squared_error: 0.0055
# Epoch 13/1000
#  - 1s - loss: 0.0889 - mean_squared_error: 0.0142 - val_loss: 0.0852 - val_mean_squared_error: 0.0073
# Epoch 14/1000
#  - 1s - loss: 0.0887 - mean_squared_error: 0.0140 - val_loss: 0.0710 - val_mean_squared_error: 0.0051
# predict: [[30.59908648 22.80757446]]
# real:      [[34.  23.7]]
#
# Train on 1736 samples, validate on 1 samples
# Epoch 1/1000
#  - 2s - loss: 0.2231 - mean_squared_error: 0.0833 - val_loss: 0.1136 - val_mean_squared_error: 0.0138
# Epoch 2/1000
#  - 1s - loss: 0.0977 - mean_squared_error: 0.0160 - val_loss: 0.0562 - val_mean_squared_error: 0.0039
# Epoch 3/1000
#  - 1s - loss: 0.0931 - mean_squared_error: 0.0150 - val_loss: 0.0405 - val_mean_squared_error: 0.0028
# Epoch 4/1000
#  - 1s - loss: 0.0922 - mean_squared_error: 0.0148 - val_loss: 0.0352 - val_mean_squared_error: 0.0022
# Epoch 5/1000
#  - 1s - loss: 0.0920 - mean_squared_error: 0.0150 - val_loss: 0.0734 - val_mean_squared_error: 0.0057
# Epoch 6/1000
#  - 1s - loss: 0.0916 - mean_squared_error: 0.0147 - val_loss: 0.0446 - val_mean_squared_error: 0.0026
# Epoch 7/1000
#  - 1s - loss: 0.0911 - mean_squared_error: 0.0147 - val_loss: 0.0631 - val_mean_squared_error: 0.0050
# Epoch 8/1000
#  - 1s - loss: 0.0910 - mean_squared_error: 0.0147 - val_loss: 0.0550 - val_mean_squared_error: 0.0049
# Epoch 9/1000
#  - 1s - loss: 0.0900 - mean_squared_error: 0.0143 - val_loss: 0.0805 - val_mean_squared_error: 0.0069
# Epoch 10/1000
#  - 1s - loss: 0.0896 - mean_squared_error: 0.0143 - val_loss: 0.0689 - val_mean_squared_error: 0.0056
# Epoch 11/1000
#  - 1s - loss: 0.0889 - mean_squared_error: 0.0141 - val_loss: 0.0561 - val_mean_squared_error: 0.0038
#
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 12/1000
#  - 1s - loss: 0.0884 - mean_squared_error: 0.0140 - val_loss: 0.0653 - val_mean_squared_error: 0.0048
# Epoch 13/1000
#  - 1s - loss: 0.0883 - mean_squared_error: 0.0139 - val_loss: 0.0578 - val_mean_squared_error: 0.0040
# Epoch 14/1000
#  - 1s - loss: 0.0883 - mean_squared_error: 0.0140 - val_loss: 0.0644 - val_mean_squared_error: 0.0048
# predict: [[30.85835075 23.06769924]]
# real:      [[31.6 23.7]]
#
# Train on 1735 samples, validate on 1 samples
# Epoch 1/1000
#  - 3s - loss: 0.2590 - mean_squared_error: 0.1060 - val_loss: 0.0467 - val_mean_squared_error: 0.0022
# Epoch 2/1000
#  - 1s - loss: 0.0997 - mean_squared_error: 0.0166 - val_loss: 0.0609 - val_mean_squared_error: 0.0039
# Epoch 3/1000
#  - 1s - loss: 0.0933 - mean_squared_error: 0.0152 - val_loss: 0.0482 - val_mean_squared_error: 0.0041
# Epoch 4/1000
#  - 1s - loss: 0.0923 - mean_squared_error: 0.0151 - val_loss: 0.0468 - val_mean_squared_error: 0.0030
# Epoch 5/1000
#  - 1s - loss: 0.0914 - mean_squared_error: 0.0148 - val_loss: 0.0577 - val_mean_squared_error: 0.0050
# Epoch 6/1000
#  - 1s - loss: 0.0917 - mean_squared_error: 0.0148 - val_loss: 0.0487 - val_mean_squared_error: 0.0033
# Epoch 7/1000
#  - 1s - loss: 0.0900 - mean_squared_error: 0.0144 - val_loss: 0.0462 - val_mean_squared_error: 0.0023
# Epoch 8/1000
#  - 1s - loss: 0.0909 - mean_squared_error: 0.0146 - val_loss: 0.0452 - val_mean_squared_error: 0.0026
# Epoch 9/1000
#  - 1s - loss: 0.0907 - mean_squared_error: 0.0145 - val_loss: 0.0506 - val_mean_squared_error: 0.0041
# Epoch 10/1000
#  - 1s - loss: 0.0900 - mean_squared_error: 0.0144 - val_loss: 0.0319 - val_mean_squared_error: 0.0010
# Epoch 11/1000
#  - 1s - loss: 0.0897 - mean_squared_error: 0.0144 - val_loss: 0.0493 - val_mean_squared_error: 0.0043
# Epoch 12/1000
#  - 1s - loss: 0.0897 - mean_squared_error: 0.0142 - val_loss: 0.0535 - val_mean_squared_error: 0.0034
# Epoch 13/1000
#  - 1s - loss: 0.0890 - mean_squared_error: 0.0141 - val_loss: 0.0287 - val_mean_squared_error: 9.5703e-04
# Epoch 14/1000
#  - 1s - loss: 0.0887 - mean_squared_error: 0.0140 - val_loss: 0.0457 - val_mean_squared_error: 0.0023
# Epoch 15/1000
#  - 1s - loss: 0.0880 - mean_squared_error: 0.0138 - val_loss: 0.0479 - val_mean_squared_error: 0.0029
# Epoch 16/1000
#  - 1s - loss: 0.0875 - mean_squared_error: 0.0139 - val_loss: 0.0595 - val_mean_squared_error: 0.0058
# Epoch 17/1000
#  - 1s - loss: 0.0892 - mean_squared_error: 0.0141 - val_loss: 0.0295 - val_mean_squared_error: 8.9271e-04
# Epoch 18/1000
#  - 1s - loss: 0.0875 - mean_squared_error: 0.0137 - val_loss: 0.0489 - val_mean_squared_error: 0.0027
# Epoch 19/1000
#  - 1s - loss: 0.0888 - mean_squared_error: 0.0140 - val_loss: 0.0466 - val_mean_squared_error: 0.0022
# Epoch 20/1000
#  - 1s - loss: 0.0863 - mean_squared_error: 0.0134 - val_loss: 0.0410 - val_mean_squared_error: 0.0019
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 21/1000
#  - 1s - loss: 0.0857 - mean_squared_error: 0.0134 - val_loss: 0.0479 - val_mean_squared_error: 0.0023
# Epoch 22/1000
#  - 1s - loss: 0.0855 - mean_squared_error: 0.0132 - val_loss: 0.0458 - val_mean_squared_error: 0.0022
# Epoch 23/1000
#  - 1s - loss: 0.0854 - mean_squared_error: 0.0133 - val_loss: 0.0463 - val_mean_squared_error: 0.0022
# predict: [[30.49291582 22.94789176]]
# real:      [[31.6 23.4]]
#
# Train on 1734 samples, validate on 1 samples
# Epoch 1/1000
#  - 3s - loss: 0.2369 - mean_squared_error: 0.0896 - val_loss: 0.0268 - val_mean_squared_error: 9.4195e-04
# Epoch 2/1000
#  - 1s - loss: 0.0965 - mean_squared_error: 0.0158 - val_loss: 0.0667 - val_mean_squared_error: 0.0048
# Epoch 3/1000
#  - 1s - loss: 0.0917 - mean_squared_error: 0.0149 - val_loss: 0.0656 - val_mean_squared_error: 0.0043
# Epoch 4/1000
#  - 1s - loss: 0.0911 - mean_squared_error: 0.0149 - val_loss: 0.0832 - val_mean_squared_error: 0.0070
# Epoch 5/1000
#  - 1s - loss: 0.0908 - mean_squared_error: 0.0147 - val_loss: 0.0665 - val_mean_squared_error: 0.0044
# Epoch 6/1000
#  - 1s - loss: 0.0902 - mean_squared_error: 0.0146 - val_loss: 0.0326 - val_mean_squared_error: 0.0011
# Epoch 7/1000
#  - 1s - loss: 0.0902 - mean_squared_error: 0.0146 - val_loss: 0.0405 - val_mean_squared_error: 0.0018
# Epoch 8/1000
#  - 1s - loss: 0.0896 - mean_squared_error: 0.0145 - val_loss: 0.0472 - val_mean_squared_error: 0.0022
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 9/1000
#  - 1s - loss: 0.0887 - mean_squared_error: 0.0143 - val_loss: 0.0546 - val_mean_squared_error: 0.0030
# Epoch 10/1000
#  - 1s - loss: 0.0886 - mean_squared_error: 0.0143 - val_loss: 0.0508 - val_mean_squared_error: 0.0026
# Epoch 11/1000
#  - 1s - loss: 0.0887 - mean_squared_error: 0.0143 - val_loss: 0.0485 - val_mean_squared_error: 0.0024
# predict: [[29.80603161 22.46483564]]
# real:      [[29.9 23.3]]
#
# Train on 1733 samples, validate on 1 samples
# Epoch 1/1000
#  - 3s - loss: 0.3025 - mean_squared_error: 0.1414 - val_loss: 0.0597 - val_mean_squared_error: 0.0041
# Epoch 2/1000
#  - 1s - loss: 0.1003 - mean_squared_error: 0.0170 - val_loss: 0.0774 - val_mean_squared_error: 0.0062
# Epoch 3/1000
#  - 1s - loss: 0.0930 - mean_squared_error: 0.0152 - val_loss: 0.0526 - val_mean_squared_error: 0.0028
# Epoch 4/1000
#  - 1s - loss: 0.0924 - mean_squared_error: 0.0151 - val_loss: 0.0686 - val_mean_squared_error: 0.0049
# Epoch 5/1000
#  - 1s - loss: 0.0930 - mean_squared_error: 0.0153 - val_loss: 0.0801 - val_mean_squared_error: 0.0109
# Epoch 6/1000
#  - 1s - loss: 0.0934 - mean_squared_error: 0.0154 - val_loss: 0.0575 - val_mean_squared_error: 0.0034
# Epoch 7/1000
#  - 1s - loss: 0.0918 - mean_squared_error: 0.0150 - val_loss: 0.0848 - val_mean_squared_error: 0.0086
# Epoch 8/1000
#  - 1s - loss: 0.0911 - mean_squared_error: 0.0148 - val_loss: 0.0976 - val_mean_squared_error: 0.0103
# Epoch 9/1000
#  - 1s - loss: 0.0927 - mean_squared_error: 0.0152 - val_loss: 0.0470 - val_mean_squared_error: 0.0024
# Epoch 10/1000
#  - 1s - loss: 0.0922 - mean_squared_error: 0.0153 - val_loss: 0.1007 - val_mean_squared_error: 0.0110
# Epoch 11/1000
#  - 1s - loss: 0.0913 - mean_squared_error: 0.0147 - val_loss: 0.0833 - val_mean_squared_error: 0.0075
# Epoch 12/1000
#  - 1s - loss: 0.0899 - mean_squared_error: 0.0145 - val_loss: 0.0717 - val_mean_squared_error: 0.0053
# Epoch 13/1000
#  - 1s - loss: 0.0905 - mean_squared_error: 0.0146 - val_loss: 0.0757 - val_mean_squared_error: 0.0065
# Epoch 14/1000
#  - 1s - loss: 0.0907 - mean_squared_error: 0.0147 - val_loss: 0.0766 - val_mean_squared_error: 0.0064
# Epoch 15/1000
#  - 1s - loss: 0.0900 - mean_squared_error: 0.0144 - val_loss: 0.0896 - val_mean_squared_error: 0.0082
# Epoch 16/1000
#  - 1s - loss: 0.0909 - mean_squared_error: 0.0146 - val_loss: 0.0662 - val_mean_squared_error: 0.0057
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
# Epoch 17/1000
#  - 1s - loss: 0.0893 - mean_squared_error: 0.0144 - val_loss: 0.0787 - val_mean_squared_error: 0.0066
# Epoch 18/1000
#  - 1s - loss: 0.0886 - mean_squared_error: 0.0141 - val_loss: 0.0811 - val_mean_squared_error: 0.0071
# Epoch 19/1000
#  - 1s - loss: 0.0886 - mean_squared_error: 0.0141 - val_loss: 0.0768 - val_mean_squared_error: 0.0063
# predict: [[30.98456526 22.98701832]]
# real:      [[29.9 22.6]]
#
# Train and validation time: 9.030180354913076
#
# Maximum temperatures metrics
# Test MEAN-SQUARED-ERROR ------------ 2.15
# Test STANDART-DEVIATION ------------ 0.8916
# Test MEAN-ABSOLUTE-ERROR ----------- 1.164
# Test MEDIAN-ABSOLUTE-ERROR --------- 1.071
#
# Errors
# 2018-12-31 = 0.4148530006408713
# 2018-12-30 = 1.1932056427001925
# 2018-12-29 = 2.36663112640381
# 2018-12-28 = 1.5886385917663546
# 2018-12-27 = 2.936268424987791
# 2018-12-26 = 1.5286661148071268
# 2018-12-25 = 0.22585620880127166
# 2018-12-24 = 0.1976125717163093
# 2018-12-23 = 0.39706687927246165
# 2018-12-22 = 0.09819803237915181
# 2018-12-21 = 0.39615392684936523
# 2018-12-20 = 0.3761122703552253
# 2018-12-19 = 0.8830877304077163
# 2018-12-18 = 1.6018554687500028
# 2018-12-17 = 3.0649987220764174
# 2018-12-16 = 0.7522542953491218
# 2018-12-15 = 1.1205592155456543
# 2018-12-14 = 1.3972053527832067
# 2018-12-13 = 0.21241769790649556
# 2018-12-12 = 0.9982613563537583
# 2018-12-11 = 1.1479485511779828
# 2018-12-10 = 1.318002510070805
# 2018-12-09 = 1.0567171096801715
# 2018-12-08 = 2.5666204452514627
# 2018-12-07 = 0.6570955276489272
# 2018-12-06 = 3.4009135246276827
# 2018-12-05 = 0.7416492462158182
# 2018-12-04 = 1.1070841789245591
# 2018-12-03 = 0.09396839141845348
# 2018-12-02 = 1.084565258026128
#
# Accuracy
# 46.67% of predictions missed between (0, 1] point(s)
# 36.67% of predictions missed between (1, 2] point(s)
# 10.00% of predictions missed between (2, 3] point(s)
# 6.67% of predictions missed between (3, 4] point(s)
#
#
#
# Minimum temperatures metrics
# Test MEAN-SQUARED-ERROR ------------ 0.39
# Test STANDART-DEVIATION ------------ 0.3529
# Test MEAN-ABSOLUTE-ERROR ----------- 0.5152
# Test MEDIAN-ABSOLUTE-ERROR --------- 0.4196
#
# Errors
# 2018-12-31 = 0.04687335491180633
# 2018-12-30 = 0.33078565597534393
# 2018-12-29 = 0.2377850770950296
# 2018-12-28 = 0.3354868412017815
# 2018-12-27 = 0.2870501518249533
# 2018-12-26 = 0.4933886051178007
# 2018-12-25 = 0.6209795236587539
# 2018-12-24 = 0.664838504791259
# 2018-12-23 = 0.36712160110473135
# 2018-12-22 = 0.2544551849365213
# 2018-12-21 = 0.2271734237670877
# 2018-12-20 = 0.36798062324523784
# 2018-12-19 = 1.0945370197296143
# 2018-12-18 = 0.5951135396957383
# 2018-12-17 = 0.028270792961116342
# 2018-12-16 = 1.0550418376922615
# 2018-12-15 = 0.6085455417633057
# 2018-12-14 = 0.22933845520019602
# 2018-12-13 = 0.9783992290496855
# 2018-12-12 = 0.9466920137405381
# 2018-12-11 = 0.1851822137832606
# 2018-12-10 = 0.038071107864382725
# 2018-12-09 = 0.174422144889828
# 2018-12-08 = 0.5743968486785889
# 2018-12-07 = 1.5138146400451653
# 2018-12-06 = 0.8924255371093786
# 2018-12-05 = 0.6323007583618185
# 2018-12-04 = 0.45210824012756134
# 2018-12-03 = 0.8351643562316866
# 2018-12-02 = 0.3870183229446411
#
# Accuracy
# 90.00% of predictions missed between (0, 1] point(s)
# 10.00% of predictions missed between (1, 2] point(s)
